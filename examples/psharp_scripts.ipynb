# %%
import petrovisor as pv
#from petrovisor import SignalType, TimeIncrement, DepthIncrement

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Authorization

# %%
# url
# discovery_url = r'https://identity.eu1.petrovisor.com'
discovery_url = r'https://identity.us1.petrovisor.com'

# workspace
workspace = 'Workspace Name'

# generate access key (only for the first time, comment the line afterwards)
key = pv.PetroVisor.generate_credentials_key()
# print(f"key : '{key}'")
# save key for later to reuse
# key = ''

pv_api = pv.PetroVisor(workspace = workspace, discovery_url = discovery_url, key = key)
print(pv_api.Api)

# %% [markdown]
# # PetroVisor API Swagger

# %% [markdown]
# https://api.eu1.petrovisor.com/index.html

# %% [markdown]
# https://api.us1.petrovisor.com/index.html

# %% [markdown]
# # Examples: P# Scripts

# %%
# import production and injection data from PetroVisor
psharp_script_name = 'Reservoir and Production Data'

# %% [markdown]
# #### Get P# script object

# %%
# get P# script
psharp_script = pv_api.get_psharp_script(psharp_script_name)
psharp_script
# Out:
# {'Content': 'Context "All Wells Start To End Monthly"\n\tEntity Set "Production Wells"\n\tScope "Production Period"\nEnd Context\n\nEntity Set "Production Wells"\n\t"Well 001"\n\t"Well 002"\n\t"Well 003"\n\t"Well 50"\nEnd Set\n\nScope "Production Period"\n\tBetween #01/01/2020#\n\tAnd #01/07/2022#\n\tStep Monthly\n\tFrom 0\n\tTo 100\n\tDepth Step Meter\nEnd Scope\n\nTable "Production/Injection"\n\tColumn "Oil" in "m3/d"\n\t\t"oil production rate" in "m3/d"\n\tEnd Column\n\tColumn "Gas" in "m3/d"\n\t\t"gas production rate" in "m3/d"\n\tEnd Column\n\tColumn "Water" in "m3/d"\n\t\t"water production rate" in "m3/d"\n\tEnd Column\n\tColumn "WCUT" in " "\n\t\t"water cut" in " "\n\tEnd Column\n\tColumn "GOR" in " "\n\t\t"gas oil ratio" in " "\n\tEnd Column\n\tColumn "Water Injection" in "m3/d"\n\t\t"water injection rate" in "m3/d"\n\tEnd Column\nEnd Table\n\nTable "Reservoir Data"\n\tColumn "Longitude" in " "\n\t\t"Longitude" in " "\n\tEnd Column\n\tColumn "Latitude" in " "\n\t\t"Latitude" in " "\n\tEnd Column\nEnd Table\n\nTable "Depth Data"\n\tColumn "x0" in " "\n\t\t"op x0" in " "\n\tEnd Column\n\tDepth Column "x0 depth" in " "\n\t\t"op x0 depth" in " "\n\tEnd Column\n\tDepth Column "x1 depth" in " "\n\t\t"op x1 depth" in " "\n\tEnd Column\nEnd Table\n\nTable "String Data"\n\tColumn "static string" in " "\n\t\t"static string"\tin " "\t\n\tEnd Column\nEnd Table\n\nTable "Time String Data"\n\tColumn "time string" in " "\n\t\t"time string" in " "\t\n\tEnd Column\nEnd Table\n\nTable "Mixed Data"\n\tColumn "static column" in " "\n\t\t"op x0" in " "\n\tEnd Column\n\tColumn "time column" in "m3/d"\n\t\t"oil production rate" in "m3/d"\n\tEnd Column\n\tDepth Column "depth column" in " "\n\t\t"op x1 depth" in " "\n\tEnd Column\n\tColumn "string column" in " "\n\t\t"static string"\tin " "\t\n\tEnd Column\nEnd Table\n\nTable "Objective Function" Input "Production/Injection"\n\tColumn "Iteration" in " "\n\t\t1 //_Double("Iteration",1)\n\tEnd Column\n\tColumn "Constraint (>=): VRR" in " "\n\t\tInput Column "Water" in "m3/d" - Input Column "Oil" in "m3/d"\n\tEnd Column\n\tColumn "Objective Function (sum): NPV" in " "\n\t\t(Input Column "Oil" in "m3/d") / (Input Column "Water" in "m3/d" + Input Column "Oil" in "m3/d")\n\tEnd Column\nEnd Table',
#  'User': 'RomanManasipov',
#  'Modified': '2023-03-21T13:14:09.308',
#  'Created': '2023-01-24T08:16:54.396',
#  'ModifiedBy': 'RomanManasipov',
#  'Labels': [],
#  'Name': 'Reservoir and Production Data'}

# %% [markdown]
# #### Parse P# script

# %%
# parse P# script
# option 1: use P# script name
psharp_script_parsed = pv_api.parse_psharp_script(psharp_script_name)
psharp_script_parsed
# Out:
# {'TableCalculations': [{'Columns': [{'Unit': {'MeasurementName': 'Flowrate',
#       'Factor': 1.15740740740741e-05,
#       'Name': 'm3/d'},
#      'Formula': '"oil production rate" in "m3/d"',
#      'ResultType': 'Numeric',
#      'Name': 'Oil'},
#     {'Unit': {'MeasurementName': 'Flowrate',
#       'Factor': 1.15740740740741e-05,
#       'Name': 'm3/d'},
#      'Formula': '"gas production rate" in "m3/d"',
#      'ResultType': 'Numeric',
#      'Name': 'Gas'},
#     {'Unit': {'MeasurementName': 'Flowrate',
#       'Factor': 1.15740740740741e-05,
#       'Name': 'm3/d'},
#      'Formula': '"water production rate" in "m3/d"',
#      'ResultType': 'Numeric',
#      'Name': 'Water'},
#     {'Unit': {'MeasurementName': 'Dimensionless', 'Factor': 1, 'Name': ' '},
#      'Formula': '"water cut" in " "',
#      'ResultType': 'Numeric',
#      'Name': 'WCUT'},
#     {'Unit': {'MeasurementName': 'Dimensionless', 'Factor': 1, 'Name': ' '},
#      'Formula': '"gas oil ratio" in " "',
#      'ResultType': 'Numeric',
#      'Name': 'GOR'},
#     {'Unit': {'MeasurementName': 'Flowrate',
#       'Factor': 1.15740740740741e-05,
#       'Name': 'm3/d'},
#      'Formula': '"water injection rate" in "m3/d"',
#      'ResultType': 'Numeric',
#      'Name': 'Water Injection'}],
#    'InputTableNames': [],
#    'Modified': '2023-03-21T13:40:16.6145452Z',
#    'Created': '2023-03-21T13:40:16.6145453Z',
#    'Labels': [],
#    'Name': 'Production/Injection'},
#   {'Columns': [{'Unit': {'MeasurementName': 'Dimensionless',
#       'Factor': 1,
#       'Name': ' '},
#      'Formula': '"Longitude" in " "',
#      'IsStatic': True,
#      'ResultType': 'Numeric',
#      'Name': 'Longitude'},
#     {'Unit': {'MeasurementName': 'Dimensionless', 'Factor': 1, 'Name': ' '},
#      'Formula': '"Latitude" in " "',
#      'IsStatic': True,
#      'ResultType': 'Numeric',
#      'Name': 'Latitude'}],
#    'InputTableNames': [],
#    'Modified': '2023-03-21T13:40:16.6158311Z',
#    'Created': '2023-03-21T13:40:16.6158313Z',
#    'Labels': [],
#    'Name': 'Reservoir Data'},
#   {'Columns': [{'Unit': {'MeasurementName': 'Dimensionless',
#       'Factor': 1,
#       'Name': ' '},
#      'Formula': '"op x0" in " "',
#      'IsStatic': True,
#      'ResultType': 'Numeric',
#      'Name': 'x0'},
#     {'Unit': {'MeasurementName': 'Dimensionless', 'Factor': 1, 'Name': ' '},
#      'Formula': '"op x0 depth" in " "',
#      'IsDepth': True,
#      'ResultType': 'Numeric',
#      'Name': 'x0 depth'},
#     {'Unit': {'MeasurementName': 'Dimensionless', 'Factor': 1, 'Name': ' '},
#      'Formula': '"op x1 depth" in " "',
#      'IsDepth': True,
#      'ResultType': 'Numeric',
#      'Name': 'x1 depth'}],
#    'InputTableNames': [],
#    'Modified': '2023-03-21T13:40:16.6158321Z',
#    'Created': '2023-03-21T13:40:16.6158321Z',
#    'Labels': [],
#    'Name': 'Depth Data'},
#   {'Columns': [{'Unit': {'MeasurementName': 'Dimensionless',
#       'Factor': 1,
#       'Name': ' '},
#      'Formula': '"static string"\tin " "',
#      'IsStatic': True,
#      'ResultType': 'String',
#      'Name': 'static string'}],
#    'InputTableNames': [],
#    'Modified': '2023-03-21T13:40:16.6158327Z',
#    'Created': '2023-03-21T13:40:16.6158327Z',
#    'Labels': [],
#    'Name': 'String Data'},
#   {'Columns': [{'Unit': {'MeasurementName': 'Dimensionless',
#       'Factor': 1,
#       'Name': ' '},
#      'Formula': '"time string" in " "',
#      'ResultType': 'String',
#      'Name': 'time string'}],
#    'InputTableNames': [],
#    'Modified': '2023-03-21T13:40:16.6158332Z',
#    'Created': '2023-03-21T13:40:16.6158333Z',
#    'Labels': [],
#    'Name': 'Time String Data'},
#   {'Columns': [{'Unit': {'MeasurementName': 'Dimensionless',
#       'Factor': 1,
#       'Name': ' '},
#      'Formula': '"op x0" in " "',
#      'IsStatic': True,
#      'ResultType': 'Numeric',
#      'Name': 'static column'},
#     {'Unit': {'MeasurementName': 'Flowrate',
#       'Factor': 1.15740740740741e-05,
#       'Name': 'm3/d'},
#      'Formula': '"oil production rate" in "m3/d"',
#      'ResultType': 'Numeric',
#      'Name': 'time column'},
#     {'Unit': {'MeasurementName': 'Dimensionless', 'Factor': 1, 'Name': ' '},
#      'Formula': '"op x1 depth" in " "',
#      'IsDepth': True,
#      'ResultType': 'Numeric',
#      'Name': 'depth column'},
#     {'Unit': {'MeasurementName': 'Dimensionless', 'Factor': 1, 'Name': ' '},
#      'Formula': '"static string"\tin " "',
#      'IsStatic': True,
#      'ResultType': 'String',
#      'Name': 'string column'}],
#    'InputTableNames': [],
#    'Modified': '2023-03-21T13:40:16.6158339Z',
#    'Created': '2023-03-21T13:40:16.6158339Z',
#    'Labels': [],
#    'Name': 'Mixed Data'},
#   {'Columns': [{'Unit': {'MeasurementName': 'Dimensionless',
#       'Factor': 1,
#       'Name': ' '},
#      'Formula': '1',
#      'IsStatic': True,
#      'ResultType': 'Numeric',
#      'Name': 'Iteration'},
#     {'Unit': {'MeasurementName': 'Dimensionless', 'Factor': 1, 'Name': ' '},
#      'Formula': 'Input Column "Water" in "m3/d" - Input Column "Oil" in "m3/d"',
#      'ResultType': 'Numeric',
#      'Name': 'Constraint (>=): VRR'},
#     {'Unit': {'MeasurementName': 'Dimensionless', 'Factor': 1, 'Name': ' '},
#      'Formula': '(Input Column "Oil" in "m3/d") / (Input Column "Water" in "m3/d" + Input Column "Oil" in "m3/d")',
#      'ResultType': 'Numeric',
#      'Name': 'Objective Function (sum): NPV'}],
#    'InputTableNames': ['Production/Injection'],
#    'Modified': '2023-03-21T13:40:16.6158348Z',
#    'Created': '2023-03-21T13:40:16.6158348Z',
#    'Labels': [],
#    'Name': 'Objective Function'}],
#  'EventCalculations': [],
#  'CleansingCalculations': [],
#  'Contexts': [{'EntitySet': {'Entities': [{'EntityTypeName': 'Well',
#       'Alias': 'First Well',
#       'Name': 'Well 001'},
#      {'EntityTypeName': 'Well', 'Name': 'Well 002'},
#      {'EntityTypeName': 'Well', 'Name': 'Well 003'},
#      {'EntityTypeName': 'Well', 'Name': 'Well 50'}],
#     'Formula': 'Entity Set "Production Wells"\n\t"Well 001"\n\t"Well 002"\n\t"Well 003"\n\t"Well 50"\nEnd Set',
#     'Modified': '2023-03-21T13:40:16.6174129Z',
#     'Created': '2023-03-21T13:40:16.6174131Z',
#     'Labels': [],
#     'Name': 'Production Wells'},
#    'Scope': {'Start': '2020-01-01T00:00:00',
#     'End': '2022-01-07T00:00:00',
#     'TimeIncrement': 'Monthly',
#     'DepthIncrement': 'Meter',
#     'EndDepth': 100,
#     'Formula': 'Scope "Production Period"\n\tBetween #01/01/2020#\n\tAnd #01/07/2022#\n\tStep Monthly\n\tFrom 0\n\tTo 100\n\tDepth Step Meter\nEnd Scope',
#     'Modified': '2023-03-21T13:40:16.6186434Z',
#     'Created': '2023-03-21T13:40:16.6186435Z',
#     'Labels': [],
#     'Name': 'Production Period'},
#    'Modified': '2023-03-21T13:40:16.6186602Z',
#    'Created': '2023-03-21T13:40:16.6186603Z',
#    'Labels': [],
#    'Name': 'All Wells Start To End Monthly'}],
#  'EntitySets': [{'Entities': [{'EntityTypeName': 'Well',
#      'Alias': 'First Well',
#      'Name': 'Well 001'},
#     {'EntityTypeName': 'Well', 'Name': 'Well 002'},
#     {'EntityTypeName': 'Well', 'Name': 'Well 003'},
#     {'EntityTypeName': 'Well', 'Name': 'Well 50'}],
#    'Formula': 'Entity Set "Production Wells"\n\t"Well 001"\n\t"Well 002"\n\t"Well 003"\n\t"Well 50"\nEnd Set',
#    'Modified': '2023-03-21T13:40:16.6174129Z',
#    'Created': '2023-03-21T13:40:16.6174131Z',
#    'Labels': [],
#    'Name': 'Production Wells'}],
#  'Scopes': [{'Start': '2020-01-01T00:00:00',
#    'End': '2022-01-07T00:00:00',
#    'TimeIncrement': 'Monthly',
#    'DepthIncrement': 'Meter',
#    'EndDepth': 100,
#    'Formula': 'Scope "Production Period"\n\tBetween #01/01/2020#\n\tAnd #01/07/2022#\n\tStep Monthly\n\tFrom 0\n\tTo 100\n\tDepth Step Meter\nEnd Scope',
#    'Modified': '2023-03-21T13:40:16.6186434Z',
#    'Created': '2023-03-21T13:40:16.6186435Z',
#    'Labels': [],
#    'Name': 'Production Period'}],
#  'Plots': [],
#  'Warning': ''}

# %%
# parse P# script
# option 2: if got P# script object already, P# script object can be used for faster access
psharp_script_parsed = pv_api.parse_psharp_script(psharp_script)
psharp_script_parsed
# Out:
# {'TableCalculations': [{'Columns': [{'Unit': {'MeasurementName': 'Flowrate',
#       'Factor': 1.15740740740741e-05,
#       'Name': 'm3/d'},
#      'Formula': '"oil production rate" in "m3/d"',
#      'ResultType': 'Numeric',
#      'Name': 'Oil'},
#     {'Unit': {'MeasurementName': 'Flowrate',
#       'Factor': 1.15740740740741e-05,
#       'Name': 'm3/d'},
#      'Formula': '"gas production rate" in "m3/d"',
#      'ResultType': 'Numeric',
#      'Name': 'Gas'},
#     {'Unit': {'MeasurementName': 'Flowrate',
#       'Factor': 1.15740740740741e-05,
#       'Name': 'm3/d'},
#      'Formula': '"water production rate" in "m3/d"',
#      'ResultType': 'Numeric',
#      'Name': 'Water'},
#     {'Unit': {'MeasurementName': 'Dimensionless', 'Factor': 1, 'Name': ' '},
#      'Formula': '"water cut" in " "',
#      'ResultType': 'Numeric',
#      'Name': 'WCUT'},
#     {'Unit': {'MeasurementName': 'Dimensionless', 'Factor': 1, 'Name': ' '},
#      'Formula': '"gas oil ratio" in " "',
#      'ResultType': 'Numeric',
#      'Name': 'GOR'},
#     {'Unit': {'MeasurementName': 'Flowrate',
#       'Factor': 1.15740740740741e-05,
#       'Name': 'm3/d'},
#      'Formula': '"water injection rate" in "m3/d"',
#      'ResultType': 'Numeric',
#      'Name': 'Water Injection'}],
#    'InputTableNames': [],
#    'Modified': '2023-03-21T13:40:16.9075233Z',
#    'Created': '2023-03-21T13:40:16.9075234Z',
#    'Labels': [],
#    'Name': 'Production/Injection'},
#   {'Columns': [{'Unit': {'MeasurementName': 'Dimensionless',
#       'Factor': 1,
#       'Name': ' '},
#      'Formula': '"Longitude" in " "',
#      'IsStatic': True,
#      'ResultType': 'Numeric',
#      'Name': 'Longitude'},
#     {'Unit': {'MeasurementName': 'Dimensionless', 'Factor': 1, 'Name': ' '},
#      'Formula': '"Latitude" in " "',
#      'IsStatic': True,
#      'ResultType': 'Numeric',
#      'Name': 'Latitude'}],
#    'InputTableNames': [],
#    'Modified': '2023-03-21T13:40:16.9090897Z',
#    'Created': '2023-03-21T13:40:16.9090898Z',
#    'Labels': [],
#    'Name': 'Reservoir Data'},
#   {'Columns': [{'Unit': {'MeasurementName': 'Dimensionless',
#       'Factor': 1,
#       'Name': ' '},
#      'Formula': '"op x0" in " "',
#      'IsStatic': True,
#      'ResultType': 'Numeric',
#      'Name': 'x0'},
#     {'Unit': {'MeasurementName': 'Dimensionless', 'Factor': 1, 'Name': ' '},
#      'Formula': '"op x0 depth" in " "',
#      'IsDepth': True,
#      'ResultType': 'Numeric',
#      'Name': 'x0 depth'},
#     {'Unit': {'MeasurementName': 'Dimensionless', 'Factor': 1, 'Name': ' '},
#      'Formula': '"op x1 depth" in " "',
#      'IsDepth': True,
#      'ResultType': 'Numeric',
#      'Name': 'x1 depth'}],
#    'InputTableNames': [],
#    'Modified': '2023-03-21T13:40:16.9090908Z',
#    'Created': '2023-03-21T13:40:16.9090908Z',
#    'Labels': [],
#    'Name': 'Depth Data'},
#   {'Columns': [{'Unit': {'MeasurementName': 'Dimensionless',
#       'Factor': 1,
#       'Name': ' '},
#      'Formula': '"static string"\tin " "',
#      'IsStatic': True,
#      'ResultType': 'String',
#      'Name': 'static string'}],
#    'InputTableNames': [],
#    'Modified': '2023-03-21T13:40:16.9090914Z',
#    'Created': '2023-03-21T13:40:16.9090915Z',
#    'Labels': [],
#    'Name': 'String Data'},
#   {'Columns': [{'Unit': {'MeasurementName': 'Dimensionless',
#       'Factor': 1,
#       'Name': ' '},
#      'Formula': '"time string" in " "',
#      'ResultType': 'String',
#      'Name': 'time string'}],
#    'InputTableNames': [],
#    'Modified': '2023-03-21T13:40:16.9090921Z',
#    'Created': '2023-03-21T13:40:16.9090921Z',
#    'Labels': [],
#    'Name': 'Time String Data'},
#   {'Columns': [{'Unit': {'MeasurementName': 'Dimensionless',
#       'Factor': 1,
#       'Name': ' '},
#      'Formula': '"op x0" in " "',
#      'IsStatic': True,
#      'ResultType': 'Numeric',
#      'Name': 'static column'},
#     {'Unit': {'MeasurementName': 'Flowrate',
#       'Factor': 1.15740740740741e-05,
#       'Name': 'm3/d'},
#      'Formula': '"oil production rate" in "m3/d"',
#      'ResultType': 'Numeric',
#      'Name': 'time column'},
#     {'Unit': {'MeasurementName': 'Dimensionless', 'Factor': 1, 'Name': ' '},
#      'Formula': '"op x1 depth" in " "',
#      'IsDepth': True,
#      'ResultType': 'Numeric',
#      'Name': 'depth column'},
#     {'Unit': {'MeasurementName': 'Dimensionless', 'Factor': 1, 'Name': ' '},
#      'Formula': '"static string"\tin " "',
#      'IsStatic': True,
#      'ResultType': 'String',
#      'Name': 'string column'}],
#    'InputTableNames': [],
#    'Modified': '2023-03-21T13:40:16.909093Z',
#    'Created': '2023-03-21T13:40:16.909093Z',
#    'Labels': [],
#    'Name': 'Mixed Data'},
#   {'Columns': [{'Unit': {'MeasurementName': 'Dimensionless',
#       'Factor': 1,
#       'Name': ' '},
#      'Formula': '1',
#      'IsStatic': True,
#      'ResultType': 'Numeric',
#      'Name': 'Iteration'},
#     {'Unit': {'MeasurementName': 'Dimensionless', 'Factor': 1, 'Name': ' '},
#      'Formula': 'Input Column "Water" in "m3/d" - Input Column "Oil" in "m3/d"',
#      'ResultType': 'Numeric',
#      'Name': 'Constraint (>=): VRR'},
#     {'Unit': {'MeasurementName': 'Dimensionless', 'Factor': 1, 'Name': ' '},
#      'Formula': '(Input Column "Oil" in "m3/d") / (Input Column "Water" in "m3/d" + Input Column "Oil" in "m3/d")',
#      'ResultType': 'Numeric',
#      'Name': 'Objective Function (sum): NPV'}],
#    'InputTableNames': ['Production/Injection'],
#    'Modified': '2023-03-21T13:40:16.9090944Z',
#    'Created': '2023-03-21T13:40:16.9090945Z',
#    'Labels': [],
#    'Name': 'Objective Function'}],
#  'EventCalculations': [],
#  'CleansingCalculations': [],
#  'Contexts': [{'EntitySet': {'Entities': [{'EntityTypeName': 'Well',
#       'Alias': 'First Well',
#       'Name': 'Well 001'},
#      {'EntityTypeName': 'Well', 'Name': 'Well 002'},
#      {'EntityTypeName': 'Well', 'Name': 'Well 003'},
#      {'EntityTypeName': 'Well', 'Name': 'Well 50'}],
#     'Formula': 'Entity Set "Production Wells"\n\t"Well 001"\n\t"Well 002"\n\t"Well 003"\n\t"Well 50"\nEnd Set',
#     'Modified': '2023-03-21T13:40:16.9119869Z',
#     'Created': '2023-03-21T13:40:16.911987Z',
#     'Labels': [],
#     'Name': 'Production Wells'},
#    'Scope': {'Start': '2020-01-01T00:00:00',
#     'End': '2022-01-07T00:00:00',
#     'TimeIncrement': 'Monthly',
#     'DepthIncrement': 'Meter',
#     'EndDepth': 100,
#     'Formula': 'Scope "Production Period"\n\tBetween #01/01/2020#\n\tAnd #01/07/2022#\n\tStep Monthly\n\tFrom 0\n\tTo 100\n\tDepth Step Meter\nEnd Scope',
#     'Modified': '2023-03-21T13:40:16.9129674Z',
#     'Created': '2023-03-21T13:40:16.9129674Z',
#     'Labels': [],
#     'Name': 'Production Period'},
#    'Modified': '2023-03-21T13:40:16.9129856Z',
#    'Created': '2023-03-21T13:40:16.9129857Z',
#    'Labels': [],
#    'Name': 'All Wells Start To End Monthly'}],
#  'EntitySets': [{'Entities': [{'EntityTypeName': 'Well',
#      'Alias': 'First Well',
#      'Name': 'Well 001'},
#     {'EntityTypeName': 'Well', 'Name': 'Well 002'},
#     {'EntityTypeName': 'Well', 'Name': 'Well 003'},
#     {'EntityTypeName': 'Well', 'Name': 'Well 50'}],
#    'Formula': 'Entity Set "Production Wells"\n\t"Well 001"\n\t"Well 002"\n\t"Well 003"\n\t"Well 50"\nEnd Set',
#    'Modified': '2023-03-21T13:40:16.9119869Z',
#    'Created': '2023-03-21T13:40:16.911987Z',
#    'Labels': [],
#    'Name': 'Production Wells'}],
#  'Scopes': [{'Start': '2020-01-01T00:00:00',
#    'End': '2022-01-07T00:00:00',
#    'TimeIncrement': 'Monthly',
#    'DepthIncrement': 'Meter',
#    'EndDepth': 100,
#    'Formula': 'Scope "Production Period"\n\tBetween #01/01/2020#\n\tAnd #01/07/2022#\n\tStep Monthly\n\tFrom 0\n\tTo 100\n\tDepth Step Meter\nEnd Scope',
#    'Modified': '2023-03-21T13:40:16.9129674Z',
#    'Created': '2023-03-21T13:40:16.9129674Z',
#    'Labels': [],
#    'Name': 'Production Period'}],
#  'Plots': [],
#  'Warning': ''}

# %% [markdown]
# #### Get P# script table names

# %%
# get P# script table names
psharp_script_table_names = pv_api.get_psharp_script_table_names(psharp_script_name)
psharp_script_table_names
# Out:
# ['Production/Injection',
#  'Reservoir Data',
#  'Depth Data',
#  'String Data',
#  'Time String Data',
#  'Mixed Data',
#  'Objective Function']

# %% [markdown]
# #### Get P# script columns/signals information from all tables

# %%
# If P# script contains tables with list of signals, get extract tables and signal names
# get psharp script signals

# option 1: use P# script name
# table_signals = pv_api.get_psharp_script_columns_and_signals(psharp_script_name)

# option 2: if got P# script object already, P# script object can be used for faster access
# table_signals = pv_api.get_psharp_script_columns_and_signals(psharp_script)

# option 3: if parsed P# script already, parsed P# script can be used for faster access
table_signals = pv_api.get_psharp_script_columns_and_signals(psharp_script_parsed)

table_signals
# Out:
# {'Production/Injection': {'Oil': {'Unit': 'm3/d',
#    'Signal': 'oil production rate',
#    'SignalUnit': 'm3/d'},
#   'Gas': {'Unit': 'm3/d',
#    'Signal': 'gas production rate',
#    'SignalUnit': 'm3/d'},
#   'Water': {'Unit': 'm3/d',
#    'Signal': 'water production rate',
#    'SignalUnit': 'm3/d'},
#   'WCUT': {'Unit': ' ', 'Signal': 'water cut', 'SignalUnit': ' '},
#   'GOR': {'Unit': ' ', 'Signal': 'gas oil ratio', 'SignalUnit': ' '},
#   'Water Injection': {'Unit': 'm3/d',
#    'Signal': 'water injection rate',
#    'SignalUnit': 'm3/d'}},
#  'Reservoir Data': {'Longitude': {'Unit': ' ',
#    'Signal': 'Longitude',
#    'SignalUnit': ' '},
#   'Latitude': {'Unit': ' ', 'Signal': 'Latitude', 'SignalUnit': ' '}},
#  'Depth Data': {'x0': {'Unit': ' ', 'Signal': 'op x0', 'SignalUnit': ' '},
#   'x0 depth': {'Unit': ' ', 'Signal': 'op x0 depth', 'SignalUnit': ' '},
#   'x1 depth': {'Unit': ' ', 'Signal': 'op x1 depth', 'SignalUnit': ' '}},
#  'String Data': {'static string': {'Unit': ' ',
#    'Signal': 'static string',
#    'SignalUnit': ' '}},
#  'Time String Data': {'time string': {'Unit': ' ',
#    'Signal': 'time string',
#    'SignalUnit': ' '}},
#  'Mixed Data': {'static column': {'Unit': ' ',
#    'Signal': 'op x0',
#    'SignalUnit': ' '},
#   'time column': {'Unit': 'm3/d',
#    'Signal': 'oil production rate',
#    'SignalUnit': 'm3/d'},
#   'depth column': {'Unit': ' ', 'Signal': 'op x1 depth', 'SignalUnit': ' '},
#   'string column': {'Unit': ' ',
#    'Signal': 'static string',
#    'SignalUnit': ' '}},
#  'Objective Function': {'Iteration': {'Unit': ' ',
#    'Signal': '',
#    'SignalUnit': ' '},
#   'Constraint (>=): VRR': {'Unit': ' ',
#    'Signal': 'Water',
#    'SignalUnit': 'm3/d'},
#   'Objective Function (sum): NPV': {'Unit': ' ',
#    'Signal': 'Oil',
#    'SignalUnit': 'm3/d'}}}

# %%
for table_name, columns in table_signals.items():
    print(f"Table name: '{table_name}'")
    for column, signal_unit in columns.items():
          print(f"Column: '{column}', Unit: '{signal_unit['Unit']}', Signal: '{signal_unit['Signal']}', SignalUnit: '{signal_unit['SignalUnit']}'")
# Out:
# Table name: 'Production/Injection'
# Column: 'Oil', Unit: 'm3/d', Signal: 'oil production rate', SignalUnit: 'm3/d'
# Column: 'Gas', Unit: 'm3/d', Signal: 'gas production rate', SignalUnit: 'm3/d'
# Column: 'Water', Unit: 'm3/d', Signal: 'water production rate', SignalUnit: 'm3/d'
# Column: 'WCUT', Unit: ' ', Signal: 'water cut', SignalUnit: ' '
# Column: 'GOR', Unit: ' ', Signal: 'gas oil ratio', SignalUnit: ' '
# Column: 'Water Injection', Unit: 'm3/d', Signal: 'water injection rate', SignalUnit: 'm3/d'
# Table name: 'Reservoir Data'
# Column: 'Longitude', Unit: ' ', Signal: 'Longitude', SignalUnit: ' '
# Column: 'Latitude', Unit: ' ', Signal: 'Latitude', SignalUnit: ' '
# Table name: 'Depth Data'
# Column: 'x0', Unit: ' ', Signal: 'op x0', SignalUnit: ' '
# Column: 'x0 depth', Unit: ' ', Signal: 'op x0 depth', SignalUnit: ' '
# Column: 'x1 depth', Unit: ' ', Signal: 'op x1 depth', SignalUnit: ' '
# Table name: 'String Data'
# Column: 'static string', Unit: ' ', Signal: 'static string', SignalUnit: ' '
# Table name: 'Time String Data'
# Column: 'time string', Unit: ' ', Signal: 'time string', SignalUnit: ' '
# Table name: 'Mixed Data'
# Column: 'static column', Unit: ' ', Signal: 'op x0', SignalUnit: ' '
# Column: 'time column', Unit: 'm3/d', Signal: 'oil production rate', SignalUnit: 'm3/d'
# Column: 'depth column', Unit: ' ', Signal: 'op x1 depth', SignalUnit: ' '
# Column: 'string column', Unit: ' ', Signal: 'static string', SignalUnit: ' '
# Table name: 'Objective Function'
# Column: 'Iteration', Unit: ' ', Signal: '', SignalUnit: ' '
# Column: 'Constraint (>=): VRR', Unit: ' ', Signal: 'Water', SignalUnit: 'm3/d'
# Column: 'Objective Function (sum): NPV', Unit: ' ', Signal: 'Oil', SignalUnit: 'm3/d'

# %% [markdown]
# #### Get P# script table by 'ID'

# %%
# execute P# script as table by id
# first table
table_id = 0
psharp_script_table_by_id1 = pv_api.load_psharp_table(psharp_script_name,
                                                      table = table_id)
psharp_script_table_by_id1
# Out:
#          Date    Entity       Alias  Oil [m3/d]   Gas [m3/d]  Water [m3/d]  \
# 0  2020-01-01  Well 001  First Well   65.965954  1391.476946           NaN
# 1  2020-01-01  Well 002        <NA>         NaN  1124.649063           NaN
# 2  2020-01-01  Well 003        <NA>         NaN  1059.649193           NaN
# 3  2020-01-01   Well 50        <NA>         NaN          NaN           NaN
# 4  2020-02-01  Well 001  First Well   48.839408  1154.037872           NaN
# ..        ...       ...         ...         ...          ...           ...
# 95 2021-12-01   Well 50        <NA>         NaN          NaN           NaN
# 96 2022-01-01  Well 001  First Well         NaN  1227.994198           NaN
# 97 2022-01-01  Well 002        <NA>         NaN  1148.961958           NaN
# 98 2022-01-01  Well 003        <NA>         NaN  1229.877342           NaN
# 99 2022-01-01   Well 50        <NA>         NaN          NaN           NaN
#
#     WCUT [ ]    GOR [ ]  Water Injection [m3/d]
# 0        NaN  44.126435                     NaN
# 1        NaN  39.643691                     NaN
# 2        NaN  54.060569                     NaN
# 3        NaN        NaN                     NaN
# 4        NaN  51.745135                     NaN
# ..       ...        ...                     ...
# 95       NaN        NaN                     NaN
# 96       NaN  46.822568                     NaN
# 97       NaN  53.092606                     NaN
# 98       NaN  46.921897                     NaN
# 99       NaN        NaN                     NaN
#
# [100 rows x 9 columns]

# %%
# execute P# script as table by id
# last table
table_id = -1
psharp_script_table_by_id2 = pv_api.load_psharp_table(psharp_script_name,
                                                      table = table_id)
psharp_script_table_by_id2
# Out:
#          Date    Entity       Alias  Iteration [ ]  Constraint (>=): VRR [ ]  \
# 0  2020-01-01  Well 001  First Well              1                       NaN
# 1  2020-01-01  Well 002        <NA>              1                       NaN
# 2  2020-01-01  Well 003        <NA>              1                       NaN
# 3  2020-01-01   Well 50        <NA>              1                       NaN
# 4  2020-02-01  Well 001  First Well              1                       NaN
# ..        ...       ...         ...            ...                       ...
# 95 2021-12-01   Well 50        <NA>              1                       NaN
# 96 2022-01-01  Well 001  First Well              1                       NaN
# 97 2022-01-01  Well 002        <NA>              1                       NaN
# 98 2022-01-01  Well 003        <NA>              1                       NaN
# 99 2022-01-01   Well 50        <NA>              1                       NaN
#
#     Objective Function (sum): NPV [ ]
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# ..                                ...
# 95                                NaN
# 96                                NaN
# 97                                NaN
# 98                                NaN
# 99                                NaN
#
# [100 rows x 6 columns]

# %% [markdown]
# #### Get P# script table by 'Name'

# %%
psharp_script_table_names
# Out:
# ['Production/Injection',
#  'Reservoir Data',
#  'Depth Data',
#  'String Data',
#  'Time String Data',
#  'Mixed Data',
#  'Objective Function']

# %%
# execute P# script as table by name
psharp_script_table_by_name1 = pv_api.load_psharp_table(psharp_script_name,
                                                        table = psharp_script_table_names[0])
psharp_script_table_by_name1
# Out:
#          Date    Entity       Alias  Oil [m3/d]   Gas [m3/d]  Water [m3/d]  \
# 0  2020-01-01  Well 001  First Well   65.965954  1391.476946           NaN
# 1  2020-01-01  Well 002        <NA>         NaN  1124.649063           NaN
# 2  2020-01-01  Well 003        <NA>         NaN  1059.649193           NaN
# 3  2020-01-01   Well 50        <NA>         NaN          NaN           NaN
# 4  2020-02-01  Well 001  First Well   48.839408  1154.037872           NaN
# ..        ...       ...         ...         ...          ...           ...
# 95 2021-12-01   Well 50        <NA>         NaN          NaN           NaN
# 96 2022-01-01  Well 001  First Well         NaN  1227.994198           NaN
# 97 2022-01-01  Well 002        <NA>         NaN  1148.961958           NaN
# 98 2022-01-01  Well 003        <NA>         NaN  1229.877342           NaN
# 99 2022-01-01   Well 50        <NA>         NaN          NaN           NaN
#
#     WCUT [ ]    GOR [ ]  Water Injection [m3/d]
# 0        NaN  44.126435                     NaN
# 1        NaN  39.643691                     NaN
# 2        NaN  54.060569                     NaN
# 3        NaN        NaN                     NaN
# 4        NaN  51.745135                     NaN
# ..       ...        ...                     ...
# 95       NaN        NaN                     NaN
# 96       NaN  46.822568                     NaN
# 97       NaN  53.092606                     NaN
# 98       NaN  46.921897                     NaN
# 99       NaN        NaN                     NaN
#
# [100 rows x 9 columns]

# %%
psharp_script_table_by_name2 = pv_api.load_psharp_table(psharp_script_name,
                                                        table = psharp_script_table_names[1])
psharp_script_table_by_name2
# Out:
#      Entity       Alias  Longitude [ ]  Latitude [ ]
# 0  Well 001  First Well              4             1
# 1  Well 002        <NA>              4             1
# 2  Well 003        <NA>              4             1
# 3   Well 50        <NA>              4             1

# %% [markdown]
# #### Get all P# script tables

# %%
# execute P# script and get all tables
psharp_script_tables = pv_api.load_psharp_table(psharp_script_name)
#psharp_script_tables = pv_api.load_psharp_table(psharp_script_name,load_full_table_info=True)

# %%
for table_name, df in psharp_script_tables.items():
    print(f"Table: '{table_name}'")
    print(f"{list(df.columns)}")
    print('\n')
# Out:
# Table: 'Production/Injection'
# ['Date', 'Entity', 'Oil [m3/d]', 'Gas [m3/d]', 'Water [m3/d]', 'GOR [ ]']
#
#
# Table: 'Reservoir Data'
# ['Date', 'Entity', 'Longitude [ ]', 'Latitude [ ]']
#
#
# Table: 'Depth Data'
# ['Date', 'Depth', 'Entity', 'x0 [ ]', 'x0 depth [ ]', 'x1 depth [ ]']
#
#
# Table: 'String Data'
# ['Date', 'Entity', 'static string [ ]']
#
#
# Table: 'Time String Data'
# ['Date', 'Entity', 'time string [ ]']
#
#
# Table: 'Mixed Data'
# ['Date', 'Depth', 'Entity', 'static column [ ]', 'time column [m3/d]', 'depth column [ ]', 'string column [ ]']
#
#
# Table: 'Objective Function'
# ['Date', 'Entity', 'Iteration [ ]', 'Constraint (>=): VRR [ ]', 'Objective Function (sum): NPV [ ]']

# %%
for table_name, df in psharp_script_tables.items():
# 87  2021-01-01   Well 50            1.0                       NaN                                NaN
# 88  2021-02-01   Well 50            1.0                       NaN                                NaN
# 89  2021-03-01   Well 50            1.0                       NaN                                NaN
# 90  2021-04-01   Well 50            1.0                       NaN                                NaN
# 91  2021-05-01   Well 50            1.0                       NaN                                NaN
# 92  2021-06-01   Well 50            1.0                       NaN                                NaN
# 93  2021-07-01   Well 50            1.0                       NaN                                NaN
# 94  2021-08-01   Well 50            1.0                       NaN                                NaN
# 95  2021-09-01   Well 50            1.0                       NaN                                NaN
# 96  2021-10-01   Well 50            1.0                       NaN                                NaN
# 97  2021-11-01   Well 50            1.0                       NaN                                NaN
# 98  2021-12-01   Well 50            1.0                       NaN                                NaN
# 99  2022-01-01   Well 50            1.0                       NaN                                NaN
# 100 2020-12-01  Well 001            NaN               1431.118913                                NaN
# 101 2021-01-01  Well 001            NaN               1888.957717                                NaN
# 102 2020-12-01  Well 002            NaN                753.275855                                NaN
# 103 2021-01-01  Well 002            NaN                431.118700                                NaN
# 104 2021-02-01  Well 002            NaN                362.018950                                NaN
# 105 2020-12-01  Well 003            NaN               1233.371048                                NaN
# 106 2021-01-01  Well 003            NaN               2196.971884                                NaN
# 107 2020-12-01  Well 001            NaN                       NaN                           0.215416
# 108 2021-01-01  Well 001            NaN                       NaN                           0.141178
# 109 2020-12-01  Well 002            NaN                       NaN                           0.211082
# 110 2021-01-01  Well 002            NaN                       NaN                           0.207086
# 111 2021-02-01  Well 002            NaN                       NaN                           0.203915
# 112 2020-12-01  Well 003            NaN                       NaN                           0.193028
# 113 2021-01-01  Well 003            NaN                       NaN                           0.055076

# %%
for table_name, df in psharp_script_tables.items():
    print(f"Table: '{table_name}'")
    print(f"{df.info()}")
    print('\n')
# Out:
# Table: 'Production/Injection'
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 168 entries, 0 to 167
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          168 non-null    datetime64[ns]
#  1   Entity        168 non-null    string
#  2   Oil [m3/d]    11 non-null     float64
#  3   Gas [m3/d]    75 non-null     float64
#  4   Water [m3/d]  7 non-null      float64
#  5   GOR [ ]       75 non-null     float64
# dtypes: datetime64[ns](1), float64(4), string(1)
# memory usage: 9.2 KB
# None
#
#
# Table: 'Reservoir Data'
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8 entries, 0 to 7
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           8 non-null      datetime64[ns]
#  1   Entity         8 non-null      string
#  2   Longitude [ ]  4 non-null      float64
#  3   Latitude [ ]   4 non-null      float64
# dtypes: datetime64[ns](1), float64(2), string(1)
# memory usage: 320.0 bytes
# None
#
#
# Table: 'Depth Data'
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 108 entries, 0 to 107
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          100 non-null    datetime64[ns]
#  1   Depth         8 non-null      float64
#  2   Entity        108 non-null    string
#  3   x0 [ ]        100 non-null    float64
#  4   x0 depth [ ]  4 non-null      float64
#  5   x1 depth [ ]  4 non-null      float64
# dtypes: datetime64[ns](1), float64(4), string(1)
# memory usage: 5.9 KB
# None
#
#
# Table: 'String Data'
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               4 non-null      datetime64[ns]
#  1   Entity             4 non-null      string
#  2   static string [ ]  4 non-null      string
# dtypes: datetime64[ns](1), string(2)
# memory usage: 128.0 bytes
# None
#
#
# Table: 'Time String Data'
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9 entries, 0 to 8
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             9 non-null      datetime64[ns]
#  1   Entity           9 non-null      string
#  2   time string [ ]  9 non-null      string
# dtypes: datetime64[ns](1), string(2)
# memory usage: 288.0 bytes
# None
#
#
# Table: 'Mixed Data'
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 215 entries, 0 to 214
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                211 non-null    datetime64[ns]
#  1   Depth               4 non-null      float64
#  2   Entity              215 non-null    string
#  3   static column [ ]   100 non-null    float64
#  4   time column [m3/d]  11 non-null     float64
#  5   depth column [ ]    4 non-null      float64
#  6   string column [ ]   100 non-null    string
# dtypes: datetime64[ns](1), float64(4), string(2)
# memory usage: 13.4 KB
# None
#
#
# Table: 'Objective Function'
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 114 entries, 0 to 113
# Data columns (total 5 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Date                               114 non-null    datetime64[ns]
#  1   Entity                             114 non-null    string
#  2   Iteration [ ]                      100 non-null    float64
#  3   Constraint (>=): VRR [ ]           7 non-null      float64
#  4   Objective Function (sum): NPV [ ]  7 non-null      float64
# dtypes: datetime64[ns](1), float64(3), string(1)
# memory usage: 5.3 KB
# None

# %% [markdown]
# #### Save DataFrame columns data to corresponsing signals

# %%
psharp_script_table_names
# Out:
# ['Production/Injection',
#  'Reservoir Data',
#  'Depth Data',
#  'String Data',
#  'Time String Data',
#  'Mixed Data',
#  'Objective Function']

# %%
# Use 'signals' argument for mapping 'column' name to 'signal' names
# If 'signals' are None or empty {}, then it assumes that column name = signal name
# Any time when cannot find signal with corresponsing name, the saving is not perfomed

# %%
# save 'Time' signals
table_name = psharp_script_table_names[0]
print(f"Table: '{table_name}'")
print(list(psharp_script_tables[table_name].columns))
pv_api.save_table_data(psharp_script_tables[table_name],
                       signals={'Oil': 'oil production rate'})
# Out:
# Table: 'Production/Injection'
# ['Date', 'Entity', 'Oil [m3/d]', 'Gas [m3/d]', 'Water [m3/d]', 'GOR [ ]']

# %%
signal_name = 'Gas'
pv_api.get(f'Signals/{signal_name}')

# %%
# save 'Static' signals
table_name = psharp_script_table_names[0]
print(f"Table: '{table_name}'")
print(list(psharp_script_tables[table_name].columns))
pv_api.save_table_data(psharp_script_tables[table_name],
                       signals={'Longitude': 'Longitude'})
# Out:
# Table: 'Production/Injection'
# ['Date', 'Entity', 'Oil [m3/d]', 'Gas [m3/d]', 'Water [m3/d]', 'GOR [ ]']

# %%
# save 'Depth' signals
table_name = psharp_script_table_names[0]
print(f"Table: '{table_name}'")
print(list(psharp_script_tables[table_name].columns))
pv_api.save_table_data(psharp_script_tables[table_name],
                       signals={'x0 depth': 'op x0 depth'})
# Out:
# Table: 'Production/Injection'
# ['Date', 'Entity', 'Oil [m3/d]', 'Gas [m3/d]', 'Water [m3/d]', 'GOR [ ]']

# %%
# save 'String' signals
table_name = psharp_script_table_names[0]
print(f"Table: '{table_name}'")
print(list(psharp_script_tables[table_name].columns))
pv_api.save_table_data(psharp_script_tables[table_name],
                       signals={'string': 'static string'})
# Out:
# Table: 'Production/Injection'
# ['Date', 'Entity', 'Oil [m3/d]', 'Gas [m3/d]', 'Water [m3/d]', 'GOR [ ]']

# %%
# save 'StringTime' signals
table_name = psharp_script_table_names[0]
print(psharp_script_tables[table_name].columns)
pv_api.save_table_data(psharp_script_tables[table_name],
                       signals={'time string': 'time string'})
# Out:
# Index(['Date', 'Entity', 'Oil [m3/d]', 'Gas [m3/d]', 'Water [m3/d]',
#        'GOR [ ]'],
#       dtype='object')
