# %%
import petrovisor as pv

# %% [markdown]
# # Authorization

# %%
# url
# discovery_url = r'https://identity.eu1.petrovisor.com'
discovery_url = r'https://identity.us1.petrovisor.com'

# workspace
workspace = 'Workspace Name'

# generate access key (only for the first time, comment the line afterwards)
key = pv.PetroVisor.generate_credentials_key()
# print(f"key : '{key}'")
# save key for later to reuse
# key = ''

pv_api = pv.PetroVisor(workspace = workspace, discovery_url = discovery_url, key = key)
print(pv_api.Api)

# %% [markdown]
# # PetroVisor API Swagger

# %% [markdown]
# https://api.eu1.petrovisor.com/index.html

# %% [markdown]
# https://api.us1.petrovisor.com/index.html

# %% [markdown]
# # Examples: Data Items
# ### 'Entity', 'EntitySet', 'Scope', 'Context', 'Signal', 'Workflow', etc.

# %%
# get list of know item types
pv_api.get_item_types()
# Out:
# ['Unit',
#  'UnitMeasurement',
#  'Entity',
#  'EntityType',
#  'Signal',
#  'ConfigurationSettingValue',
#  'ConfigurationSettings',
#  'Tag',
#  'ProcessTemplate',
#  'MessageEntry',
#  'Ticket',
#  'UserSetting',
#  'CustomWorkflowActivity',
#  'WebWorkflowActivity',
#  'EventSubscription',
#  'WorkspacePackage',
#  'Hierarchy',
#  'Scope',
#  'EntitySet',
#  'Context',
#  'TableCalculation',
#  'EventCalculation',
#  'CleansingCalculation',
#  'Plot',
#  'PSharpScript',
#  'CleansingScript',
#  'WorkflowSchedule',
#  'RWorkflowActivity',
#  'Workflow',
#  'FilterDefinition',
#  'Filter',
#  'DCA',
#  'ChartDefinition',
#  'Chart',
#  'VoronoiGrid',
#  'GeoDataGrid',
#  'Polygon',
#  'PivotTableDefinition',
#  'PivotTable',
#  'DataIntegrationSet',
#  'ReferenceTableDefinition',
#  'ReferenceTable',
#  'PowerBIItem',
#  'MachineLearningModel',
#  'MLModel',
#  'DataGrid',
#  'DataGridSet',
#  'DataConnection',
#  'DataSource',
#  'Scenario',
#  'DataIntegrationSession']

# %%
# get entity names
item_names = pv_api.get_item_names('Entity')
item_names
# Out:
# ['_this is an entity with a super long name to check if bug 11469 is fixed or not',
#  '01043200070000',
#  '01043200080000',
#  '01107203040000',
#  '01107203060000',
#  '01107203100000',
#  '01107203110000',
#  '01M-037',
#  '01M-038',
#  '01M-039',
#  '01M-085',
#  '01M-232',
#  '01M-312',
#  '02M-098',
#  '02M-101',
#  '02M-338',
#  '02M-339',
#  '03M-141',
#  '03M-143',
#  '03M-146',
#  '03M-147',
#  '03M-148',
#  '03M-243',
#  '03M-353',
#  '03M-361',
#  '04030038990000',
#  '04030039000000',
#  '04030058810000',
#  '04030114530000',
#  '04030114580000',
#  '04030150650000',
#  '04030177290000',
#  '04030177300000',
#  '04030224480000',
#  '04030264760000',
#  '04030297800000',
#  '04030337540000',
#  '04030381550000',
#  '04030391570000',
#  '04030400380000',
#  '04030411920000',
#  '04030411950000',
#  '04030416160000',
#  '04030429770000',
#  '04030429780000',
#  '04030429790000',
#  '04030441600000',
#  '04030441650000',
#  '04030463290000',
#  '04030463360000',
#  '04030464340000',
#  '04030491490000',
#  '04030499910000',
#  '04M-105',
#  '04M-128',
#  '04M-129',
#  '04M-248',
#  '04M-335',
#  '04M-336',
#  '05055060900000',
#  '05055060910000',
#  '05055060920000',
#  '05055060940000',
#  '05055061080000',
#  '05055061120000',
#  '05055061130000',
#  '05073067740000',
#  '05073067760000',
#  '05073067770000',
#  '05073067780000',
#  '05075090730000',
#  '05075090740000',
#  '05087076470000',
#  '05087076480000',
#  '05087077940000',
#  '05087078150000',
#  '05087078170000',
#  '05121062440000',
#  '05121097570000',
#  '05121099070000',
#  '05121099430000',
#  '05121099440000',
#  '05121099550000',
#  '05121100150000',
#  '05121101230000',
#  '05123102770000',
#  '05123104860000',
#  '05123104870000',
#  '05123106060000',
#  '05123114420000',
#  '05123119450000',
#  '05123119460000',
#  '05123131140000',
#  '07 RANCH 14 #4',
#  '07 RANCH 2 #1',
#  '07 RANCH 23 #3',
#  '07 RANCH 26 #1',
#  '07 RANCH 26 #2',
#  '07 RANCH 35 #5',
#  '12TH MAN 660 #1H',
#  '12TH MAN 660 #1W',
#  '12TH MAN 660 #1WR',
#  '12TH MAN 660 #2H',
#  '12TH MAN 660 #2W',
#  '12TH MAN 660 A #1XH',
#  '15007239780000',
#  '15007239790000',
#  '15007239790100',
#  '15007239830100',
#  '15007239960000',
#  '15007239960001',
#  '15007239960100',
#  '15007240020000',
#  '15025215570000',
#  '15033216490100',
#  '15033216490101',
#  '15033216500100',
#  '15033216510100',
#  '15033216630100',
#  '15033216640100',
#  '15033216830100',
#  '15039208440000',
#  '15051246170000',
#  '15057208580000',
#  '15057208610100',
#  '15065200090000',
#  '15065200090001',
#  '15065200870000',
#  '15065302120000',
#  '15065302120001',
#  '15083218270100',
#  '15083218280100',
#  '15083218300000',
#  '15083218350000',
#  '15083218360100',
#  '15083218390000',
#  '15083218490000',
#  '15083218500100',
#  '15083218540100',
#  '15095222540000',
#  '15095222550100',
#  '15097217310100',
#  '15097217320100',
#  '15097217330100',
#  '15145212870000',
#  '15151218820000',
#  '15151218820001',
#  '15151219160000',
#  '15167064540000',
#  '15167064540001',
#  '15167064540002',
#  '15167064550000',
#  '15167193760000',
#  '15167194690000',
#  '15167228970000',
#  '15167700540000',
#  '15185225940000',
#  '16001011810000',
#  '16045003220000',
#  '16045003820000',
#  '16051002750000',
#  '16051011120000',
#  '16053051820000',
#  '16053053850000',
#  '16121000180000',
#  '16121000190000',
#  '16121000200000',
#  '16121005410000',
#  '16121009770000',
#  '16121009780000',
#  '16121009860000',
#  '16121009870000',
#  '16121009880000',
#  '16121010060000',
#  '16121010820000',
#  '16153002550000',
#  '16153005840000',
#  '16153005910000',
#  '16153005920000',
#  '16153024570000',
#  '16153024580000',
#  '16153024650000',
#  '16153024820000',
#  '16153024830000',
#  '16153024840000',
#  '16199004010000',
#  '16207000140000',
#  '16207010630000',
#  '16207010690000',
#  '16207010760000',
#  '16207010770000',
#  '16207011010000',
#  '16207011820000',
#  '16207012620000',
#  '16207012630000',
#  '16207012640000',
#  '16207013320000',
#  '16207013740000',
#  '17003003090000',
#  '17013000110000',
#  '17013000140000',
#  '17013000180000',
#  '17013000200000',
#  '17013000220000',
#  '17013000540000',
#  '17013000610000',
#  '17013001010000',
#  '17013001020000',
#  '17013001040000',
#  '17013001060000',
#  '17013001270000',
#  '17013001300000',
#  '17013001510000',
#  '17013001610000',
#  '17013001720000',
#  '17013001830000',
#  '17013002420000',
#  '17013002500000',
#  '17013002930000',
#  '17013002940000',
#  '17013002950000',
#  '17013004990000',
#  '17013006070000',
#  '17013200110000',
#  '17013200190000',
#  '17013200240000',
#  '17013200270000',
#  '17013200330000',
#  '17013200400000',
#  '17013200410000',
#  '17013200470000',
#  '17013200620000',
#  '17013200990000',
#  '17013201040000',
#  '17013201130000',
#  '17013201150000',
#  '17013201170000',
#  '17013201230000',
#  '17013201250000',
#  '17013201420000',
#  '17013201580000',
#  '17013201590000',
#  '17013201660000',
#  '17013201700000',
#  '17013201760000',
#  '17013201860000',
#  '17013201910000',
#  '17013202010000',
#  '17013202020000',
#  '17013202060000',
#  '17013202090000',
#  '17013202200000',
#  '17013202360000',
#  '17013202370000',
#  '17013202480000',
#  '17013202510000',
#  '17013202570000',
#  '17013203050000',
#  '17013203420000',
#  '17013203540000',
#  '17013204100000',
#  '17013204180000',
#  '17013204220000',
#  '17013204610000',
#  '17013204660000',
#  '17013204780000',
#  '17013205030000',
#  '17013205100000',
#  '17013205110000',
#  '17013205120000',
#  '17013205180000',
#  '17013205210000',
#  '17013205250000',
#  '17013205260000',
#  '17013205270000',
#  '17013205280000',
#  '17013205290000',
#  '17013205310000',
#  '17013205360000',
#  '17013205380000',
#  '17013205460000',
#  '17013205490000',
#  '17013205500000',
#  '17013205510000',
#  '17013205660000',
#  '17013205700000',
#  '17013205710000',
#  '17013205750000',
#  '17013205980000',
#  '17013206010000',
#  '17013206070000',
#  '17013206100000',
#  '17013206250000',
#  '17013206280000',
#  '17013206300000',
#  '17013206330000',
#  '17013206370000',
#  '17013206380000',
#  '17013206420000',
#  '17013206450000',
#  '17013206470000',
#  '17013206500000',
#  '17013206520000',
#  '17013206550000',
#  '17013206580000',
#  '17013206640000',
#  '17013206650000',
#  '17013206690000',
#  '17013206770000',
#  '17013206800000',
#  '17013206820000',
#  '17013206840000',
#  '17013206850000',
#  '17013206880000',
#  '17013206890000',
#  '17013206900000',
#  '17013206910000',
#  '17013206950000',
#  '17013206990000',
#  '17013207000000',
#  '17013207010000',
#  '17013207060000',
#  '17013207070000',
#  '17013207120000',
#  '17013207140000',
#  '17013207180000',
#  '17013207190000',
#  '17013207230000',
#  '17013207260000',
#  '17013207270000',
#  '17013207290000',
#  '17013207330000',
#  '17013207360000',
#  '17013207370000',
#  '17013207400000',
#  '17013207420000',
#  '17013207440000',
#  '17013207600000',
#  '17013207680000',
#  '17013207720000',
#  '17013207840000',
#  '17013207880000',
#  '17013207900000',
#  '17013207910000',
#  '17013207920000',
#  '17013207930000',
#  '17013207940000',
#  '17013207970000',
#  '17013208010000',
#  '17013208030000',
#  '17013208040000',
#  '17013208060000',
#  '17013208070000',
#  '17013208080000',
#  '17013208120000',
#  '17013208130000',
#  '17013208140000',
#  '17013208150000',
#  '17013208200000',
#  '17013208210000',
#  '17013208220000',
#  '17013208240000',
#  '17013208310000',
#  '17013208350000',
#  '17013208380000',
#  '17013208390000',
#  '17013208420000',
#  '17013208430000',
#  '17013208440000',
#  '17013208470000',
#  '17013208480000',
#  '17013208490000',
#  '17013208500000',
#  '17013208530000',
#  '17013208540000',
#  '17013208550000',
#  '17013208600000',
#  '17013208610000',
#  '17013208620000',
#  '17013208640000',
#  '17013208690000',
#  '17013208700000',
#  '17013208720000',
#  '17013208740000',
#  '17013208760000',
#  '17013208820000',
#  '17013208830000',
#  '17013208850000',
#  '17013208860000',
#  '17013208910000',
#  '17013208930000',
#  '17013208950000',
#  '17013208990000',
#  '17013209000000',
#  '17013209030000',
#  '17013209040000',
#  '17013209050000',
#  '17013209070000',
#  '17013209120000',
#  '17013209140000',
#  '17013209150000',
#  '17013209170000',
#  '17013209180000',
#  '17013209240000',
#  '17013209250000',
#  '17013209260000',
#  '17013209270000',
#  '17013209280000',
#  '17013209310000',
#  '17013209320000',
#  '17013209330000',
#  '17013209350000',
#  '17013209370000',
#  '17013209380000',
#  '17013209390000',
#  '17013209400000',
#  '17013209420000',
#  '17013209430000',
#  '17013209450000',
#  '17013209460000',
#  '17013209470000',
#  '17013209480000',
#  '17013209500000',
#  '17013209520000',
#  '17013209530000',
#  '17013209550000',
#  '17013209560000',
#  '17013209590000',
#  '17013209600000',
#  '17013209610000',
#  '17013209620000',
#  '17013209630000',
#  '17013209640000',
#  '17013209660000',
#  '17013209670000',
#  '17013209680000',
#  '17013209690000',
#  '17013209710000',
#  '17013209750000',
#  '17013209770000',
#  '17013209780000',
#  '17013209800000',
#  '17013209820000',
#  '17013209830000',
#  '17013209850000',
#  '17013209880000',
#  '17013209890000',
#  '17013209900000',
#  '17013209920000',
#  '17013209930000',
#  '17013209940000',
#  '17013209970000',
#  '17013210010000',
#  '17013210030000',
#  '17013210040000',
#  '17013210050000',
#  '17013210090000',
#  '17013210110000',
#  '17013210120000',
#  '17013210130000',
#  '17013210140000',
#  '17013210150000',
#  '17013210160000',
#  '17013210180000',
#  '17013210190000',
#  '17013210200000',
#  '17013210230000',
#  '17013210240000',
#  '17013210250000',
#  '17013210260000',
#  '17013210270000',
#  '17013210290000',
#  '17013210300000',
#  '17013210310000',
#  '17013210330000',
#  '17013210340000',
#  '17013210350000',
#  '17013210410000',
#  '17013210450000',
#  '17013210460000',
#  '17013210480000',
#  '17013210510000',
#  '17013210530000',
#  '17013210540000',
#  '17013210570000',
#  '17013210590000',
#  '17013210610000',
#  '17013210620000',
#  '17013210630000',
#  '17013210640000',
#  '17013210650000',
#  '17013210660000',
#  '17013210680000',
#  '17013210690000',
#  '17013210700000',
#  '17013210710000',
#  '17013210750000',
#  '17013210780000',
#  '17013210800000',
#  '17013210810000',
#  '17013210860000',
#  '17013210870000',
#  '17013210880000',
#  '17013210890000',
#  '17013210900000',
#  '17013210910000',
#  '17013210940000',
#  '17013210990000',
#  '17013211000000',
#  '17013211010000',
#  '17013211020000',
#  '17013211040000',
#  '17013211050000',
#  '17013211150000',
#  '17013211180000',
#  '17013211190000',
#  '17013211200000',
#  '17013211220000',
#  '17013211240000',
#  '17013211250000',
#  '17013211260000',
#  '17013211280000',
#  '17013211290000',
#  '17013211300000',
#  '17013211310000',
#  '17013211320000',
#  '17013211330000',
#  '17013211350000',
#  '17013211370000',
#  '17013211410000',
#  '17013211450000',
#  '17013211460000',
#  '17013211470000',
#  '17013211540000',
#  '17013211550000',
#  '17013211620000',
#  '17013211630000',
#  '17013211640000',
#  '17013211660000',
#  '17013211670000',
#  '17013211700000',
#  '17013211730000',
#  '17013211770000',
#  '17013211790000',
#  '17013211800000',
#  '17013211810000',
#  '17013211820000',
#  '17013211850000',
#  '17013211880000',
#  '17013211900000',
#  '17013211930000',
#  '17013211950000',
#  '17013211970000',
#  '17013212000000',
#  '17013212010000',
#  '17013212020000',
#  '17013212080000',
#  '17013212090000',
#  '17013212100000',
#  '17013212170000',
#  '17013212180000',
#  '17013212200000',
#  '17013212250000',
#  '17013212270000',
#  '17013212350000',
#  '17013212380000',
#  '17013212420000',
#  '17013212440000',
#  '17013212460000',
#  '17013212470000',
#  '17013212480000',
#  '17013212500000',
#  '17013212510000',
#  '17013212520000',
#  '17013212530000',
#  '17013212540000',
#  '17013212600000',
#  '17013212610000',
#  '17013212620000',
#  '17013212630000',
#  '17013212640000',
#  '17013212650000',
#  '17013212670000',
#  '17013212680000',
#  '17013212740000',
#  '17013212750000',
#  '17013212770000',
#  '17013212810000',
#  '17013212830000',
#  '17013212890000',
#  '17013212900000',
#  '17013212950000',
#  '17013212960000',
#  '17013212970000',
#  '17013213000000',
#  '17013213020000',
#  '17013213060000',
#  '17013213080000',
#  '17013213090000',
#  '17013213100000',
#  '17013213110000',
#  '17013213190000',
#  '17013213200000',
#  '17013213240000',
#  '17013213260000',
#  '17013213350000',
#  '17013213360000',
#  '17013213390000',
#  '17013213410000',
#  '17013213420000',
#  '17013213430000',
#  '17013213450000',
#  '17013213480000',
#  '17013213490000',
#  '17013213500000',
#  '17013213510000',
#  '17013213520000',
#  '17013213550000',
#  '17013213590000',
#  '17013213600000',
#  '17013213660000',
#  '17013213690000',
#  '17013213700000',
#  '17013213710000',
#  '17013213720000',
#  '17013213730000',
#  '17013213740000',
#  '17013213750000',
#  '17013213760000',
#  '17013213770000',
#  '17013213780000',
#  '17013213790000',
#  '17013213820000',
#  '17013213850000',
#  '17013213900000',
#  '17013214000000',
#  '17013214020000',
#  '17013214050000',
#  '17013214060000',
#  '17013214080000',
#  '17013214140000',
#  '17013214150000',
#  '17013214180000',
#  '17013214220000',
#  '17013214230000',
#  '17013214250000',
#  '17013214260000',
#  '17013214290000',
#  '17013214330000',
#  '17013214340000',
#  '17013214390000',
#  '17013214400000',
#  '17013214480000',
#  '17013214490000',
#  '17013214540000',
#  '17013214580000',
#  '17013214610000',
#  '17013214650000',
#  '17013214660000',
#  '17013214690000',
#  '17013214700000',
#  '17013214720000',
#  '17013214760000',
#  '17013214780000',
#  '17013214860000',
#  '17013214870000',
#  '17013214880000',
#  '17013214910000',
#  '17013214930000',
#  '17013214960000',
#  '17013214970000',
#  '17013215030000',
#  '17013215040000',
#  '17013215060000',
#  '17013215090000',
#  '17013215120000',
#  '17013215130000',
#  '17013215140000',
#  '17013215150000',
#  '17013215190000',
#  '17013215210000',
#  '17013215250000',
#  '17013215270000',
#  '17013215290000',
#  '17013215300000',
#  '17013215330000',
#  '17013215400000',
#  '17013215410000',
#  '17013215420000',
#  '17013215440000',
#  '17013215460000',
#  '17013215470000',
#  '17013215520000',
#  '17013215530000',
#  '17013215600000',
#  '17013215620000',
#  '17013215650000',
#  '17013215660000',
#  '17013215680000',
#  '17013215690000',
#  '17013215730000',
#  '17013215740000',
#  '17013215750000',
#  '17013215780000',
#  '17013215800000',
#  '17013215840000',
#  '17013215880000',
#  '17013215890000',
#  '17013215900000',
#  '17013215930000',
#  '17013215940000',
#  '17013215950000',
#  '17013215980000',
#  '17013215990000',
#  '17013216000000',
#  '17013216060000',
#  '17013216090000',
#  '17013216100000',
#  '17013216130000',
#  '17013216140000',
#  '17013216150000',
#  '17013216170000',
#  '17013216180000',
#  '17013216190000',
#  '17013216200000',
#  '17013216220000',
#  '17013216230000',
#  '17013216240000',
#  '17013216250000',
#  '17013216270000',
#  '17013216290000',
#  '17013216320000',
#  '17013216330000',
#  '17013216350000',
#  '17013216360000',
#  '17013216380000',
#  '17013216440000',
#  '17013216460000',
#  '17013216470000',
#  '17013216540000',
#  '17013216590000',
#  '17013216600000',
#  '17013216690000',
#  '17013216700000',
#  '17013216720000',
#  '17013216760000',
#  '17013216790000',
#  '17013216800000',
#  '17013216910000',
#  '17013216920000',
#  '17013217020000',
#  '17013217030000',
#  '17013217090000',
#  '17013217100000',
#  '17013217110000',
#  '17013217120000',
#  '17013217130000',
#  '17013217210000',
#  '17013217220000',
#  '17013217230000',
#  '17013217240000',
#  '17013217250000',
#  '17013217270000',
#  '17013217280000',
#  '17013217350000',
#  '17013217400000',
#  '17013217430000',
#  '17013217450000',
#  '17013217480000',
#  '17013217500000',
#  '17013217520000',
#  '17013217530000',
#  '17013217550000',
#  '17013217570000',
#  '17013217580000',
#  '17013217590000',
#  '17013217600000',
#  '17013217610000',
#  '17013217630000',
#  '17013217640000',
#  '17013217670000',
#  '17013217680000',
#  '17013217720000',
#  '17013217740000',
#  '17013217750000',
#  '17013217810000',
#  '17013217840000',
#  '17013217900000',
#  '17013217910000',
#  '17013217920000',
#  '17013217950000',
#  '17013217960000',
#  '17013217970000',
#  '17013217980000',
#  '17013217990000',
#  '17013218130000',
#  '17013218160000',
#  '17013218250000',
#  '17013218320000',
#  '17013218330000',
#  '17013218560000',
#  '17013218570000',
#  '17013218580000',
#  '17013218740000',
#  '17013218810000',
#  '17013218830000',
#  '17013218840000',
#  '17013218850000',
#  '17013218870000',
#  '17013218890000',
#  '17013218910000',
#  '17013218920000',
#  '17013219010000',
#  '17013219030000',
#  '17013219060000',
#  '17013219110000',
#  '17013219150000',
#  '17013219210000',
#  '17013219220000',
#  '17013219320000',
#  '17013219330000',
#  '17013219360000',
#  '17013219390000',
#  '17013219510000',
#  '17013219540000',
#  '17013219610000',
#  '17013219650000',
#  '17013219670000',
#  '17013219720000',
#  '17013219730000',
#  '17013219770000',
#  '17013219830000',
#  '17013219870000',
#  '17013219880000',
#  '17013219980000',
#  '17013220690000',
#  '17013221440000',
#  '17013221490000',
#  '17013221500000',
#  '17013221510000',
#  '17013221520000',
#  '17013221530000',
#  '17013221540000',
#  '17013221550000',
#  '17013221630000',
#  '17013221640000',
#  '17013221650000',
#  '17013221700000',
#  '17013221710000',
#  '17027008150000',
#  '17027219790000',
#  '17027223040000',
#  '17027225680000',
#  '17027225830000',
#  '17041201800000',
#  '17061208030000',
#  '17061209200000',
#  '17061209400000',
#  '17061211030000',
#  '17061211640000',
#  '17061211860000',
#  '17061212440000',
#  '17061212520000',
#  '17061212590000',
#  '17061212600000',
#  '17061212780000',
#  '17061212800000',
#  '17061212950000',
#  '17061213070000',
#  '17061213130000',
#  '17061213250000',
#  '17061213520000',
#  '17061213630000',
#  '17061213640000',
#  '17061213650000',
#  '17061213850000',
#  '17061213860000',
#  '17061213870000',
#  '17061213970000',
#  '17061214060000',
#  '17061214070000',
#  '17061214150000',
#  '17061214160000',
#  '17061214260000',
#  '17061214270000',
#  '17061214340000',
#  '17061880180000',
#  '17061880190000',
#  '17065200890000',
#  '17085218650000',
#  '17119007000000',
#  '17119015040000',
#  '17119015270000',
#  '17119015290000',
#  '17119015300000',
#  '17119015320000',
#  '17119015560000',
#  '17119200850000',
#  '17119200920000',
#  '17119200930000',
#  '17119200990000',
#  '17119201480000',
#  '17119201560000',
#  '17119201620000',
#  '17119201700000',
#  '17119201880000',
#  '17119201960000',
#  '17119202130000',
#  '17119202330000',
#  '17119202390000',
#  '17119202570000',
#  '17119202730000',
#  '17119202920000',
#  '17119203230000',
#  '17119203440000',
#  '17119203450000',
#  '17119209950000',
#  '17119210330000',
#  '17119211520000',
#  '17119211540000',
#  '17119211690000',
#  '17119212610000',
#  '17119213390000',
#  '17119213770000',
#  '17119213790000',
#  '17119213940000',
#  '17119213960000',
#  '17119213970000',
#  '17119214000000',
#  '17119214170000',
#  '17119214200000',
#  '17119214560000',
#  '17119214620000',
#  '17119214640000',
#  '17119214940000',
#  '17119214960000',
#  '17119215040000',
#  '17119215120000',
#  '17119215130000',
#  '17119215160000',
#  '17119215220000',
#  '17119215250000',
#  '17119215270000',
#  '17119215320000',
#  '17119215410000',
#  '17119215450000',
#  '17119215480000',
#  '17119215590000',
#  '17119215820000',
#  '17119215830000',
#  '17119215860000',
#  '17119215900000',
#  '17119215910000',
#  '17119215970000',
#  '17119216000000',
#  '17119216070000',
#  '17119216080000',
#  '17119216160000',
#  '17119216250000',
#  '17119216260000',
#  '17119216270000',
#  '17119216280000',
#  '17119216290000',
#  '17119216340000',
#  '17119216440000',
#  '17119216500000',
#  '17119216530000',
#  '17119216560000',
#  '17119216570000',
#  '17119216620000',
#  '17119216630000',
#  '17119216640000',
#  '17119216650000',
#  '17119216670000',
#  '17119216690000',
#  '17119216700000',
#  '17119216710000',
#  '17119216730000',
#  '17119216820000',
#  '17119216840000',
#  '17119216880000',
#  '17119216910000',
#  '17119216920000',
#  '17119216930000',
#  '17119216990000',
#  '17119217010000',
#  '17119217020000',
#  '17119217030000',
#  '17119217120000',
#  '17119217160000',
#  '17119217170000',
#  '17119217210000',
#  '17119217260000',
#  '17119217320000',
#  '17119217330000',
#  '17119217480000',
#  '17119217580000',
#  '17119217590000',
#  '17119217600000',
#  '17119217690000',
#  ...]

# %% [markdown]
# #### Add or Edit Item

# %%
# add or edit item
name = 'Test Well'
pv_api.add_item('Entity', {
  'Name': name,
  'EntityTypeName': 'Well',
  'Alias': '',
  'IsOpportunity': False,
})
# Out:
# {'EntityTypeName': 'Well', 'Alias': '', 'Name': 'Test Well'}

# %% [markdown]
# #### Get Item

# %%
# get item
name = 'Test Well'
pv_api.get_item('Entity',name)
# Out:
# {'EntityTypeName': 'Well', 'Name': 'Test Well'}

# %% [markdown]
# #### Delete Item

# %%
# delete item
name = 'Test Well'
pv_api.delete_item('Entity',name)
# Out:
# <Response [200]>

# %% [markdown]
# #### Get Items

# %%
# get item names
pv_api.get_item_names('Signal')
# Out:
# ['__temp_col_flower',
#  '__temp_col_petal length',
#  '__temp_col_petal width',
#  '_this is a super long signal name, again to check if bug 11469 is fixed or not',
#  'abandonment cost',
#  'abc oil ratio',
#  'abc water ratio',
#  'absolute open flow potential',
#  'ad valorem tax',
#  'aggregated oil production 2 year',
#  'aggregated oil production 2 year predicted',
#  'allocated capital expenses per time increment',
#  'annulus pressure',
#  'average operating expense',
#  'average royalty',
#  'average working interest',
#  'azimuth angle',
#  'basic sediment and water',
#  'basin',
#  'basis for ngl yield',
#  'best three-month oil equivalent production rate',
#  'bottom hole flowing pressure',
#  'bottom hole pressure',
#  'bottom hole pressure decreasing trend threshold',
#  'bottom hole pressure increasing trend threshold',
#  'bottom hole pressure lower threshold',
#  'bottom hole pressure upper threshold',
#  'bottom hole temperature',
#  'bottom hole temperature decreasing trend threshold',
#  'bottom hole temperature increasing trend threshold',
#  'bottom hole temperature lower threshold',
#  'bottom hole temperature upper threshold',
#  'butane price offset',
#  'butane sales price',
#  'butane transportation cost',
#  'butane yield',
#  'capital cost',
#  'capital expense factor',
#  'cash flow per time increment',
#  'casing head pressure',
#  'casing inner diameter',
#  'Chan patterns',
#  'chan plot classification',
#  'choke downstream gas pressure',
#  'choke opening',
#  'choke size',
#  'choke upstream gas pressure',
#  'CO2 content',
#  'completed lateral length',
#  'compression hurdle',
#  'condensate butane content',
#  'condensate ethane content',
#  'condensate gas ratio',
#  'condensate methane content',
#  'condensate pentane+ content',
#  'condensate price offset',
#  'condensate production rate',
#  'condensate propane content',
#  'condensate sales price',
#  'condensate transportation cost',
#  'condensate variable operating expense',
#  'country',
#  'county',
#  'critical gas flow rate',
#  'critical gas velocity',
#  'cumulative cash flow',
#  'cumulative condensate production',
#  'cumulative gas injection',
#  'cumulative gas production',
#  'cumulative injection pressure',
#  'cumulative liquid production',
#  'cumulative oil production',
#  'cumulative test',
#  'cumulative time on production',
#  'cumulative water injection',
#  'cumulative water production',
#  'current operator',
#  'current operator test',
#  'date of first production',
#  'deferred gas per time increment',
#  'deferred oil per time increment',
#  'deferred production',
#  'deliquification foamers',
#  'deliquification plunger lift',
#  'deliquification velocity string',
#  'deliquification wellhead compression',
#  'development well fixed monthly operating expense',
#  'discharge coefficient',
#  'downhole condition probability',
#  'drainage area',
#  'drainage radius',
#  'drilling cost per completed lateral length',
#  'drilling cost per vertical depth',
#  'dynamic liquid level',
#  'dynamometer downhole',
#  'economic limit month',
#  'economical lifetime',
#  'economics producing month',
#  'economics well type',
#  'effective rate of return',
#  'entities scenario',
#  'erosion',
#  'estimated ultimate recovery condensate',
#  'estimated ultimate recovery gas',
#  'estimated ultimate recovery gas equivalent',
#  'estimated ultimate recovery oil',
#  'estimated ultimate recovery oil equivalent',
#  'estimated ultimate recovery water',
#  'ethane price offset',
#  'ethane sales price',
#  'ethane transportation cost',
#  'ethane yield',
#  'evaluation well fixed monthly operating expense',
#  'field',
#  'finding and development costs',
#  'First Principle Component',
#  'fixed completion cost',
#  'fixed drilling cost',
#  'fl class',
#  'fl class predicted',
#  'flat royalty rate',
#  'flooded compartment in time',
#  'flowdown code',
#  'flower',
#  'flower Response Surface ML Example t = 01/01/1992 12:25:00',
#  'flower_binary',
#  'flowmeter factor',
#  'flowmeter final reading',
#  'flowmeter initial reading',
#  'flowmeter volume change',
#  'flowrate',
#  'fluid formation volume factor',
#  'fluid intensity',
#  'fluid temperature',
#  'gas channeling probability',
#  'gas compressibility factor',
#  'gas conduit volume',
#  'gas decline rate liquid loading',
#  'gas density',
#  'gas formation volume factor',
#  'gas injection rate',
#  'gas lift valve inlet area',
#  'gas liquid ratio',
#  'gas oil ratio',
#  'gas oil ratio upper threshold',
#  'gas plant fuel shrink',
#  'gas plant process loss',
#  'gas plant total liquids volume',
#  'gas plant variable capital recovery expense',
#  'gas plant variable operating expense',
#  'gas price factor',
#  'gas price offset',
#  'gas production rate',
#  'gas sales price',
#  'gas severance tax',
#  'gas specific gravity',
#  'gas transportation cost',
#  'gas variable operating expense (post compression)',
#  'gas variable operating expense (pre compression)',
#  'gross abandonment costs per time increment',
#  'gross amount',
#  'gross effective royalty rate',
#  'gross income',
#  'gross operating expenses',
#  'gross production taxes',
#  'gross revenue',
#  'gross revenue condensate',
#  'gross revenue gas',
#  'gross revenue ngls',
#  'gross revenue oil',
#  'gross reversion balance',
#  'gross royalty payments',
#  'gross sales condensate volume',
#  'gross sales gas volume',
#  'gross sales oil volume',
#  'gross sales water volume',
#  'gross transportation costs',
#  'gross volume',
#  'H2S content',
#  'heterogeneity index gas',
#  'heterogeneity index liquid',
#  'heterogeneity index oil',
#  'heterogeneity index water',
#  'history cumulative test',
#  'history cumulative test overload',
#  'hub butane price fraction',
#  'hub condensate price fraction',
#  'hub ethane price fraction',
#  'hub gas price',
#  'hub oil price',
#  'hub pentane+ price fraction',
#  'hub propane price fraction',
#  'id',
#  'implied horizontal well spacing',
#  'inactive string category',
#  'inclination angle',
#  'inflation factor',
#  'initial oil saturation',
#  'injected gas per time increment',
#  'injected water per time increment',
#  'injection point depth',
#  'injection point fluid density',
#  'injection point lift gas density',
#  'injection point lift gas rate',
#  'injection point liquid production rate',
#  'injection point tubing pressure',
#  'injection port size',
#  'injection pressure',
#  'injectivity index',
#  'inspection date',
#  'latitude',
#  'lease',
#  'lift gas density',
#  'liquid above pump',
#  'liquid density',
#  'liquid loading prediction',
#  'liquid price factor',
#  'liquid production rate',
#  'liquid production rate estimated',
#  'longitude',
#  'max allowable water cut',
#  'measured depth',
#  'month',
#  'motor current',
#  'motor efficiency',
#  'motor frequency',
#  'motor overload',
#  'motor voltage',
#  'multi-well savings per well',
#  'MVR_B90_OilEq_boed',
#  'MVR_B90_OilEq_boed_pred_PV',
#  'MVR_B90_OilEq_boed_pred_R',
#  'MVR_BH_Lat',
#  'MVR_BH_Long',
#  'MVR_Fluid_Pumped_e6gal',
#  'MVR_Implied_HZ_Spacing_e3ft',
#  'MVR_Lateral_Length_e3ft',
#  'MVR_Record',
#  'MVR_TVD_e3ft',
#  'N2 content',
#  'net amount',
#  'net present value discount 1',
#  'net present value undiscounted',
#  'net revenue interest abandonment costs',
#  'net revenue interest capital costs',
#  'net revenue interest revenue',
#  'net revenue interest with reversion',
#  'net thickness',
#  'net volume',
#  'netback',
#  'normalized productivity index',
#  'null static',
#  'null static string',
#  'number of perforation clusters',
#  'number of perforation stages',
#  'number of stages',
#  'oil density',
#  'oil formation volume factor',
#  'oil gas ratio',
#  'oil price offset',
#  'oil production rate',
#  'oil sales price',
#  'oil saturation',
#  'oil severance tax',
#  'oil transportation cost',
#  'oil variable operating expense',
#  'one year netback',
#  'op dp',
#  'op dq',
#  'op p',
#  'op q',
#  'op x0',
#  'op x0 depth',
#  'op x0 depth max',
#  'op x0 depth min',
#  'op x0 max',
#  'op x0 min',
#  'op x0 time',
#  'op x0 time max',
#  'op x0 time min',
#  'op x1',
#  'op x1 depth',
#  'op x1 max',
#  'op x1 min',
#  'op x1 time',
#  'operating status',
#  'operator',
#  'Optimization Workflow final op x0',
#  'Optimization Workflow final op x0 depth',
#  'Optimization Workflow final op x0 time',
#  'Optimization Workflow final op x1',
#  'Optimization Workflow final op x1 depth',
#  'Optimization Workflow final op x1 time',
#  'Optimization Workflow initial op x0',
#  'Optimization Workflow initial op x0 depth',
#  'Optimization Workflow initial op x0 time',
#  'Optimization Workflow initial op x1',
#  'Optimization Workflow initial op x1 depth',
#  'Optimization Workflow initial op x1 time',
#  'orifice efficiency factor',
#  'orifice valve area',
#  'original oil in place',
#  'original operator',
#  'payout',
#  'payout multiple',
#  'pentane+ price offset',
#  'pentane+ sales price',
#  'pentane+ transportation cost',
#  'pentane+ yield',
#  'perforation bottom',
#  'perforation cluster spacing',
#  'perforation cost per cluster',
#  'perforation top',
#  'permeability',
#  'petal length',
#  'petal length Response Surface ML Example t = 01/01/1992 12:25:00',
#  'petal width',
#  'petal width Response Surface ML Example t = 01/01/1992 12:25:00',
#  'plunger diameter',
#  'plunger diameter smart',
#  'plunger stroke',
#  'plunger type',
#  'porosity',
#  'pressure datum',
#  'primary formation',
#  'primary phase',
#  'problem score',
#  'produced condensate per time increment',
#  'produced condensate per time increment forecast',
#  'produced gas per time increment',
#  'produced gas per time increment forecast',
#  'produced liquid per time increment',
#  'produced oil per time increment',
#  'produced oil per time increment forecast',
#  'produced water per time increment',
#  'produced water per time increment forecast',
#  'production impact',
#  'production score',
#  'productivity index',
#  'propane price offset',
#  'propane sales price',
#  'propane transportation cost',
#  'propane yield',
#  'proppant cost',
#  'proppant intensity',
#  'pump curve',
#  'pump downhole condition',
#  'pump downhole condition (enumerated)',
#  'pump efficiency',
#  'pump factor',
#  'pump fillage',
#  'pump frequency',
#  'pump intake pressure',
#  'pump model',
#  'pump off point',
#  'pump outlet pressure',
#  'pump setting depth',
#  'reason of change',
#  'reconciled oil per time increment',
#  'reconciled water per time increment',
#  'recovery factor',
#  'recycle ratio',
#  'remarks',
#  'reservoir area',
#  'reservoir pressure',
#  'reservoir temperature',
#  'response surface',
#  'response surface point',
#  'reversion month',
#  'rod density',
#  'rod diameter',
#  'rod elasticity',
#  'rod friction coefficient',
#  'rod stress',
#  'rod viscosity',
#  'sales gas heat value',
#  'sand problem probability',
#  'sand production rate',
#  'Second Principle Component',
#  'sepal length',
#  'sepal width',
#  'separator pressure',
#  'shut-in class',
#  'shut-in score',
#  'shuting duration',
#  'skin',
#  'smoothed derivative water oil ratio',
#  'smoothed water oil ratio',
#  'stage plug cost per stage',
#  'stage spacing',
#  'start of production offset for development wells',
#  'start of production offset for evaluation wells',
#  'start of production offset for rework wells',
#  'state',
#  'static string',
#  'static string test',
#  'stimulation fluid cost',
#  'subsurface x-coordinate',
#  'subsurface y-coordinate',
#  'surface card',
#  'surface tension water',
#  'surface x-coordinate',
#  'surface y-coordinate',
#  'target gas production per time increment',
#  'target gas production rate',
#  'target oil production per time increment',
#  'target oil production rate',
#  'target water injection per time increment',
#  'target water injection rate',
#  'temporal feature 1',
#  'temporal feature 1 time',
#  'temporal feature 2',
#  'temporal feature 2 time',
#  'temporal feature 3',
#  'temporal feature 3 time',
#  'temporal feature 4',
#  'temporal feature 4 time',
#  'theoretical liquid rate',
#  'third principle component',
#  'time on injection',
#  'time on production',
#  'time string',
#  'total proppant injected',
#  'total stimulation fluid injected',
#  'total true vertical depth',
#  'true vertical depth',
#  'tubing inner diameter',
#  'tubing outer diameter',
#  'tubing volume downstream of gas injection point',
#  'tubing_pressure',
#  'upstream gas temperature',
#  'vfm liquid production rate',
#  'voidage replacement ratio',
#  'warning index',
#  'water channeling probability',
#  'water coning probability',
#  'water cut',
#  'water cut upper threshold',
#  'water density',
#  'water gas ratio',
#  'water injection rate',
#  'water oil ratio',
#  'water oil ratio smoothed',
#  'water production rate',
#  'water salinity',
#  'water saturation',
#  'water variable operating expense',
#  'well head pressure',
#  'well head pressure decreasing trend threshold',
#  'well head pressure increasing trend threshold',
#  'well head pressure lower threshold',
#  'well head pressure upper threshold',
#  'well head temperature',
#  'well name',
#  'well name static',
#  'well status',
#  'well test bottomhole pressure',
#  'well test bottomhole pressure measured',
#  'well test gas rate',
#  'well test indicator',
#  'well test oil contribution factor',
#  'well test oil contribution multiplication factor',
#  'well test oil production rate measured',
#  'well test oil rate',
#  'well test produced gas per time increment',
#  'well test produced liquid per time increment',
#  'well test produced oil per time increment',
#  'well test produced water per time increment',
#  'well test uptime',
#  'well test uptime contribution factor',
#  'well test water contribution factor',
#  'well test water contribution multiplication factor',
#  'well test water cut',
#  'well test water rate',
#  'well type',
#  'well type static',
#  'wellbore profile',
#  'wellbore radius',
#  'working interest after payout',
#  'working interest after reversion',
#  'working interest before payout',
#  'working interest before reversion',
#  'working interest condensate volume',
#  'working interest cumulative income',
#  'working interest gas volume',
#  'working interest income',
#  'working interest liquid volume',
#  'working interest oil volume',
#  'working interest operating expenses',
#  'working interest production taxes',
#  'working interest reserves condensate',
#  'working interest reserves equivalent',
#  'working interest reserves gas',
#  'working interest reserves liquid',
#  'working interest reserves oil',
#  'working interest revenue',
#  'working interest royalty payments',
#  'working interest transportation costs',
#  'working interest water volume',
#  'working interest with reversion',
#  'year of first production']

# %%
# get items
pv_api.get_items('Signal')
# Out:
# [{'ShortName': '__temp_col_flower',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': ' ',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'DepthDependent',
#   'DefaultLineType': 'Solid',
#   'Labels': ['Jessica Next'],
#   'Name': '__temp_col_flower'},
#  {'ShortName': '__temp_col_petal l',
#   'MeasurementName': 'Length',
#   'StorageUnitName': 'cm',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'DepthDependent',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': '__temp_col_petal length'},
#  {'ShortName': '__temp_col_petal w',
#   'MeasurementName': 'Length',
#   'StorageUnitName': 'cm',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'DepthDependent',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': '__temp_col_petal width'},
#  {'ShortName': 's',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': ' ',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'Static',
#   'DefaultLineType': 'Solid',
#   'SettingName': 'Months',
#   'Labels': [],
#   'Name': '_this is a super long signal name, again to check if bug 11469 is fixed or not'},
#  {'ShortName': 'abandonment cost',
#   'MeasurementName': 'Currency',
#   'StorageUnitName': 'EUR',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'Static',
#   'DefaultLineType': 'Solid',
#   'Description': 'Total cost to plug and abandon a well',
#   'Labels': ['Economics', 'Wells Management Dashboard'],
#   'Name': 'abandonment cost'},
#  {'ShortName': 'ABC Oil Ratio',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': '%',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'Static',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'abc oil ratio'},
#  {'ShortName': 'ABC Water Ratio',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': ' ',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'abc water ratio'},
#  {'ShortName': 'aof',
#   'MeasurementName': 'Flowrate',
#   'StorageUnitName': 'bbl/d',
#   'AggregationType': 'Average',
#   'ContainerAggregationType': 'Average',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'absolute open flow potential'},
#  {'ShortName': 'ad valorem tax',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': ' ',
#   'AggregationType': 'Average',
#   'ContainerAggregationType': 'Average',
#   'SignalType': 'Static',
#   'DefaultLineType': 'Solid',
#   'Description': 'Ad valorem tax rate',
#   'Labels': ['Economics', 'Wells Management Dashboard'],
#   'Name': 'ad valorem tax'},
#  {'ShortName': 'agg qo 2 y',
#   'MeasurementName': 'Volume',
#   'StorageUnitName': 'STB',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'aggregated oil production 2 year'},
#  {'ShortName': 'aggr qo 2 y pred',
#   'MeasurementName': 'Volume',
#   'StorageUnitName': 'STB',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'aggregated oil production 2 year predicted'},
#  {'ShortName': 'allocated capex',
#   'MeasurementName': 'Currency',
#   'StorageUnitName': 'EUR',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Description': 'Capital expenses paid or expected to be paid per time increment',
#   'Labels': ['Economics'],
#   'Name': 'allocated capital expenses per time increment'},
#  {'ShortName': 'ann press',
#   'MeasurementName': 'Pressure',
#   'StorageUnitName': 'bar',
#   'AggregationType': 'Average',
#   'ContainerAggregationType': 'Average',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'annulus pressure'},
#  {'ShortName': 'avg opex',
#   'MeasurementName': 'CurrencyPerVolume',
#   'StorageUnitName': 'EUR/m3',
#   'AggregationType': 'Average',
#   'ContainerAggregationType': 'Average',
#   'SignalType': 'Static',
#   'DefaultLineType': 'Solid',
#   'Description': 'Average operating cost of a well or collection of wells for one time increment',
#   'Labels': ['Economics'],
#   'Name': 'average operating expense'},
#  {'ShortName': 'avg royalty',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': ' ',
#   'AggregationType': 'Average',
#   'ContainerAggregationType': 'Average',
#   'SignalType': 'Static',
#   'DefaultLineType': 'Solid',
#   'Description': 'Average royalty rate for a well or a collection of wells. This value is calculated in the Economics package based on royalty rates and any reversion conditions.',
#   'Labels': ['Economics'],
#   'Name': 'average royalty'},
#  {'ShortName': 'avg wi',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': ' ',
#   'AggregationType': 'Average',
#   'ContainerAggregationType': 'Average',
#   'SignalType': 'Static',
#   'DefaultLineType': 'Solid',
#   'Description': 'Average working interest for a well or a collection of wells over the economical lifetime. Takes into account changes in working interest to reversion conditions.',
#   'Labels': ['Economics', 'Production and Completion Dashboards'],
#   'Name': 'average working interest'},
#  {'ShortName': 'azimuth',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': ' ',
#   'AggregationType': 'Average',
#   'ContainerAggregationType': 'Average',
#   'SignalType': 'DepthDependent',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'azimuth angle'},
#  {'ShortName': 'bsw',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': '%',
#   'AggregationType': 'Average',
#   'ContainerAggregationType': 'Average',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'basic sediment and water'},
#  {'ShortName': 'basin',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': ' ',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Count',
#   'SignalType': 'String',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'basin'},
#  {'ShortName': 'basis for ngl yield',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': ' ',
#   'AggregationType': 'Min',
#   'ContainerAggregationType': 'Min',
#   'SignalType': 'Static',
#   'DefaultLineType': 'Solid',
#   'Description': 'Flag that indicates how NGL yield will be handled in the Economics package scripts: 1 = Raw Gas, 2 = Gas - Fuel, 3 = Gas - Fuel - Shrink',
#   'Labels': ['Economics', 'Wells Management Dashboard'],
#   'Name': 'basis for ngl yield'},
#  {'ShortName': 'b3oil equivalent',
#   'MeasurementName': 'Flowrate',
#   'StorageUnitName': 'm3/d',
#   'AggregationType': 'Average',
#   'ContainerAggregationType': 'Average',
#   'SignalType': 'Static',
#   'DefaultLineType': 'Solid',
#   'Description': 'Maximum value of the three-month moving average of the oil-equivalent production rate',
#   'Labels': ['Completion Optimization',
#    'Production and Completion Dashboards',
#    'Production KPIs',
#    'Type Curve Builder'],
#   'Name': 'best three-month oil equivalent production rate'},
#  {'ShortName': 'BHFP',
#   'MeasurementName': 'Pressure',
#   'StorageUnitName': 'Pa',
#   'AggregationType': 'Average',
#   'ContainerAggregationType': 'Average',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'bottom hole flowing pressure'},
#  {'ShortName': 'bhp',
#   'MeasurementName': 'Pressure',
#   'StorageUnitName': 'bar',
#   'AggregationType': 'Average',
#   'ContainerAggregationType': 'Average',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'bottom hole pressure'},
#  {'ShortName': 'bhp dec thld',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': ' ',
#   'AggregationType': 'Average',
#   'ContainerAggregationType': 'Average',
#   'SignalType': 'Static',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'bottom hole pressure decreasing trend threshold'},
#  {'ShortName': 'bhp inc thld',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': ' ',
#   'AggregationType': 'Average',
#   'ContainerAggregationType': 'Average',
#   'SignalType': 'Static',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'bottom hole pressure increasing trend threshold'},
#  {'ShortName': 'bhp lower thld',
#   'MeasurementName': 'Pressure',
#   'StorageUnitName': 'bar',
#   'AggregationType': 'Average',
#   'ContainerAggregationType': 'Max',
#   'SignalType': 'Static',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'bottom hole pressure lower threshold'},
#  {'ShortName': 'bhp upper thld',
#   'MeasurementName': 'Pressure',
#   'StorageUnitName': 'bar',
#   'AggregationType': 'Average',
#   'ContainerAggregationType': 'Min',
#   'SignalType': 'Static',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'bottom hole pressure upper threshold'},
#  {'ShortName': 'bht',
#   'MeasurementName': 'Temperature',
#   'StorageUnitName': 'degC',
#   'AggregationType': 'Average',
#   'ContainerAggregationType': 'Average',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'bottom hole temperature'},
#  {'ShortName': 'bht dec thld',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': ' ',
#   'AggregationType': 'Average',
#   'ContainerAggregationType': 'Average',
#   'SignalType': 'Static',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'bottom hole temperature decreasing trend threshold'},
#  {'ShortName': 'bht inc thld',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': ' ',
#   'AggregationType': 'Average',
#   'ContainerAggregationType': 'Average',
#   'SignalType': 'Static',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'bottom hole temperature increasing trend threshold'},
#  {'ShortName': 'bht lower thld',
#   'MeasurementName': 'Temperature',
#   'StorageUnitName': 'degC',
#   'AggregationType': 'Average',
#   'ContainerAggregationType': 'Max',
#   'SignalType': 'Static',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'bottom hole temperature lower threshold'},
#  {'ShortName': 'bht upper thld',
#   'MeasurementName': 'Temperature',
#   'StorageUnitName': 'degC',
#   'AggregationType': 'Average',
#   'ContainerAggregationType': 'Min',
#   'SignalType': 'Static',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'bottom hole temperature upper threshold'},
#  {'ShortName': 'butane price offset',
#   'MeasurementName': 'CurrencyPerVolume',
#   'StorageUnitName': 'EUR/m3',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'Static',
#   'DefaultLineType': 'Solid',
#   'Description': 'Offset to be added or subtracted from the final commodity sales price due to transportation from the plant to the hub',
#   'Labels': ['Economics', 'Wells Management Dashboard'],
#   'Name': 'butane price offset'},
#  {'ShortName': 'butane sales price',
#   'MeasurementName': 'CurrencyPerVolume',
#   'StorageUnitName': 'EUR/m3',
#   'AggregationType': 'Average',
#   'ContainerAggregationType': 'Average',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Description': 'Final sales price of the commodity after accounting for price offset, liquid price factor, and inflation. Calculated in the "Economics Price Forecast Calculations" script.',
#   'Labels': ['Economics', 'Wells Management Dashboard'],
#   'Name': 'butane sales price'},
#  {'ShortName': 'butane transportation cost',
#   'MeasurementName': 'CurrencyPerVolume',
#   'StorageUnitName': 'EUR/m3',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'Static',
#   'DefaultLineType': 'Solid',
#   'Description': 'Per-volume cost to transport the commodity',
#   'Labels': ['Economics', 'Wells Management Dashboard'],
#   'Name': 'butane transportation cost'},
#  {'ShortName': 'butane yield',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': ' ',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'Static',
#   'DefaultLineType': 'Solid',
#   'Description': 'Yield from a gas plant of volume of butane (C4) per volume of gas',
#   'Labels': ['Economics', 'Wells Management Dashboard'],
#   'Name': 'butane yield'},
#  {'ShortName': 'capital cost',
#   'MeasurementName': 'Currency',
#   'StorageUnitName': 'EUR',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'Static',
#   'DefaultLineType': 'Solid',
#   'Description': 'Total capital cost for a well',
#   'Labels': ['Completion Optimization',
#    'Economics',
#    'Wells Management Dashboard'],
#   'Name': 'capital cost'},
#  {'ShortName': 'capex fct',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': ' ',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'Static',
#   'DefaultLineType': 'Solid',
#   'Description': 'Multiplier for capital expenses (including abandonment costs). Will default to 1.0 in Economics workflow if signal is left blank.',
#   'Labels': ['Economics', 'Wells Management Dashboard'],
#   'Name': 'capital expense factor'},
#  {'ShortName': 'cfpti',
#   'MeasurementName': 'Currency',
#   'StorageUnitName': 'EUR',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Description': 'Working interest share of cash flow (revenues - expenses - capital costs - P&A costs) per time increment',
#   'Labels': ['Economics'],
#   'Name': 'cash flow per time increment'},
#  {'ShortName': 'chp',
#   'MeasurementName': 'Pressure',
#   'StorageUnitName': 'bar',
#   'AggregationType': 'Average',
#   'ContainerAggregationType': 'Average',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'casing head pressure'},
#  {'ShortName': 'casing id',
#   'MeasurementName': 'Length',
#   'StorageUnitName': 'in',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'Static',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'casing inner diameter'},
#  {'ShortName': 'Chan patterns',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': ' ',
#   'AggregationType': 'Average',
#   'ContainerAggregationType': 'Average',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'Chan patterns'},
#  {'ShortName': 'chan plot classification',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': ' ',
#   'AggregationType': 'Average',
#   'ContainerAggregationType': 'Average',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'chan plot classification'},
#  {'ShortName': 'choke downstr gas p',
#   'MeasurementName': 'Pressure',
#   'StorageUnitName': 'psi',
#   'AggregationType': 'Average',
#   'ContainerAggregationType': 'Average',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'choke downstream gas pressure'},
#  {'ShortName': 'choke opening',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': ' ',
#   'AggregationType': 'Average',
#   'ContainerAggregationType': 'Average',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'choke opening'},
#  {'ShortName': 'choke size',
#   'MeasurementName': 'Length',
#   'StorageUnitName': 'mm',
#   'AggregationType': 'Average',
#   'ContainerAggregationType': 'Average',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'choke size'},
#  {'ShortName': 'choke upstr gas p',
#   'MeasurementName': 'Pressure',
#   'StorageUnitName': 'psi',
#   'AggregationType': 'Average',
#   'ContainerAggregationType': 'Average',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'choke upstream gas pressure'},
#  {'ShortName': 'CO2 content',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': '%',
#   'AggregationType': 'Average',
#   'ContainerAggregationType': 'Average',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'CO2 content'},
#  {'ShortName': 'lat len',
#   'MeasurementName': 'Length',
#   'StorageUnitName': 'm',
#   'AggregationType': 'Average',
#   'ContainerAggregationType': 'Max',
#   'SignalType': 'Static',
#   'DefaultLineType': 'Solid',
#   'Description': 'Completed lateral length of a well',
#   'Labels': ['Completion Optimization',
#    'Production and Completion Dashboards',
#    'Reactivation And Shut-In Dashboard',
#    'Voronoi'],
#   'Name': 'completed lateral length'},
#  {'ShortName': 'compression hurdle',
#   'MeasurementName': 'Flowrate',
#   'StorageUnitName': 'm3/d',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'Static',
#   'DefaultLineType': 'Solid',
#   'Description': 'Gas plant compression hurdle rate. Used to determine whether pre-compression or post-compression variable expense will be used in Economics workflow.',
#   'Labels': ['Economics'],
#   'Name': 'compression hurdle'},
#  {'ShortName': 'condensate butane content',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': ' ',
#   'AggregationType': 'Average',
#   'ContainerAggregationType': 'Average',
#   'SignalType': 'Static',
#   'DefaultLineType': 'Solid',
#   'Description': 'Yield of butane (C4) coming out of the wellsite condensate going through the gas plant condensate stabilization process',
#   'Labels': ['Economics', 'Wells Management Dashboard'],
#   'Name': 'condensate butane content'},
#  {'ShortName': 'condensate ethane content',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': ' ',
#   'AggregationType': 'Average',
#   'ContainerAggregationType': 'Average',
#   'SignalType': 'Static',
#   'DefaultLineType': 'Solid',
#   'Description': 'Yield of ethane (C2) coming out of the wellsite condensate going through the gas plant condensate stabilization process',
#   'Labels': ['Economics', 'Wells Management Dashboard'],
#   'Name': 'condensate ethane content'},
#  {'ShortName': 'cgr',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': '%',
#   'AggregationType': 'Average',
#   'ContainerAggregationType': 'Average',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Description': 'Ratio of the volume of produced condensate to the volume of produced gas at standard conditions',
#   'Labels': ['Basic'],
#   'Name': 'condensate gas ratio'},
#  {'ShortName': 'condensate methane content',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': ' ',
#   'AggregationType': 'Average',
#   'ContainerAggregationType': 'Average',
#   'SignalType': 'Static',
#   'DefaultLineType': 'Solid',
#   'Description': 'Yield of methane (C1) coming out of the wellsite condensate going through the gas plant condensate stabilization process',
#   'Labels': ['Economics', 'Wells Management Dashboard'],
#   'Name': 'condensate methane content'},
#  {'ShortName': 'condensate pentane+ content',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': ' ',
#   'AggregationType': 'Average',
#   'ContainerAggregationType': 'Average',
#   'SignalType': 'Static',
#   'DefaultLineType': 'Solid',
#   'Description': 'Yield of pentane+ (C5+) coming out of the wellsite condensate going through the gas plant condensate stabilization process',
#   'Labels': ['Economics', 'Wells Management Dashboard'],
#   'Name': 'condensate pentane+ content'},
#  {'ShortName': 'condensate price offset',
#   'MeasurementName': 'CurrencyPerVolume',
#   'StorageUnitName': 'EUR/m3',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'Static',
#   'DefaultLineType': 'Solid',
#   'Description': 'Offset to be added or subtracted from the final commodity sales price due to transportation from the plant to the hub',
#   'Labels': ['Economics', 'Wells Management Dashboard'],
#   'Name': 'condensate price offset'},
#  {'ShortName': 'condensate rate',
#   'MeasurementName': 'Flowrate',
#   'StorageUnitName': 'm3/h',
#   'AggregationType': 'Average',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Description': 'Rate at which an entity is producing condensate',
#   'Labels': ['Basic', 'Production Forecast (DCA)', 'Production KPIs'],
#   'Name': 'condensate production rate'},
#  {'ShortName': 'condensate propane content',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': ' ',
#   'AggregationType': 'Average',
#   'ContainerAggregationType': 'Average',
#   'SignalType': 'Static',
#   'DefaultLineType': 'Solid',
#   'Description': 'Yield of propane (C3) coming out of the wellsite condensate going through the gas plant condensate stabilization process',
#   'Labels': ['Economics', 'Wells Management Dashboard'],
#   'Name': 'condensate propane content'},
#  {'ShortName': 'condensate sales price',
#   'MeasurementName': 'CurrencyPerVolume',
#   'StorageUnitName': 'EUR/m3',
#   'AggregationType': 'Average',
#   'ContainerAggregationType': 'Average',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Description': 'The final sales price of the commodity after accounting for price offset, liquid price factor, and inflation. Calculated in the "Economics Price Forecast Calculations" script.',
#   'Labels': ['Economics', 'Wells Management Dashboard'],
#   'Name': 'condensate sales price'},
#  {'ShortName': 'condensate transportation cost',
#   'MeasurementName': 'CurrencyPerVolume',
#   'StorageUnitName': 'EUR/m3',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'Static',
#   'DefaultLineType': 'Solid',
#   'Description': 'Cost per volume to transport condensate from the wellhead to the plant',
#   'Labels': ['Economics'],
#   'Name': 'condensate transportation cost'},
#  {'ShortName': 'condensate var opex',
#   'MeasurementName': 'CurrencyPerVolume',
#   'StorageUnitName': 'EUR/m3',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'Static',
#   'DefaultLineType': 'Solid',
#   'Description': 'Cost per volume to process condensate at the plant',
#   'Labels': ['Economics'],
#   'Name': 'condensate variable operating expense'},
#  {'ShortName': 'country',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': ' ',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Count',
#   'SignalType': 'String',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'country'},
#  {'ShortName': 'county',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': ' ',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Mode',
#   'SignalType': 'String',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'county'},
#  {'ShortName': 'critical gas rate',
#   'MeasurementName': 'Flowrate',
#   'StorageUnitName': 'm3/d',
#   'AggregationType': 'Average',
#   'ContainerAggregationType': 'Average',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'critical gas flow rate'},
#  {'ShortName': 'critical gas velocity',
#   'MeasurementName': 'Velocity',
#   'StorageUnitName': 'm/h',
#   'AggregationType': 'Average',
#   'ContainerAggregationType': 'Average',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'critical gas velocity'},
#  {'ShortName': 'cumul cash flow',
#   'MeasurementName': 'Currency',
#   'StorageUnitName': 'EUR',
#   'AggregationType': 'Last',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Description': 'Working interest portion of the accumulated cash flow per time increment',
#   'Labels': ['Economics'],
#   'Name': 'cumulative cash flow'},
#  {'ShortName': 'cum condensate prod',
#   'MeasurementName': 'Volume',
#   'StorageUnitName': 'm3',
#   'AggregationType': 'Last',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Description': 'Volume of condensate that has been produced throughout the lifetime of an entity',
#   'Labels': ['Basic', 'Production Forecast (DCA)'],
#   'Name': 'cumulative condensate production'},
#  {'ShortName': 'cum gas inj',
#   'MeasurementName': 'Volume',
#   'StorageUnitName': 'm3',
#   'AggregationType': 'Last',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Description': 'Volume of gas that has been injected throughout the lifetime of an entity',
#   'Labels': ['Basic'],
#   'Name': 'cumulative gas injection'},
#  {'ShortName': 'cum gas prod',
#   'MeasurementName': 'Volume',
#   'StorageUnitName': 'm3',
#   'AggregationType': 'Last',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Description': 'Volume of gas that has been produced throughout the lifetime of an entity',
#   'Labels': ['Basic',
#    'Entity Scores',
#    'Production Forecast (DCA)',
#    'Sucker Rod Pump Monitoring'],
#   'Name': 'cumulative gas production'},
#  {'ShortName': 'cum inj press',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': ' ',
#   'AggregationType': 'Average',
#   'ContainerAggregationType': 'Average',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'cumulative injection pressure'},
#  {'ShortName': 'cum liquid prod',
#   'MeasurementName': 'Volume',
#   'StorageUnitName': 'm3',
#   'AggregationType': 'Last',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Description': 'Volume of liquid that has been produced throughout the lifetime of an entity',
#   'Labels': ['Basic', 'Sucker Rod Pump Monitoring'],
#   'Name': 'cumulative liquid production'},
#  {'ShortName': 'cum oil prod',
#   'MeasurementName': 'Volume',
#   'StorageUnitName': 'm3',
#   'AggregationType': 'Last',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Description': 'Volume of oil that has been produced throughout the lifetime of an entity',
#   'Labels': ['Basic',
#    'Entity Scores',
#    'Production Forecast (DCA)',
#    'Reactivation And Shut-In Dashboard',
#    'Sucker Rod Pump Monitoring'],
#   'Name': 'cumulative oil production'},
#  {'ShortName': 'cum test',
#   'MeasurementName': 'Volume',
#   'StorageUnitName': 'm3',
#   'AggregationType': 'Last',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'cumulative test'},
#  {'ShortName': 'cum uptime',
#   'MeasurementName': 'Time',
#   'StorageUnitName': 'd',
#   'AggregationType': 'Last',
#   'ContainerAggregationType': 'Average',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Description': 'Total time throughout the lifetime of an entity it spent producing',
#   'Labels': ['Basic',
#    'Entity Scores',
#    'Reactivation And Shut-In Dashboard',
#    'Sucker Rod Pump Monitoring'],
#   'Name': 'cumulative time on production'},
#  {'ShortName': 'cum water inj',
#   'MeasurementName': 'Volume',
#   'StorageUnitName': 'm3',
#   'AggregationType': 'Last',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Description': 'Volume of water that has been injected throughout the lifetime of an entity',
#   'Labels': ['Basic'],
#   'Name': 'cumulative water injection'},
#  {'ShortName': 'cum water prod',
#   'MeasurementName': 'Volume',
#   'StorageUnitName': 'm3',
#   'AggregationType': 'Last',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Description': 'Volume of water that has been produced throughout the lifetime of an entity',
#   'Labels': ['Basic',
#    'Production Forecast (DCA)',
#    'Sucker Rod Pump Monitoring'],
#   'Name': 'cumulative water production'},
#  {'ShortName': 'current operator',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': ' ',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Count',
#   'SignalType': 'String',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'current operator'},
#  {'ShortName': 'current op',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': ' ',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'StringTimeDependent',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'current operator test'},
#  {'ShortName': 'DOFP',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': ' ',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'String',
#   'DefaultLineType': 'Solid',
#   'Description': 'Date an entity started producing',
#   'Labels': ['Economics',
#    'Production KPIs',
#    'Production and Completion Dashboards'],
#   'Name': 'date of first production'},
#  {'ShortName': 'dgpti',
#   'MeasurementName': 'Volume',
#   'StorageUnitName': 'm3',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Description': 'Volume of gas lost due to scheduled or unscheduled repairs and maintenance or poor performance',
#   'Labels': ['Downtime Monitoring'],
#   'Name': 'deferred gas per time increment'},
#  {'ShortName': 'dopti',
#   'MeasurementName': 'Volume',
#   'StorageUnitName': 'm3',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Description': 'Volume of oil lost due to scheduled or unscheduled repairs and maintenance or poor performance',
#   'Labels': ['Downtime Monitoring'],
#   'Name': 'deferred oil per time increment'},
#  {'ShortName': 'def prod',
#   'MeasurementName': 'Volume',
#   'StorageUnitName': 'm3',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'deferred production'},
#  {'ShortName': 'deliquification foamers',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': ' ',
#   'AggregationType': 'Average',
#   'ContainerAggregationType': 'Average',
#   'SignalType': 'Static',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'deliquification foamers'},
#  {'ShortName': 'deliquification plunger lift',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': ' ',
#   'AggregationType': 'Average',
#   'ContainerAggregationType': 'Average',
#   'SignalType': 'Static',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'deliquification plunger lift'},
#  {'ShortName': 'deliquification velocity strin',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': ' ',
#   'AggregationType': 'Average',
#   'ContainerAggregationType': 'Average',
#   'SignalType': 'Static',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'deliquification velocity string'},
#  {'ShortName': 'deliquification wellhead compr',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': ' ',
#   'AggregationType': 'Average',
#   'ContainerAggregationType': 'Average',
#   'SignalType': 'Static',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'deliquification wellhead compression'},
#  {'ShortName': 'dev well fixed monthly opex',
#   'MeasurementName': 'Currency',
#   'StorageUnitName': 'EUR',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'Static',
#   'DefaultLineType': 'Solid',
#   'Description': 'Fixed monthly costs to operate a development well',
#   'Labels': ['Economics'],
#   'Name': 'development well fixed monthly operating expense'},
#  {'ShortName': 'discharge coeff',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': ' ',
#   'AggregationType': 'Average',
#   'ContainerAggregationType': 'Average',
#   'SignalType': 'Static',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'discharge coefficient'},
#  {'ShortName': 'DHP',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': ' ',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'downhole condition probability'},
#  {'ShortName': 'drainage area',
#   'MeasurementName': 'Area',
#   'StorageUnitName': 'm2',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'Static',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'drainage area'},
#  {'ShortName': 'drainage radius',
#   'MeasurementName': 'Length',
#   'StorageUnitName': 'm',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'Static',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'drainage radius'},
#  {'ShortName': 'lateral cost',
#   'MeasurementName': 'CurrencyPerLength',
#   'StorageUnitName': 'EUR/m',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Average',
#   'SignalType': 'Static',
#   'DefaultLineType': 'Solid',
#   'Description': 'Drilling cost per completed lateral length. Used to determine total capital cost for a completion design.',
#   'Labels': ['Completion Optimization'],
#   'Name': 'drilling cost per completed lateral length'},
#  {'ShortName': 'vertical depth cost',
#   'MeasurementName': 'CurrencyPerLength',
#   'StorageUnitName': 'EUR/m',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Average',
#   'SignalType': 'Static',
#   'DefaultLineType': 'Solid',
#   'Description': 'Drilling cost per vertical depth. Used to determine total capital cost for a completion design.',
#   'Labels': ['Completion Optimization'],
#   'Name': 'drilling cost per vertical depth'},
#  {'ShortName': 'dynamic liquid level',
#   'MeasurementName': 'Length',
#   'StorageUnitName': 'm',
#   'AggregationType': 'Average',
#   'ContainerAggregationType': 'Average',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'dynamic liquid level'},
#  {'ShortName': 'dynamometer downhole',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': ' ',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'StringTimeDependent',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'dynamometer downhole'},
#  {'ShortName': 'economic limit month',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': ' ',
#   'AggregationType': 'Average',
#   'ContainerAggregationType': 'Average',
#   'SignalType': 'Static',
#   'DefaultLineType': 'Solid',
#   'Description': 'Month at which a well becomes un-economic (relative to the EconomicsEffectiveDate)',
#   'Labels': ['Economics'],
#   'Name': 'economic limit month'},
#  {'ShortName': 'economical lifetime',
#   'MeasurementName': 'Time',
#   'StorageUnitName': 'h',
#   'AggregationType': 'Average',
#   'ContainerAggregationType': 'Average',
#   'SignalType': 'Static',
#   'DefaultLineType': 'Solid',
#   'Description': 'Total length of time over which a well is expected to be economic according to the cash flow calculations',
#   'Labels': ['Economics'],
#   'Name': 'economical lifetime'},
#  {'ShortName': 'prod month',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': ' ',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Description': "Number of months since an entity's Date of First Production (DOFP)",
#   'Labels': ['Economics'],
#   'Name': 'economics producing month'},
#  {'ShortName': 'economics well type',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': ' ',
#   'AggregationType': 'Min',
#   'ContainerAggregationType': 'Min',
#   'SignalType': 'Static',
#   'DefaultLineType': 'Solid',
#   'Description': 'Numeric flag to specify the type of well: 0 = Existing, 1 = Evaluation, 2 = Development, 3 = Rework, 4 = Farm-in Evaluation, 5 = Farm-in Development',
#   'Labels': ['Completion Optimization', 'Economics'],
#   'Name': 'economics well type'},
#  {'ShortName': 'effective ror',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': ' ',
#   'AggregationType': 'Average',
#   'ContainerAggregationType': 'Average',
#   'SignalType': 'Static',
#   'DefaultLineType': 'Solid',
#   'Description': 'Effective rate of return based on the calculated cash flows',
#   'Labels': ['Completion Optimization', 'Economics'],
#   'Name': 'effective rate of return'},
#  {'ShortName': 'entities scenario',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': ' ',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'String',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'entities scenario'},
#  {'ShortName': 'erosion',
#   'MeasurementName': 'Length',
#   'StorageUnitName': 'um',
#   'AggregationType': 'Average',
#   'ContainerAggregationType': 'Average',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'erosion'},
#  {'ShortName': 'eur condensate',
#   'MeasurementName': 'Volume',
#   'StorageUnitName': 'm3',
#   'AggregationType': 'Max',
#   'ContainerAggregationType': 'Average',
#   'SignalType': 'Static',
#   'DefaultLineType': 'Solid',
#   'Description': 'Total estimated quantity of recoverable condensate',
#   'Labels': ['Estimated Ultimate Recovery',
#    'Production and Completion Dashboards',
#    'Wells Management Dashboard'],
#   'Name': 'estimated ultimate recovery condensate'},
#  {'ShortName': 'eur gas',
#   'MeasurementName': 'Volume',
#   'StorageUnitName': 'm3',
#   'AggregationType': 'Max',
#   'ContainerAggregationType': 'Average',
#   'SignalType': 'Static',
#   'DefaultLineType': 'Solid',
#   'Description': 'Total estimated quantity of recoverable gas',
#   'Labels': ['Estimated Ultimate Recovery',
#    'Production and Completion Dashboards',
#    'Wells Management Dashboard'],
#   'Name': 'estimated ultimate recovery gas'},
#  {'ShortName': 'eur gas equivalent',
#   'MeasurementName': 'Volume',
#   'StorageUnitName': 'm3',
#   'AggregationType': 'Max',
#   'ContainerAggregationType': 'Average',
#   'SignalType': 'Static',
#   'DefaultLineType': 'Solid',
#   'Description': 'Total estimated quantity of recoverable gas equivalent',
#   'Labels': ['Estimated Ultimate Recovery',
#    'Production and Completion Dashboards'],
#   'Name': 'estimated ultimate recovery gas equivalent'},
#  {'ShortName': 'eur oil',
#   'MeasurementName': 'Volume',
#   'StorageUnitName': 'm3',
#   'AggregationType': 'Max',
#   'ContainerAggregationType': 'Average',
#   'SignalType': 'Static',
#   'DefaultLineType': 'Solid',
#   'Description': 'Total estimated quantity of recoverable oil',
#   'Labels': ['Estimated Ultimate Recovery',
#    'Production and Completion Dashboards',
#    'Wells Management Dashboard'],
#   'Name': 'estimated ultimate recovery oil'},
#  {'ShortName': 'eur oil equivalent',
#   'MeasurementName': 'Volume',
#   'StorageUnitName': 'm3',
#   'AggregationType': 'Max',
#   'ContainerAggregationType': 'Average',
#   'SignalType': 'Static',
#   'DefaultLineType': 'Solid',
#   'Description': 'Total estimated quantity of recoverable oil equivalent',
#   'Labels': ['Completion Optimization',
#    'Estimated Ultimate Recovery',
#    'Production and Completion Dashboards'],
#   'Name': 'estimated ultimate recovery oil equivalent'},
#  {'ShortName': 'eur water',
#   'MeasurementName': 'Volume',
#   'StorageUnitName': 'm3',
#   'AggregationType': 'Max',
#   'ContainerAggregationType': 'Average',
#   'SignalType': 'Static',
#   'DefaultLineType': 'Solid',
#   'Description': 'Total estimated quantity of recoverable water',
#   'Labels': ['Estimated Ultimate Recovery',
#    'Production and Completion Dashboards',
#    'Wells Management Dashboard'],
#   'Name': 'estimated ultimate recovery water'},
#  {'ShortName': 'ethane price offset',
#   'MeasurementName': 'CurrencyPerVolume',
#   'StorageUnitName': 'EUR/m3',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'Static',
#   'DefaultLineType': 'Solid',
#   'Description': 'Offset to be added or subtracted from the final commodity sales price due to transportation from the plant to the hub',
#   'Labels': ['Economics'],
#   'Name': 'ethane price offset'},
#  {'ShortName': 'ethane sales price',
#   'MeasurementName': 'CurrencyPerVolume',
#   'StorageUnitName': 'EUR/m3',
#   'AggregationType': 'Average',
#   'ContainerAggregationType': 'Average',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Description': 'Final sales price of the commodity after accounting for price offset, liquid price factor, and inflation. Calculated in the "Economics Price Forecast Calculations" script.',
#   'Labels': ['Economics', 'Wells Management Dashboard'],
#   'Name': 'ethane sales price'},
#  {'ShortName': 'ethane transportation cost',
#   'MeasurementName': 'CurrencyPerVolume',
#   'StorageUnitName': 'EUR/m3',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'Static',
#   'DefaultLineType': 'Solid',
#   'Description': 'Cost per volume to transport ethane (C2) from the wellhead to the plant',
#   'Labels': ['Economics'],
#   'Name': 'ethane transportation cost'},
#  {'ShortName': 'ethane yield',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': ' ',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'Static',
#   'DefaultLineType': 'Solid',
#   'Description': 'Yield from a gas plant of volume of ethane (C2) per volume of gas',
#   'Labels': ['Economics'],
#   'Name': 'ethane yield'},
#  {'ShortName': 'eval well fixed monthly opex',
#   'MeasurementName': 'Currency',
#   'StorageUnitName': 'EUR',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'Static',
#   'DefaultLineType': 'Solid',
#   'Description': 'Fixed monthly costs to operate an evaluation well',
#   'Labels': ['Economics'],
#   'Name': 'evaluation well fixed monthly operating expense'},
#  {'ShortName': 'field',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': ' ',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Count',
#   'SignalType': 'String',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'field'},
#  {'ShortName': 'finding and development costs',
#   'MeasurementName': 'CurrencyPerVolume',
#   'StorageUnitName': 'EUR/m3',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'Static',
#   'DefaultLineType': 'Solid',
#   'Description': 'Average capital expenditure per barrel of oil equivalent recovered',
#   'Labels': ['Economics'],
#   'Name': 'finding and development costs'},
#  {'ShortName': 'pca1',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': ' ',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'First Principle Component'},
#  {'ShortName': 'fixed completion cost',
#   'MeasurementName': 'Currency',
#   'StorageUnitName': 'EUR',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Average',
#   'SignalType': 'Static',
#   'DefaultLineType': 'Solid',
#   'Description': 'Fixed completion cost of a single well (does not include variable costs like stage plug costs or perforation costs)',
#   'Labels': ['Completion Optimization'],
#   'Name': 'fixed completion cost'},
#  {'ShortName': 'fixed drilling cost',
#   'MeasurementName': 'Currency',
#   'StorageUnitName': 'EUR',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Average',
#   'SignalType': 'Static',
#   'DefaultLineType': 'Solid',
#   'Description': 'Fixed drilling cost of a single well',
#   'Labels': ['Completion Optimization'],
#   'Name': 'fixed drilling cost'},
#  {'ShortName': 'class',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': ' ',
#   'AggregationType': 'Average',
#   'ContainerAggregationType': 'Average',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'fl class'},
#  {'ShortName': 'fl class predicted',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': ' ',
#   'AggregationType': 'Average',
#   'ContainerAggregationType': 'Average',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'fl class predicted'},
#  {'ShortName': 'flat royalty rate',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': ' ',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'Static',
#   'DefaultLineType': 'Solid',
#   'Description': 'Fixed percent of revenues owed to royalty holders',
#   'Labels': ['Economics'],
#   'Name': 'flat royalty rate'},
#  {'ShortName': 'flooded compartment in time',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': ' ',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'flooded compartment in time'},
#  {'ShortName': 'flowdown code',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': ' ',
#   'AggregationType': 'Average',
#   'ContainerAggregationType': 'Average',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'flowdown code'},
#  {'ShortName': 'flower',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': ' ',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'flower'},
#  {'ShortName': 'flower Response Surface ML Exa',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': ' ',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'DepthDependent',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'flower Response Surface ML Example t = 01/01/1992 12:25:00'},
#  {'ShortName': 'flower_binary',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': ' ',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'flower_binary'},
#  {'ShortName': 'flowmeter factor',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': ' ',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'Static',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'flowmeter factor'},
#  {'ShortName': 'flowmeter final reading',
#   'MeasurementName': 'Volume',
#   'StorageUnitName': 'bbl',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'flowmeter final reading'},
#  {'ShortName': 'flowmeter initial reading',
#   'MeasurementName': 'Volume',
#   'StorageUnitName': 'bbl',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'flowmeter initial reading'},
#  {'ShortName': 'flowmeter volume change',
#   'MeasurementName': 'Volume',
#   'StorageUnitName': 'm3',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'flowmeter volume change'},
#  {'ShortName': 'flowrate',
#   'MeasurementName': 'Flowrate',
#   'StorageUnitName': 'm3/s',
#   'AggregationType': 'Average',
#   'ContainerAggregationType': 'Average',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'flowrate'},
#  {'ShortName': 'fluid fvf',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': ' ',
#   'AggregationType': 'Average',
#   'ContainerAggregationType': 'Average',
#   'SignalType': 'Static',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'fluid formation volume factor'},
#  {'ShortName': 'fluid intensity',
#   'MeasurementName': 'Area',
#   'StorageUnitName': 'm2',
#   'AggregationType': 'Average',
#   'ContainerAggregationType': 'Average',
#   'SignalType': 'Static',
#   'DefaultLineType': 'Solid',
#   'Description': 'Volume of fluid per lateral length.',
#   'Labels': ['Completion Optimization'],
#   'Name': 'fluid intensity'},
#  {'ShortName': 'fluid temp',
#   'MeasurementName': 'Temperature',
#   'StorageUnitName': 'K',
#   'AggregationType': 'Average',
#   'ContainerAggregationType': 'Average',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'fluid temperature'},
#  {'ShortName': 'gas channeling',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': ' ',
#   'AggregationType': 'Average',
#   'ContainerAggregationType': 'Average',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'gas channeling probability'},
#  {'ShortName': 'gas compressibility factor',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': ' ',
#   'AggregationType': 'Average',
#   'ContainerAggregationType': 'Average',
#   'SignalType': 'PVT',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'gas compressibility factor'},
#  {'ShortName': 'gas conduit volume',
#   'MeasurementName': 'Volume',
#   'StorageUnitName': 'ft3',
#   'AggregationType': 'Average',
#   'ContainerAggregationType': 'Average',
#   'SignalType': 'Static',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'gas conduit volume'},
#  {'ShortName': 'gas decline rate ll',
#   'MeasurementName': 'Flowrate',
#   'StorageUnitName': 'm3/h',
# ...
#   'AggregationType': 'Average',
#   'ContainerAggregationType': 'Min',
#   'SignalType': 'Static',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'well head pressure upper threshold'},
#  {'ShortName': 'wht',
#   'MeasurementName': 'Temperature',
#   'StorageUnitName': 'degC',
#   'AggregationType': 'Average',
#   'ContainerAggregationType': 'Average',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'well head temperature'},
#  {'ShortName': 'well name',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': ' ',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'StringTimeDependent',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'well name'},
#  {'ShortName': 'well name static',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': ' ',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'String',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'well name static'},
#  {'ShortName': 'well status',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': ' ',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'String',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'well status'},
#  {'ShortName': 'wt bhp',
#   'MeasurementName': 'Pressure',
#   'StorageUnitName': 'bar',
#   'AggregationType': 'Average',
#   'ContainerAggregationType': 'Average',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'well test bottomhole pressure'},
#  {'ShortName': 'WT BHP measured',
#   'MeasurementName': 'Pressure',
#   'StorageUnitName': 'psi',
#   'AggregationType': 'Average',
#   'ContainerAggregationType': 'Average',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'well test bottomhole pressure measured'},
#  {'ShortName': 'well test gas rate',
#   'MeasurementName': 'Flowrate',
#   'StorageUnitName': 'MMSCF/d',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'well test gas rate'},
#  {'ShortName': 'wt indicator',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': ' ',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Labels': ['Back Allocation'],
#   'Name': 'well test indicator'},
#  {'ShortName': 'wt oil contribution factor',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': ' ',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'well test oil contribution factor'},
#  {'ShortName': 'well test oil CMF',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': ' ',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'well test oil contribution multiplication factor'},
#  {'ShortName': 'WT qo measured',
#   'MeasurementName': 'Flowrate',
#   'StorageUnitName': 'bbl/d',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'well test oil production rate measured'},
#  {'ShortName': 'wt oil rate',
#   'MeasurementName': 'Flowrate',
#   'StorageUnitName': 'm3/d',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'well test oil rate'},
#  {'ShortName': 'wt pgpi',
#   'MeasurementName': 'Volume',
#   'StorageUnitName': 'MMSCF',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'well test produced gas per time increment'},
#  {'ShortName': 'wt plpti',
#   'MeasurementName': 'Flowrate',
#   'StorageUnitName': 'm3/d',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'well test produced liquid per time increment'},
#  {'ShortName': 'wt popti',
#   'MeasurementName': 'Volume',
#   'StorageUnitName': 'm3',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'well test produced oil per time increment'},
#  {'ShortName': 'wt pwpti',
#   'MeasurementName': 'Volume',
#   'StorageUnitName': 'm3',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'well test produced water per time increment'},
#  {'ShortName': 'wt uptime',
#   'MeasurementName': 'Time',
#   'StorageUnitName': 'h',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'well test uptime'},
#  {'ShortName': 'wt uptime contribution',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': ' ',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'well test uptime contribution factor'},
#  {'ShortName': 'wt water contribution factor',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': ' ',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'well test water contribution factor'},
#  {'ShortName': 'well test water CMF',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': ' ',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'well test water contribution multiplication factor'},
#  {'ShortName': 'wt wc',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': ' ',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'well test water cut'},
#  {'ShortName': 'wt water rate',
#   'MeasurementName': 'Flowrate',
#   'StorageUnitName': 'm3/d',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'well test water rate'},
#  {'ShortName': 'well type',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': ' ',
#   'AggregationType': 'Average',
#   'ContainerAggregationType': 'Average',
#   'SignalType': 'String',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'well type'},
#  {'ShortName': 'well type static',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': ' ',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'String',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'well type static'},
#  {'ShortName': 'wellbore profile',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': ' ',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'String',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'wellbore profile'},
#  {'ShortName': 'wellbore r',
#   'MeasurementName': 'Length',
#   'StorageUnitName': 'm',
#   'AggregationType': 'Average',
#   'ContainerAggregationType': 'Average',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'wellbore radius'},
#  {'ShortName': 'WI APO',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': ' ',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Average',
#   'SignalType': 'Static',
#   'DefaultLineType': 'Solid',
#   'Description': 'Working interest percentage after payout condition, if any, is met',
#   'Labels': ['Economics'],
#   'Name': 'working interest after payout'},
#  {'ShortName': 'wi post-rev',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': ' ',
#   'AggregationType': 'Average',
#   'ContainerAggregationType': 'Average',
#   'SignalType': 'Static',
#   'DefaultLineType': 'Solid',
#   'Description': 'Working interest percentage after reversion condition is met',
#   'Labels': ['Economics'],
#   'Name': 'working interest after reversion'},
#  {'ShortName': 'WI BPO',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': ' ',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Average',
#   'SignalType': 'Static',
#   'DefaultLineType': 'Solid',
#   'Description': 'Working interest percentage before payout condition, if any, is met',
#   'Labels': ['Economics'],
#   'Name': 'working interest before payout'},
#  {'ShortName': 'wi pre-reversion',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': ' ',
#   'AggregationType': 'Average',
#   'ContainerAggregationType': 'Average',
#   'SignalType': 'Static',
#   'DefaultLineType': 'Solid',
#   'Description': 'Working interest percentage before reversion condition is met',
#   'Labels': ['Economics'],
#   'Name': 'working interest before reversion'},
#  {'ShortName': 'wi condensate vol',
#   'MeasurementName': 'Volume',
#   'StorageUnitName': 'm3',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Description': 'Working interest share of the condensate sales volumes',
#   'Labels': ['Economics'],
#   'Name': 'working interest condensate volume'},
#  {'ShortName': 'wi cumul income',
#   'MeasurementName': 'Currency',
#   'StorageUnitName': 'EUR',
#   'AggregationType': 'Last',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Description': 'Working interest share of the cumulative income',
#   'Labels': ['Economics'],
#   'Name': 'working interest cumulative income'},
#  {'ShortName': 'wi gas vol',
#   'MeasurementName': 'Volume',
#   'StorageUnitName': 'm3',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Description': 'Working interest share of the gas sales volumes',
#   'Labels': ['Economics'],
#   'Name': 'working interest gas volume'},
#  {'ShortName': 'wi income',
#   'MeasurementName': 'Currency',
#   'StorageUnitName': 'EUR',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Description': 'Working interest share of income (revenue - expenses)',
#   'Labels': ['Economics'],
#   'Name': 'working interest income'},
#  {'ShortName': 'wi liquid vol',
#   'MeasurementName': 'Volume',
#   'StorageUnitName': 'm3',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Description': 'Working interest share of total sales liquid volumes',
#   'Labels': ['Economics'],
#   'Name': 'working interest liquid volume'},
#  {'ShortName': 'wi oil vol',
#   'MeasurementName': 'Volume',
#   'StorageUnitName': 'm3',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Description': 'Calculated tubing volume from injection depth and tubing inner diameter',
#   'Labels': ['Economics'],
#   'Name': 'working interest oil volume'},
#  {'ShortName': 'wi opex',
#   'MeasurementName': 'Currency',
#   'StorageUnitName': 'EUR',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Description': 'Working interest share of total operating expenses',
#   'Labels': ['Economics'],
#   'Name': 'working interest operating expenses'},
#  {'ShortName': 'wi prod taxes',
#   'MeasurementName': 'Currency',
#   'StorageUnitName': 'EUR',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Description': 'Working interest share of production taxes',
#   'Labels': ['Economics'],
#   'Name': 'working interest production taxes'},
#  {'ShortName': 'wi reserves condensate',
#   'MeasurementName': 'Volume',
#   'StorageUnitName': 'm3',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'Static',
#   'DefaultLineType': 'Solid',
#   'Description': 'Working interest share of condensate reserves',
#   'Labels': ['Economics', 'Wells Management Dashboard'],
#   'Name': 'working interest reserves condensate'},
#  {'ShortName': 'wi reserves equivalent',
#   'MeasurementName': 'Volume',
#   'StorageUnitName': 'm3',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'Static',
#   'DefaultLineType': 'Solid',
#   'Description': 'Working interest share of oil equivalent reserves',
#   'Labels': ['Economics', 'Wells Management Dashboard'],
#   'Name': 'working interest reserves equivalent'},
#  {'ShortName': 'wi reserves gas',
#   'MeasurementName': 'Volume',
#   'StorageUnitName': 'm3',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'Static',
#   'DefaultLineType': 'Solid',
#   'Description': 'Working interest share of gas reserves',
#   'Labels': ['Economics', 'Wells Management Dashboard'],
#   'Name': 'working interest reserves gas'},
#  {'ShortName': 'wi reserves liquid',
#   'MeasurementName': 'Volume',
#   'StorageUnitName': 'm3',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'Static',
#   'DefaultLineType': 'Solid',
#   'Description': 'Working interest share of liquid reserves',
#   'Labels': ['Economics', 'Wells Management Dashboard'],
#   'Name': 'working interest reserves liquid'},
#  {'ShortName': 'wi reserves oil',
#   'MeasurementName': 'Volume',
#   'StorageUnitName': 'm3',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'Static',
#   'DefaultLineType': 'Solid',
#   'Description': 'Working interest share of oil reserves',
#   'Labels': ['Economics', 'Wells Management Dashboard'],
#   'Name': 'working interest reserves oil'},
#  {'ShortName': 'wi revenue',
#   'MeasurementName': 'Currency',
#   'StorageUnitName': 'EUR',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Description': 'Working interest share of revenue',
#   'Labels': ['Economics'],
#   'Name': 'working interest revenue'},
#  {'ShortName': 'wi royalty payments',
#   'MeasurementName': 'Currency',
#   'StorageUnitName': 'EUR',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Description': 'Working interest portion of royalty payments',
#   'Labels': ['Economics'],
#   'Name': 'working interest royalty payments'},
#  {'ShortName': 'wi transportation costs',
#   'MeasurementName': 'Currency',
#   'StorageUnitName': 'EUR',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Description': 'Working interest portion of transportation costs',
#   'Labels': ['Economics'],
#   'Name': 'working interest transportation costs'},
#  {'ShortName': 'wi water vol',
#   'MeasurementName': 'Volume',
#   'StorageUnitName': 'm3',
#   'AggregationType': 'Sum',
#   'ContainerAggregationType': 'Sum',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Description': 'Working interest share of water sales volumes',
#   'Labels': ['Economics'],
#   'Name': 'working interest water volume'},
#  {'ShortName': 'wi with reversion',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': ' ',
#   'AggregationType': 'Average',
#   'ContainerAggregationType': 'Average',
#   'SignalType': 'TimeDependent',
#   'DefaultLineType': 'Solid',
#   'Description': 'Working interest in an entity over time. Working interest may change due to, for example, an existing back-in interest.',
#   'Labels': ['Economics'],
#   'Name': 'working interest with reversion'},
#  {'ShortName': 'yofp',
#   'MeasurementName': 'Dimensionless',
#   'StorageUnitName': ' ',
#   'AggregationType': 'Average',
#   'ContainerAggregationType': 'Average',
#   'SignalType': 'Static',
#   'DefaultLineType': 'Solid',
#   'Labels': [],
#   'Name': 'year of first production'}]

# %%
# get items paged
pv_api.get_items_paged('Workflow',
                       page=1,
                       page_size=10)
# Out:
# {'Items': [{'Activities': [{'ActivityType': 'DataImport',
#      'ActivityName': '_Data Import Session Stats',
#      'Settings': '{"ScenarioOptions":{}}',
#      'StopWorkflow': 'Error',
#      'MappedInputArguments': [],
#      'MappedOutputArguments': [],
#      'InputArgumentsInfo': [],
#      'ExternalValidationError': ''}],
#    'User': 'GeorgSchweiger',
#    'Modified': '2022-11-11T08:37:38.132',
#    'Created': '2023-01-24T08:16:54.615',
#    'Labels': [],
#    'Name': '_Data Import Session Stats'},
#   {'Activities': [{'ActivityType': 'Web',
#      'ActivityName': 'test',
#      'Settings': '',
#      'StopWorkflow': 'Error',
#      'MappedInputArguments': [{'ArgumentName': 'P# Script Name',
#        'ArgumentType': 'StringValue',
#        'AcceptableArgumentTypes': ['StringValue'],
#        'Options': []}],
#      'MappedOutputArguments': [],
#      'InputArgumentsInfo': [],
#      'ExternalValidationError': ''}],
#    'User': 'DNikolaev',
#    'Modified': '2022-06-21T13:04:40.889',
#    'Created': '2023-01-24T08:16:54.615',
#    'Labels': [],
#    'Name': '_test'},
#   {'Activities': [{'ActivityType': 'PivotTable',
#      'ActivityName': "Single'Quotation",
#      'Settings': '',
#      'StopWorkflow': 'Error',
#      'MappedInputArguments': [],
#      'MappedOutputArguments': [],
#      'InputArgumentsInfo': [],
#      'ExternalValidationError': ''},
#     {'ActivityType': 'PSharpScript',
#      'ActivityName': '11629',
#      'Settings': '{"MaxDegreeOfParallelismOnScriptExecution":2,"ParallelismOnExecution":"Default","NamedParametersSettings":[]}',
#      'StopWorkflow': 'Error',
#      'MappedInputArguments': [],
#      'MappedOutputArguments': [],
#      'InputArgumentsInfo': [],
#      'ExternalValidationError': ''},
#     {'ActivityType': 'PSharpScript',
#      'ActivityName': 'A Test Script',
#      'Settings': '{"MaxDegreeOfParallelismOnScriptExecution":2,"ParallelismOnExecution":"Default","NamedParametersSettings":[]}',
#      'StopWorkflow': 'Error',
#      'MappedInputArguments': [],
#      'MappedOutputArguments': [],
#      'InputArgumentsInfo': [],
#      'ExternalValidationError': ''}],
#    'Modified': '2023-03-06T13:46:17.899',
#    'Created': '2023-01-24T08:16:54.615',
#    'ModifiedBy': 'GeorgSchweiger',
#    'Labels': [],
#    'Name': '11629'},
#   {'Activities': [{'ActivityType': 'PSharpScript',
#      'ActivityName': '11681',
#      'Settings': '{"EntitiesPerScriptExecution":100,"MaxDegreeOfParallelismOnScriptExecution":4,"ParallelismOnExecution":"Max","NamedParametersSettings":[]}',
#      'StopWorkflow': 'Error',
#      'MappedInputArguments': [],
#      'MappedOutputArguments': [],
#      'InputArgumentsInfo': [],
#      'ExternalValidationError': ''},
#     {'ActivityType': 'PSharpScript',
#      'ActivityName': 'A Test Script',
#      'Settings': '{"MaxDegreeOfParallelismOnScriptExecution":2,"ParallelismOnExecution":"Default","NamedParametersSettings":[]}',
#      'StopWorkflow': 'Error',
#      'MappedInputArguments': [],
#      'MappedOutputArguments': [],
#      'InputArgumentsInfo': [],
#      'ExternalValidationError': ''}],
#    'User': 'GeorgSchweiger',
#    'Modified': '2022-09-15T13:51:40.88',
#    'Created': '2023-01-24T08:16:54.615',
#    'Labels': [],
#    'Name': '11681'},
#   {'Activities': [{'ActivityType': 'PSharpScript',
#      'ActivityName': 'ABC Plot Surveillance',
#      'Settings': '{"MaxDegreeOfParallelismOnScriptExecution":-1,"ParallelismOnExecution":"Default","NamedParametersSettings":[]}',
#      'StopWorkflow': 'Error',
#      'MappedInputArguments': [],
#      'MappedOutputArguments': [],
#      'InputArgumentsInfo': [],
#      'ExternalValidationError': ''}],
#    'IsLocked': True,
#    'Modified': '2022-04-22T12:06:59.269',
#    'Created': '2023-01-24T08:16:54.615',
#    'Labels': ['ABC Plot'],
#    'Name': 'ABC Plot Surveillance'},
#   {'Activities': [{'ActivityType': 'Web',
#      'ActivityName': 'api_tests',
#      'Settings': '',
#      'StopWorkflow': 'Error',
#      'MappedInputArguments': [{'ArgumentName': 'test_name',
#        'ArgumentType': 'StringValue',
#        'AcceptableArgumentTypes': ['StringValue'],
#        'Options': []}],
#      'MappedOutputArguments': [],
#      'InputArgumentsInfo': [],
#      'ExternalValidationError': ''}],
#    'User': 'RomanManasipov',
#    'Modified': '2023-01-18T13:41:15.46',
#    'Created': '2023-01-24T08:16:54.615',
#    'Labels': [],
#    'Name': 'API Tests'},
#   {'Activities': [{'ActivityType': 'PSharpScript',
#      'ActivityName': 'Assign Primary Phase',
#      'Settings': '{"EntitiesPerScriptExecution":500,"MaxDegreeOfParallelismOnScriptExecution":4,"ParallelismOnExecution":"Max","NamedParametersSettings":[]}',
#      'StopWorkflow': 'Error',
#      'MappedInputArguments': [],
#      'MappedOutputArguments': [],
#      'InputArgumentsInfo': [],
#      'ExternalValidationError': ''}],
#    'IsLocked': True,
#    'Modified': '2022-12-15T10:18:37.879',
#    'Created': '2023-01-24T08:16:54.615',
#    'Description': 'Determines the primary phase for an entity based on the first six months of\nproduction.',
#    'Labels': ['Basic'],
#    'Name': 'Assign Primary Phase'},
#   {'Activities': [{'ActivityType': 'PSharpScript',
#      'ActivityName': 'Back Allocation 1',
#      'Settings': '{"MaxDegreeOfParallelismOnScriptExecution":2,"ParallelismOnExecution":"Default","NamedParametersSettings":[]}',
#      'StopWorkflow': 'Error',
#      'MappedInputArguments': [],
#      'MappedOutputArguments': [],
#      'InputArgumentsInfo': [],
#      'ExternalValidationError': 'Error parsing P# script \'Back Allocation 1\' in workflow \'Back Allocation\' :  - Line 45: We found an error in the column definition of table "Meter Reconciliation". Please have a look at the column definition of the table.\n - Line 46: We found an error in the expression definition of column "Reconciled water". Please have a look at the expression of the column. \n - Line 46: We couldn\'t validate the IF condition.\n - Line 46: There is an issue with the argument definition of function "Contains". Check the function arguments and make sure that you provide them in the required form. Consult the help to find more information about functions and arguments. \n - Line 46: There is an issue with the function call. Check the function name, the brackets, the argument(s) and argument type(s), and function input parameter expression(s).\n - The function "CurrentEntityName" does not exist in P#. Make sure there is no typo in the function name. Consult the help file to find more information about the availability and correct name of the functionality you want to use.\n'},
#     {'ActivityType': 'PSharpScript',
#      'ActivityName': 'Back Allocation 2',
#      'Settings': '{"MaxDegreeOfParallelismOnScriptExecution":2,"ParallelismOnExecution":"Default","NamedParametersSettings":[]}',
#      'StopWorkflow': 'Error',
#      'MappedInputArguments': [],
#      'MappedOutputArguments': [],
#      'InputArgumentsInfo': [],
#      'ExternalValidationError': 'Error parsing P# script \'Back Allocation 2\' in workflow \'Back Allocation\' :  - Line 83: We found an error in the column definition of table "WT contribution factor". Please have a look at the column definition of the table.\n - Line 84: We found an error in the expression definition of column "WT oil total contr". Please have a look at the expression of the column. \n - Line 84: We couldn\'t resolve the left part of expression "/". Have a look at the formula and change it.\n - Line 84: There is an issue with the function call. Check the function name, the brackets, the argument(s) and argument type(s), and function input parameter expression(s).\n - The function "GapFilling" does not exist in P#. Make sure there is no typo in the function name. Consult the help file to find more information about the availability and correct name of the functionality you want to use.\n'},
#     {'ActivityType': 'PSharpScript',
#      'ActivityName': 'Back Allocation 3 ',
#      'Settings': '{"MaxDegreeOfParallelismOnScriptExecution":2,"ParallelismOnExecution":"Default","NamedParametersSettings":[]}',
#      'StopWorkflow': 'Error',
#      'MappedInputArguments': [],
#      'MappedOutputArguments': [],
#      'InputArgumentsInfo': [],
#      'ExternalValidationError': 'Error parsing P# script \'Back Allocation 3 \' in workflow \'Back Allocation\' :  - Line 35: We found an error in the column definition of table "Calculation". Please have a look at the column definition of the table.\n - Line 36: We found an error in the expression definition of column "WT oil total contr". Please have a look at the expression of the column. \n - Line 36: We couldn\'t resolve the left part of expression "/". Have a look at the formula and change it.\n - Line 36: There is an issue with the function call. Check the function name, the brackets, the argument(s) and argument type(s), and function input parameter expression(s).\n - The function "GapFilling" does not exist in P#. Make sure there is no typo in the function name. Consult the help file to find more information about the availability and correct name of the functionality you want to use.\n'}],
#    'User': 'DavidGonczi',
#    'Modified': '2022-03-31T15:12:51.045',
#    'Created': '2023-01-24T08:16:54.615',
#    'Labels': [],
#    'Name': 'Back Allocation'},
#   {'Activities': [{'ActivityType': 'PSharpScript',
#      'ActivityName': 'Back Allocation 2',
#      'Settings': '{"MaxDegreeOfParallelismOnScriptExecution":2,"ParallelismOnExecution":"Default","NamedParametersSettings":[]}',
#      'StopWorkflow': 'Error',
#      'MappedInputArguments': [],
#      'MappedOutputArguments': [],
#      'InputArgumentsInfo': [],
#      'ExternalValidationError': 'Error parsing P# script \'Back Allocation 2\' in workflow \'Back Allocation 2\' :  - Line 83: We found an error in the column definition of table "WT contribution factor". Please have a look at the column definition of the table.\n - Line 84: We found an error in the expression definition of column "WT oil total contr". Please have a look at the expression of the column. \n - Line 84: We couldn\'t resolve the left part of expression "/". Have a look at the formula and change it.\n - Line 84: There is an issue with the function call. Check the function name, the brackets, the argument(s) and argument type(s), and function input parameter expression(s).\n - The function "GapFilling" does not exist in P#. Make sure there is no typo in the function name. Consult the help file to find more information about the availability and correct name of the functionality you want to use.\n'}],
#    'User': 'DavidGonczi',
#    'Modified': '2022-03-31T15:12:51.045',
#    'Created': '2023-01-24T08:16:54.615',
#    'Labels': ['Boot Camp'],
#    'Name': 'Back Allocation 2'},
#   {'Activities': [{'ActivityType': 'PSharpScript',
#      'ActivityName': 'Back Allocation 3 ',
#      'Settings': '{"MaxDegreeOfParallelismOnScriptExecution":2,"ParallelismOnExecution":"Default","NamedParametersSettings":[]}',
#      'StopWorkflow': 'Error',
#      'MappedInputArguments': [],
#      'MappedOutputArguments': [],
#      'InputArgumentsInfo': [],
#      'ExternalValidationError': 'Error parsing P# script \'Back Allocation 3 \' in workflow \'Back Allocation 3\' :  - Line 35: We found an error in the column definition of table "Calculation". Please have a look at the column definition of the table.\n - Line 36: We found an error in the expression definition of column "WT oil total contr". Please have a look at the expression of the column. \n - Line 36: We couldn\'t resolve the left part of expression "/". Have a look at the formula and change it.\n - Line 36: There is an issue with the function call. Check the function name, the brackets, the argument(s) and argument type(s), and function input parameter expression(s).\n - The function "GapFilling" does not exist in P#. Make sure there is no typo in the function name. Consult the help file to find more information about the availability and correct name of the functionality you want to use.\n'}],
#    'User': 'DavidGonczi',
#    'Modified': '2022-03-31T15:12:51.045',
#    'Created': '2023-01-24T08:16:54.615',
#    'Labels': ['Boot Camp'],
#    'Name': 'Back Allocation 3'}]}

# %%
# get item infos
pv_api.get_item_infos('MachineLearningModel')
# Out:
# [{'IsTrained': True,
#   'Type': 'Regression',
#   'IsModelPerEntity': False,
#   'TableFormula': 'Table "ML Inputs"\r\n\tColumn "Cumulative Oil Production Neighbors 1000m Average" in "STB"\r\n\t\tCumulative(\r\n\t\t\tAggregateNeighbors(\r\n\t\t\t\t"produced oil per time increment" in "STB",\r\n\t\t\t\tAggregations.Average,\r\n\t\t\t\t1000,\r\n\t\t\t\t"m",\r\n\t\t\t\t"subsurface x-coordinate",\r\n\t\t\t\t"subsurface y-coordinate",\r\n\t\t\t\tTrue,\r\n\t\t\t\tFalse\r\n\t\t\t)\r\n\t\t\t,\r\n\t\t\t"linear"\r\n\t\t)\r\n\tEnd Column\r\n\tColumn "Cumulative Oil Current Target" in "STB"\r\n\t\tCumulative("produced oil per time increment" In "STB")\r\n\tEnd Column\r\nEnd Table\r\n',
#   'ContextFormula': 'Context "AutoMLContext"\r\n\tEntity Set "UK Wells"\r\n\tScope "Start To End Monthly"\r\nEnd Context\r\n\r\nEntity Set "UK Wells"\r\n"Well J0001"\r\n"Well J0002"\r\n"Well J0003"\r\n"Well J0004"\r\n"Well J0005"\r\n"Well J0006"\r\n"Well J0007"\r\n"Well J0008"\r\nEnd Set\n\r\nScope "Start To End Monthly"\r\n\tBetween #10/1/2005#\r\n\tAnd #1/1/2016#\r\n\tStep Monthly\r\nEnd Scope\n\r\n',
#   'LabelColumnName': 'Cumulative Oil Current Target',
#   'TrainingOptions': {'TestFraction': 10,
#    'ValidationFraction': 10,
#    'OptimizationMetric': 'RSquared',
#    'TimeToTrain': 10,
#    'NumberOfClusters': 5,
#    'NumberOfCrossValidationFolds': 1,
#    'TrainersToExclude': ['FastTree',
#     'FastTreeTweedie',
#     'LightGbm',
#     'OnlineGradientDescent',
#     'Ols',
#     'LbfgsPoissonRegression',
#     'StochasticDualCoordinateAscent']},
#   'Trained': '2021-11-22T12:59:18.409Z',
#   'TestDataMode': 'Union',
#   'ValidationDataMode': 'Union',
#   'OutlierFilters': [],
#   'Modified': '2022-05-18T07:58:23.55',
#   'Created': '2023-01-24T08:16:54.787',
#   'Labels': ['Aggregation bug'],
#   'Name': 'BCO Cumulative 1'},
#  {'IsTrained': True,
#   'Type': 'Regression',
#   'IsModelPerEntity': False,
#   'TableFormula': 'Table "ML Inputs"\r\n\tColumn "Cumulative Oil Production Neighbors 400m Average 2" in "STB"\r\n\t\tCumulative(\r\n\t\t\tAggregateFromEntities("produced oil per time increment" in "STB", Aggregations.Average, "Well J0002, Well J0007", ", ")\r\n\t\t\t, "linear")\r\n\tEnd Column\r\n\tColumn "Cumulative Oil Current Target" in "STB"\r\n\t\tCumulative("produced oil per time increment" In "STB")\r\n\tEnd Column\r\nEnd Table\r\n',
#   'ContextFormula': 'Context "AutoMLContext"\r\n\tEntity Set "UK Wells"\r\n\tScope "Start To End Monthly"\r\nEnd Context\r\n\r\nEntity Set "UK Wells"\r\n"Well J0001"\r\n"Well J0002"\r\n"Well J0003"\r\n"Well J0004"\r\n"Well J0005"\r\n"Well J0006"\r\n"Well J0007"\r\n"Well J0008"\r\nEnd Set\n\r\nScope "Start To End Monthly"\r\n\tBetween #10/1/2005#\r\n\tAnd #1/1/2016#\r\n\tStep Monthly\r\nEnd Scope\n\r\n',
#   'LabelColumnName': 'Cumulative Oil Current Target',
#   'TrainingOptions': {'TestFraction': 0.1,
#    'ValidationFraction': 0.1,
#    'OptimizationMetric': 'RSquared',
#    'TimeToTrain': 5,
#    'NumberOfClusters': 5,
#    'NumberOfCrossValidationFolds': 1,
#    'TrainersToExclude': ['FastTree',
#     'FastTreeTweedie',
#     'LightGbm',
#     'OnlineGradientDescent',
#     'Ols',
#     'LbfgsPoissonRegression',
#     'StochasticDualCoordinateAscent']},
#   'Trained': '2021-11-19T08:15:15.5082171Z',
#   'TestDataMode': 'Union',
#   'ValidationDataMode': 'Union',
#   'OutlierFilters': [],
#   'Modified': '2022-05-18T07:04:28.021',
#   'Created': '2023-01-24T08:16:54.787',
#   'Labels': ['Aggregation bug'],
#   'Name': 'BCO Cumulative 2'},
#  {'IsTrained': True,
#   'Type': 'Regression',
#   'IsModelPerEntity': False,
#   'TableFormula': 'Table "Classification"\r\n\tColumn "Gapfilled Water" in "m3"\r\n\t\tMovingAvg("produced water per time increment" in "m3", 2,2)\r\n\tEnd Column\r\n\tColumn "Gapfilled Oil" in "m3"\r\n\t\tMovingAvg("produced oil per time increment" in "m3", 2,2)\r\n\tEnd Column\r\n\tColumn "WOR" in " "\r\n\t\tColumn "Gapfilled Water" in "m3" /\r\n\t\t\tColumn "Gapfilled Oil" in "m3"\r\n\tEnd Column\r\n\tColumn "WOR Smoothed" in " "\r\n\t\tMovingAvg(Column "Gapfilled Water" in "m3" /\r\n\t\t\tColumn "Gapfilled Oil" in "m3", 10, 10)\r\n\tEnd Column\r\n\tColumn "WOR Trend Derivative Large Window" in " "\r\n\t\tFillGaps(iif(Cumulative(1)/200 - Round(Cumulative(1)/200, 0)=0, MovingDiff(MovingAvg(Column "WOR" in " ", 400, 400), 200) ,Null()))\r\n\tEnd Column\r\n\tColumn "WOR Trend 2nd Derivative Large Window" in " "\r\n\t\tMovingDiff(Column "WOR Trend Derivative Large Window" in " ",1)\r\n\tEnd Column\r\n\tColumn "WOR Smoothed derivative" in " "\r\n\t\tMovingDiff(Column "WOR Smoothed" in " ",  1)\r\n\tEnd Column\r\n\tColumn "WOR Smoothed 2nd derivative" in " "\r\n\t\tMovingDiff(Column "WOR Smoothed derivative" in " ",  1)\r\n\tEnd Column\r\n\t\r\n\tColumn "Chan patterns" in " "\r\n\t\tFillGaps("Chan patterns" in " ")\r\n\tEnd Column\r\n\t\r\nEnd Table\r\n',
#   'TestDataMode': 'Union',
#   'ValidationDataMode': 'Union',
#   'OutlierFilters': [],
#   'Modified': '2022-03-31T15:12:51.154',
#   'Created': '2023-01-24T08:16:54.787',
#   'Labels': [],
#   'Name': 'Chan Patterns'},
#  {'IsTrained': True,
#   'Type': 'Regression',
#   'IsModelPerEntity': False,
#   'TableFormula': 'Table "Machine Learning Training"\r\n\tColumn "Logarithmic Water Oil Ratio" in " "\r\n\t\tLog("smoothed water oil ratio" in " ")\r\n\tEnd Column\r\n\tColumn "Logarithmic Derivative Water Oil Ratio" in " "\r\n\t\tLog("smoothed derivative water oil ratio" in " ")\r\n\tEnd Column\r\n\tColumn "Chan Plot Classification" in " "\r\n\t\t"chan plot classification" in " "\r\n\tEnd Column\r\nEnd Table\r\n',
#   'TestDataMode': 'Union',
#   'ValidationDataMode': 'Union',
#   'OutlierFilters': [],
#   'Modified': '2022-03-31T15:12:51.154',
#   'Created': '2023-01-24T08:16:54.787',
#   'Labels': [],
#   'Name': 'Chan Plot Classification'},
#  {'Type': 'Regression',
#   'IsModelPerEntity': False,
#   'TableFormula': 'Table "MLModelTable"\n\tColumn "best three-month oil equivalent production rate" in "m3/d"\n\t\t"best three-month oil equivalent production rate" in "m3/d"\n\tEnd Column\n\tColumn "completed lateral length" in "ft"\n\t\t"completed lateral length" in "ft"\n\tEnd Column\n\tColumn "fluid intensity" in "bbl/ft"\n\t\t"fluid intensity" in "bbl/ft"\n\tEnd Column\n\tColumn "proppant intensity" in "lbm/ft"\n\t\t"proppant intensity" in "lbm/ft"\n\tEnd Column\n\tColumn "total true vertical depth" in "ft"\n\t\t"total true vertical depth" in "ft"\n\tEnd Column\n\tColumn "stage spacing" in "ft"\n\t\t"stage spacing" in "ft"\n\tEnd Column\n\tColumn "number of perforation stages" in " "\n\t\t"number of perforation stages" in " "\n\tEnd Column\n\tColumn "number of perforation clusters" in " "\n\t\t"number of perforation clusters" in " "\n\tEnd Column\n\tColumn "perforation cluster spacing" in "ft"\n\t\t"perforation cluster spacing" in "ft"\n\tEnd Column\n\tColumn "implied horizontal well spacing" in "ft"\n\t\t"implied horizontal well spacing" in "ft"\n\tEnd Column\nEnd Table',
#   'ContextFormula': 'Context "AutoMLContext"\n  Entity Set "MLModelEntitySet"\n  Scope "MLModelScopeFormula"\n  Hierarchy "Well Hierarchy"\nEnd Context\nEntity Set "MLModelEntitySet" = "Type Curve Builder Wells"\nScope "MLModelScopeFormula"\n    Between Now()\n    And Now()\n    Step EveryFiveMinutes\nEnd Scope',
#   'LabelColumnName': 'best three-month oil equivalent production rate',
#   'TrainingOptions': {'TimeToTrain': 5,
#    'NumberOfClusters': 1,
#    'NumberOfCrossValidationFolds': 1,
#    'TrainersToExclude': []},
#   'TestDataMode': 'Union',
#   'ValidationDataMode': 'Union',
#   'OutlierFilters': ['CooksDistance'],
#   'IsLocked': True,
#   'Modified': '2022-12-05T12:46:47.709',
#   'Created': '2023-01-24T08:16:54.787',
#   'Description': 'Suggested model for use in the Completion Optimization workflow that is based on the suggested well cost model. This model should only be used as a starting point and should be modified as appropriate for the given data-set.\n\nThe entity set used for training this model should be the same entity set that was used to construct the type curves.',
#   'Labels': ['Completion Optimization'],
#   'Name': 'Completion Optimization  - B90 Oil Equivalent'},
#  {'IsTrained': True,
#   'Type': 'Regression',
#   'IsModelPerEntity': False,
#   'TableFormula': 'Table "FilterTable"\r\n\tColumn "flower" in " "\r\n\t\t"flower" in " "\r\n\tEnd Column\r\n\tColumn "petal length" in "cm"\r\n\t\t"petal length" in "cm"\r\n\tEnd Column\r\n\tColumn "petal width" in "cm"\r\n\t\t"petal width" in "cm"\r\n\tEnd Column\r\n\tColumn "sepal length" in "cm"\r\n\t\t"sepal length" in "cm"\r\n\tEnd Column\r\n\tColumn "sepal width" in "cm"\r\n\t\t"sepal width" in "cm"\r\n\tEnd Column\r\nEnd Table\r\n',
#   'ContextFormula': 'Context "AutoMLContext"\r\n\tEntity Set "FilterEntitySet"\r\n\tScope "FilterScope"\r\nEnd Context\r\n\r\nEntity Set "FilterEntitySet"\r\n\t"ML Example"\r\nEnd Set\n\r\nScope "FilterScope" \n\tBetween #01/01/1992 00:00# \n\tAnd #01/01/1992 12:25# \n\tStep EveryFiveMinutes \nEnd Scope\n\r\n',
#   'LabelColumnName': 'flower',
#   'TestDataMode': 'Union',
#   'ValidationDataMode': 'Union',
#   'OutlierFilters': [],
#   'Modified': '2022-03-31T15:12:51.154',
#   'Created': '2023-01-24T08:16:54.787',
#   'Labels': [],
#   'Name': 'Iris Example'},
#  {'IsTrained': True,
#   'Type': 'Regression',
#   'IsModelPerEntity': False,
#   'TableFormula': 'Table "Iris Flowers Table"\n\tColumn "Iris class" in " "\n\t\t"Iris class" in " "\n\tEnd Column\n\tColumn "petal length (cm)" in "cm"\n\t\t"petal length (cm)" in "cm"\n\tEnd Column\n\tColumn "petal width (cm)" in "cm"\n\t\t"petal width (cm)" in "cm"\n\tEnd Column\n\tColumn "sepal length (cm)" in "cm"\n\t\t"sepal length (cm)" in "cm"\n\tEnd Column\n\tColumn "sepal width (cm)" in "cm"\n\t\t"sepal width (cm)" in "cm"\n\tEnd Column\nEnd Table\n',
#   'ContextFormula': 'Context "AutoMLContext"\r\n\tEntity Set "Iris Flowers"\r\n\tScope "Iris Flowers Scope"\r\nEnd Context\r\n\r\nEntity Set "Iris Flowers"\n\t"Flower001"\n\t"Flower002"\n\t"Flower003"\n\t"Flower004"\n\t"Flower005"\n\t"Flower006"\n\t"Flower007"\n\t"Flower008"\n\t"Flower009"\n\t"Flower010"\n\t"Flower011"\n\t"Flower012"\n\t"Flower013"\n\t"Flower014"\n\t"Flower015"\n\t"Flower016"\n\t"Flower017"\n\t"Flower018"\n\t"Flower019"\n\t"Flower020"\n\t"Flower021"\n\t"Flower022"\n\t"Flower023"\n\t"Flower024"\n\t"Flower025"\n\t"Flower026"\n\t"Flower027"\n\t"Flower028"\n\t"Flower029"\n\t"Flower030"\n\t"Flower031"\n\t"Flower032"\n\t"Flower033"\n\t"Flower034"\n\t"Flower035"\n\t"Flower036"\n\t"Flower037"\n\t"Flower038"\n\t"Flower039"\n\t"Flower040"\n\t"Flower041"\n\t"Flower042"\n\t"Flower043"\n\t"Flower044"\n\t"Flower045"\n\t"Flower046"\n\t"Flower047"\n\t"Flower048"\n\t"Flower049"\n\t"Flower050"\n\t"Flower051"\n\t"Flower052"\n\t"Flower053"\n\t"Flower054"\n\t"Flower055"\n\t"Flower056"\n\t"Flower057"\n\t"Flower058"\n\t"Flower059"\n\t"Flower060"\n\t"Flower061"\n\t"Flower062"\n\t"Flower063"\n\t"Flower064"\n\t"Flower065"\n\t"Flower066"\n\t"Flower067"\n\t"Flower068"\n\t"Flower069"\n\t"Flower070"\n\t"Flower071"\n\t"Flower072"\n\t"Flower073"\n\t"Flower074"\n\t"Flower075"\n\t"Flower076"\n\t"Flower077"\n\t"Flower078"\n\t"Flower079"\n\t"Flower080"\n\t"Flower081"\n\t"Flower082"\n\t"Flower083"\n\t"Flower084"\n\t"Flower085"\n\t"Flower086"\n\t"Flower087"\n\t"Flower088"\n\t"Flower089"\n\t"Flower090"\n\t"Flower091"\n\t"Flower092"\n\t"Flower093"\n\t"Flower094"\n\t"Flower095"\n\t"Flower096"\n\t"Flower097"\n\t"Flower098"\n\t"Flower099"\n\t"Flower100"\n\t"Flower101"\n\t"Flower102"\n\t"Flower103"\n\t"Flower104"\n\t"Flower105"\n\t"Flower106"\n\t"Flower107"\n\t"Flower108"\n\t"Flower109"\n\t"Flower110"\n\t"Flower111"\n\t"Flower112"\n\t"Flower113"\n\t"Flower114"\n\t"Flower115"\n\t"Flower116"\n\t"Flower117"\n\t"Flower118"\n\t"Flower119"\n\t"Flower120"\n\t"Flower121"\n\t"Flower122"\n\t"Flower123"\n\t"Flower124"\n\t"Flower125"\n\t"Flower126"\n\t"Flower127"\n\t"Flower128"\n\t"Flower129"\n\t"Flower130"\n\t"Flower131"\n\t"Flower132"\n\t"Flower133"\n\t"Flower134"\n\t"Flower135"\n\t"Flower136"\n\t"Flower137"\n\t"Flower138"\n\t"Flower139"\n\t"Flower140"\n\t"Flower141"\n\t"Flower142"\n\t"Flower143"\n\t"Flower144"\n\t"Flower145"\n\t"Flower146"\n\t"Flower147"\n\t"Flower148"\n\t"Flower149"\n\t"Flower150"\nEnd Set\n\r\nScope "Iris Flowers Scope" \n\tBetween #05/26/2021 13:55:10# \n\tAnd #05/26/2021 13:55:10# \n\tStep Monthly \nEnd Scope\n\r\n',
#   'LabelColumnName': 'Iris class',
#   'TestDataMode': 'Union',
#   'ValidationDataMode': 'Union',
#   'OutlierFilters': [],
#   'Modified': '2022-03-31T15:12:51.154',
#   'Created': '2023-01-24T08:16:54.787',
#   'Labels': [],
#   'Name': 'IrisML'},
#  {'IsTrained': True,
#   'Type': 'MultipleClassification',
#   'IsModelPerEntity': False,
#   'TableFormula': 'Table "FilterTable"\r\n\tColumn "flower" in " "\r\n\t\t"flower" in " "\r\n\tEnd Column\r\n\tColumn "petal length" in "cm"\r\n\t\t"petal length" in "cm"\r\n\tEnd Column\r\n\tColumn "petal width" in "cm"\r\n\t\t"petal width" in "cm"\r\n\tEnd Column\r\n\tColumn "sepal length" in "cm"\r\n\t\t"sepal length" in "cm"\r\n\tEnd Column\r\n\tColumn "sepal width" in "cm"\r\n\t\t"sepal width" in "cm"\r\n\tEnd Column\r\nEnd Table\r\n',
#   'ContextFormula': 'Context "AutoMLContext"\r\n\tEntity Set "MLModelEntitySet"\r\n\tScope "MLModelScope"\r\nEnd Context\r\n\r\nEntity Set "MLModelEntitySet"\r\n\t"ML Example"\r\nEnd Set\n\r\nScope "MLModelScope"\r\n\tBetween #01/01/2010 00:00#\r\n\tAnd #01/01/2010 01:36#\r\n\tStep EveryMinute\r\nEnd Scope\n\r\n',
#   'LabelColumnName': 'flower',
#   'TestDataMode': 'Union',
#   'ValidationDataMode': 'Union',
#   'OutlierFilters': [],
#   'Modified': '2022-03-31T15:12:51.154',
#   'Created': '2023-01-24T08:16:54.787',
#   'Labels': [],
#   'Name': 'IrisMultiClassification'},
#  {'Type': 'MultipleClassification',
#   'IsModelPerEntity': False,
#   'TableFormula': 'Table "MLModelTable"\n\n\tColumn "Events Target" in " "  \n\t\t// "temporal feature 1 time" in " "\n\t\tIIF(\n\t\t\t"temporal feature 1 time" in " "\n\t\t\t!+\n\t\t\tShift("temporal feature 1 time" in " ",-1) !+\n\t\t\tShift("temporal feature 1 time" in " ",-2) !+\n\t\t\tShift("temporal feature 1 time" in " ",-3) !+\n\t\t\tShift("temporal feature 1 time" in " ",-4) \n\t\t\t> 0\n\t\t\t,\n\n\t\t\t"temporal feature 1 time" in " "\n\t\t\t!+\n\t\t\tShift("temporal feature 1 time" in " ",-1) !+\n\t\t\tShift("temporal feature 1 time" in " ",-2) !+\n\t\t\tShift("temporal feature 1 time" in " ",-3) !+\n\t\t\tShift("temporal feature 1 time" in " ",-4)\n\t\t\t,\n\t\t\t0\n\t\t)\n\n\tEnd Column\n\n\tColumn "WHP" in " "\n\t\t"temporal feature 2 time" in " "\n\tEnd Column\n\n\tColumn "CP" in " " \n\t\t"temporal feature 3 time" in " "\n\tEnd Column\n\n\tColumn "GR" in " " \n\t\t"temporal feature 4 time" in " "\n\tEnd Column\n\t\nEnd Table',
#   'ContextFormula': 'Context "AutoMLContext"\n  Entity Set "MLModelEntitySet"\n  Scope "Start To End Daily"\n  \nEnd Context\nEntity Set "MLModelEntitySet" = "22 Wells"\nScope "Start To End Daily"\r\n\tBetween #09/01/2021#\r\n\tAnd  #03/01/2022#\r\n\tStep Daily\r\nEnd Scope',
#   'LabelColumnName': 'Events Target',
#   'TrainingOptions': {'TimeToTrain': 5,
#    'NumberOfClusters': 1,
#    'NumberOfCrossValidationFolds': 1,
#    'TrainersToExclude': []},
#   'TestDataMode': 'Union',
#   'ValidationDataMode': 'Union',
#   'OutlierFilters': [],
#   'User': 'DNikolaev',
#   'Modified': '2022-03-31T15:31:13.828',
#   'Created': '2023-01-24T08:16:54.787',
#   'Labels': [],
#   'Name': 'ML MultClassification'},
#  {'Type': 'BinaryClassification',
#   'IsModelPerEntity': False,
#   'TableFormula': 'Table "Table"\n\n\tColumn "Events" in " "\n\t\t"temporal feature 4" in " "\n\tEnd Column\n\n\tColumn "WHP" in "psi"\n\t\t"temporal feature 1" in " "\n\tEnd Column\n\n\tColumn "CP" in "psi"\n\t\t"temporal feature 2" in " "\n\tEnd Column\n\n\tColumn "GR" in " "\n\t\t"temporal feature 3" in " "\n\tEnd Column\n\nEnd Table',
#   'ContextFormula': 'Context "AutoMLContext"\n  Entity Set "MLModelEntitySet"\n  Scope "Start To End Daily"\n  \nEnd Context\nEntity Set "MLModelEntitySet" = "All TestWells"\nScope "Start To End Daily"\r\n\tBetween StartOf()\r\n\tAnd EndOf()\r\n\tStep Daily\r\nEnd Scope',
#   'LabelColumnName': 'Events',
#   'TrainingOptions': {'TimeToTrain': 5,
#    'NumberOfClusters': 1,
#    'NumberOfCrossValidationFolds': 1,
#    'TrainersToExclude': []},
#   'TestDataMode': 'Union',
#   'ValidationDataMode': 'Union',
#   'OutlierFilters': [],
#   'User': 'DNikolaev',
#   'Modified': '2022-03-31T15:12:51.154',
#   'Created': '2023-01-24T08:16:54.787',
#   'Labels': [],
#   'Name': 'ML Static bug'},
#  {'IsTrained': True,
#   'Type': 'Regression',
#   'IsModelPerEntity': False,
#   'TableFormula': 'Table "ESP PCA"\r\n\tColumn "Motor Voltage" in "V"\r\n\t\t"motor voltage" in "V"\r\n\tEnd Column\r\n\tColumn "Pressure intake" in "psi"\r\n\t\t"pump intake pressure" in "psi"\r\n\tEnd Column\r\nEnd Table\r\n',
#   'ContextFormula': 'Context "AutoMLContext"\r\n\tEntity Set "Well 58 B5"\r\n\tScope "Start To End Daily"\r\nEnd Context\r\n\r\nEntity Set "Well 58 B5"\r\n\t"Well 58 B5"\r\nEnd Set\n\r\nScope "Start To End Daily"\r\n\tBetween StartOf()\r\n\tAnd EndOf()\r\n\tStep Daily\r\nEnd Scope\n\r\n',
#   'LabelColumnName': 'Motor Voltage',
#   'TestDataMode': 'Union',
#   'ValidationDataMode': 'Union',
#   'OutlierFilters': [],
#   'Modified': '2022-03-31T15:12:51.154',
#   'Created': '2023-01-24T08:16:54.787',
#   'Labels': [],
#   'Name': 'Model Name'},
#  {'IsTrained': True,
#   'Type': 'MultipleClassification',
#   'IsModelPerEntity': False,
#   'TableFormula': 'Table "FilterTable"\r\n\tColumn "flower" in " "\r\n\t\t"flower" in " "\r\n\tEnd Column\r\n\tColumn "petal length" in "cm"\r\n\t\t"petal length" in "cm"\r\n\tEnd Column\r\n\tColumn "petal width" in "cm"\r\n\t\t"petal width" in "cm"\r\n\tEnd Column\r\n\tColumn "sepal length" in "cm"\r\n\t\t"sepal length" in "cm"\r\n\tEnd Column\r\n\tColumn "sepal width" in "cm"\r\n\t\t"sepal width" in "cm"\r\n\tEnd Column\r\nEnd Table\r\n',
#   'ContextFormula': 'Context "AutoMLContext"\r\n\tEntity Set "FilterEntitySet"\r\n\tScope "FilterScope"\r\nEnd Context\r\n\r\nEntity Set "FilterEntitySet"\r\n\t"ML Example"\r\nEnd Set\n\r\nScope "FilterScope" \n\tBetween #01/01/1992 00:00# \n\tAnd #01/01/1992 12:25# \n\tStep EveryFiveMinutes \nEnd Scope\n\r\n',
#   'LabelColumnName': 'flower',
#   'TestDataMode': 'Union',
#   'ValidationDataMode': 'Union',
#   'OutlierFilters': [],
#   'Modified': '2022-03-31T15:12:51.154',
#   'Created': '2023-01-24T08:16:54.787',
#   'Labels': [],
#   'Name': 'MulticlassClassification'},
#  {'IsTrained': True,
#   'Type': 'Regression',
#   'IsModelPerEntity': False,
#   'TableFormula': 'Table "FilterTable"\r\n\tColumn "bottom hole pressure decreasing trend threshold" in " "\r\n\t\t"bottom hole pressure decreasing trend threshold" in " "\r\n\tEnd Column\r\n\tColumn "bottom hole pressure increasing trend threshold" in " "\r\n\t\t"bottom hole pressure increasing trend threshold" in " "\r\n\tEnd Column\r\n\tColumn "bottom hole pressure lower threshold" in "bar"\r\n\t\t"bottom hole pressure lower threshold" in "bar"\r\n\tEnd Column\r\n\tColumn "bottom hole pressure upper threshold" in "bar"\r\n\t\t"bottom hole pressure upper threshold" in "bar"\r\n\tEnd Column\r\n\tColumn "bottom hole temperature decreasing trend threshold" in " "\r\n\t\t"bottom hole temperature decreasing trend threshold" in " "\r\n\tEnd Column\r\n\tColumn "bottom hole temperature increasing trend threshold" in " "\r\n\t\t"bottom hole temperature increasing trend threshold" in " "\r\n\tEnd Column\r\n\tColumn "bottom hole temperature lower threshold" in "degC"\r\n\t\t"bottom hole temperature lower threshold" in "degC"\r\n\tEnd Column\r\n\tColumn "bottom hole temperature upper threshold" in "degC"\r\n\t\t"bottom hole temperature upper threshold" in "degC"\r\n\tEnd Column\r\nEnd Table\r\n',
#   'TestDataMode': 'Union',
#   'ValidationDataMode': 'Union',
#   'OutlierFilters': [],
#   'Modified': '2022-03-31T15:12:51.154',
#   'Created': '2023-01-24T08:16:54.787',
#   'Labels': [],
#   'Name': 'MyRegressionModel'},
#  {'IsTrained': True,
#   'Type': 'Regression',
#   'IsModelPerEntity': False,
#   'TableFormula': 'Table "Iris dataset"\r\n\tColumn "aggregated oil production 2 year" in "STB"\r\n\t\t"aggregated oil production 2 year" in "STB"\r\n\tEnd Column\r\n\tColumn "initial oil saturation" in " "\r\n\t\t"initial oil saturation" in " "\r\n\tEnd Column\r\n\tColumn "normalized productivity index" in " "\r\n\t\t"normalized productivity index" in " "\r\n\tEnd Column\r\nEnd Table\r\n',
#   'TestDataMode': 'Union',
#   'ValidationDataMode': 'Union',
#   'OutlierFilters': [],
#   'Modified': '2022-03-31T15:12:51.154',
#   'Created': '2023-01-24T08:16:54.787',
#   'Labels': [],
#   'Name': 'Oil volume prediction'},
#  {'IsTrained': True,
#   'Type': 'Regression',
#   'IsModelPerEntity': False,
#   'TableFormula': 'Table "Test"\r\n\tColumn "Oil" in "m3"\r\n\t\t"produced oil per time increment" in "m3"\r\n\tEnd Column\r\n\tColumn "ones" in " "\r\n\t\t1.0\r\n\tEnd Column\r\n\tColumn "Step" in " "\r\n\t\t1.0\r\n\tEnd Column\r\n\tColumn "Diff" in " "\r\n\t\tIIf(IsNull(MovingDiff("produced oil per time increment" in "m3", Column "Step" in " ")) And IsNotNull ("produced oil per time increment" in "m3"), NULL(), MovingDiff(IIf(IsNull("produced oil per time increment" in "m3"),0.0,"produced oil per time increment" in "m3"), Column "Step" in " "))\r\n\tEnd Column\r\n\tColumn "Shifted Oil" in "m3"\r\n\t\tIf IsNotNull(MovingDiff("produced oil per time increment" in "m3", Column "Step" in " ")) Then\r\n\t\t\t"produced oil per time increment" in "m3" !- MovingDiff("produced oil per time increment" in "m3", Column "Step" in " ")\r\n\t\tElseIf IsNull(MovingDiff("produced oil per time increment" in "m3", Column "Step" in " ")) And Column "Diff" in " " = 0 Then\r\n\t\t\tNull()\r\n\t\tElseIf IsNull(MovingDiff("produced oil per time increment" in "m3", Column "Step" in " ")) And IsNotNull(Column "Diff" in " ") Then\r\n\t\t\t"produced oil per time increment" in "m3" !- MovingDiff(IIf(IsNull("produced oil per time increment" in "m3"),0.0,"produced oil per time increment" in "m3"), Column "Step" in " ")\r\n\t\tElse\r\n\t\t\tNull()\r\n\t\tEnd If\r\n\tEnd Column\r\n\tColumn "Outlier" in " "\r\n\t\tIf "produced oil per time increment" in "m3" = 15 Or\r\n\t\t\t"produced oil per time increment" in "m3" = 35 Or\r\n\t\t\t"produced oil per time increment" in "m3" = 10 Or\r\n\t\t\t"produced oil per time increment" in "m3" = 25 Or\r\n\t\t\t"produced oil per time increment" in "m3" = 27 Or\r\n\t\t\t"produced oil per time increment" in "m3" = 40 Or\r\n\t\t\t"produced oil per time increment" in "m3" = 5 Or\r\n\t\t\t"produced oil per time increment" in "m3" = 20 Or\r\n\t\t\t"produced oil per time increment" in "m3" = 17 Or\r\n\t\t\t"produced oil per time increment" in "m3" = 33\r\n\t\tThen\r\n\t\t\t1.0\r\n\t\tElse\r\n\t\t\t0.0\r\n\t\tEnd If\r\n\tEnd Column\r\n\tColumn "Change Point" in " "\r\n\t\tIf "produced oil per time increment" in "m3" = 23.66682902 Then\r\n\t\t\t1.0\r\n\t\tElse\r\n\t\t\t0.0\r\n\t\tEnd If\r\n\tEnd Column\r\nEnd Table\r\n',
#   'ContextFormula': 'Context "AutoMLContext"\r\n\tEntity Set "MLModelEntitySet"\r\n\tScope "MLModelScope"\r\nEnd Context\r\n\r\nEntity Set "MLModelEntitySet"\r\n\t"ML Example"\r\nEnd Set\n\r\nScope "MLModelScope"\r\n\tBetween #01/01/2010 00:00#\r\n\tAnd #01/01/2010 01:36#\r\n\tStep EveryMinute\r\nEnd Scope\n\r\n',
#   'LabelColumnName': 'Oil',
#   'TestDataMode': 'Union',
#   'ValidationDataMode': 'Union',
#   'OutlierFilters': [],
#   'Modified': '2022-03-31T15:12:51.154',
#   'Created': '2023-01-24T08:16:54.787',
#   'Labels': [],
#   'Name': 'Outlier Detection'},
#  {'IsTrained': True,
#   'Type': 'Regression',
#   'IsModelPerEntity': False,
#   'TableFormula': '/// ESP PCA Data Preparation\r\n/// \r\n/// Description:\r\n///  \r\n/// \r\n/// Input:\r\n///  motor voltage [V]\r\n///  motor current [A]\r\n///  pump efficiency [ ]\r\n///  motor efficiency [ ]\r\n///  pump factor [ ]\r\n///  pump intake pressure [psi]\r\n/// \r\n/// Author: Ramez Abdalla, 22/11/2021\r\n\r\nContext "All Wells Start To End Daily"\r\n\tEntity Set "Well 58 B5"\r\n\tScope "Start To End Daily"\r\nEnd Context\r\n//Context "Well 58 B Daily"\r\n//    Entity Set "Well 58 B5"\r\n//    Scope "14-20 Daily-"\r\n//End Context\n\n\n\r\nTable "ESP PCA"\r\n\tColumn "Motor Voltage" in "V"\r\n\t\t "motor voltage" in "V"\r\n\tEnd Column\r\n\t\r\n//\tColumn "Motor Current" in "A"\r\n//\t\t"motor current" in "A"\r\n//\tEnd Column\r\n\t\r\n//\tColumn "Pump Efficiency" in " "\r\n//\t\t"pump efficiency" in " "//e.g. 0.60\r\n//\tEnd Column\r\n//\t\r\n//\tColumn "Motor Efficiency" in " "\r\n//\t\t"motor efficiency" in " "\t//e.g. 0.5\r\n//\tEnd Column\r\n//\t\r\n//\tColumn "Pump Factor" in " "\r\n//\t\t"pump factor" in " "\t// e.g. 0.55\r\n//\tEnd Column\r\n//\t\r\n\tColumn "Pressure intake" in "psi"\r\n\t\t"pump intake pressure" in "psi"\r\n\tEnd Column\r\n\t\r\nEnd Table',
#   'ContextFormula': '/// ESP PCA Data Preparation\r\n/// \r\n/// Description:\r\n///  \r\n/// \r\n/// Input:\r\n///  motor voltage [V]\r\n///  motor current [A]\r\n///  pump efficiency [ ]\r\n///  motor efficiency [ ]\r\n///  pump factor [ ]\r\n///  pump intake pressure [psi]\r\n/// \r\n/// Author: Ramez Abdalla, 22/11/2021\r\n\r\nContext "All Wells Start To End Daily"\r\n\tEntity Set "Well 58 B5"\r\n\tScope "Start To End Daily"\r\nEnd Context\r\n//Context "Well 58 B Daily"\r\n//    Entity Set "Well 58 B5"\r\n//    Scope "14-20 Daily-"\r\n//End Context\n\n\n\r\nTable "ESP PCA"\r\n\tColumn "Motor Voltage" in "V"\r\n\t\t "motor voltage" in "V"\r\n\tEnd Column\r\n\t\r\n//\tColumn "Motor Current" in "A"\r\n//\t\t"motor current" in "A"\r\n//\tEnd Column\r\n\t\r\n//\tColumn "Pump Efficiency" in " "\r\n//\t\t"pump efficiency" in " "//e.g. 0.60\r\n//\tEnd Column\r\n//\t\r\n//\tColumn "Motor Efficiency" in " "\r\n//\t\t"motor efficiency" in " "\t//e.g. 0.5\r\n//\tEnd Column\r\n//\t\r\n//\tColumn "Pump Factor" in " "\r\n//\t\t"pump factor" in " "\t// e.g. 0.55\r\n//\tEnd Column\r\n//\t\r\n\tColumn "Pressure intake" in "psi"\r\n\t\t"pump intake pressure" in "psi"\r\n\tEnd Column\r\n\t\r\nEnd Table',
#   'TestDataMode': 'Union',
#   'ValidationDataMode': 'Union',
#   'OutlierFilters': [],
#   'Modified': '2022-03-31T15:12:51.154',
#   'Created': '2023-01-24T08:16:54.787',
#   'Labels': [],
#   'Name': 'PCA BootCamp'},
#  {'IsTrained': True,
#   'Type': 'Regression',
#   'IsModelPerEntity': False,
#   'TableFormula': '/// ESP PCA Data Preparation\r\n/// \r\n/// Description:\r\n///  \r\n/// \r\n/// Input:\r\n///  motor voltage [V]\r\n///  motor current [A]\r\n///  pump efficiency [ ]\r\n///  motor efficiency [ ]\r\n///  pump factor [ ]\r\n///  pump intake pressure [psi]\r\n/// \r\n/// Author: Ramez Abdalla, 22/11/2021\r\n// Updated\r\nContext "All Wells Start To End Daily"\r\n\tEntity Set "Well 58 B5"\r\n\tScope "ESP Scope"\r\nEnd Context\r\n\r\n\r\n\r\n//Context "Well 58 B Daily"\r\n//    Entity Set "Well 58 B5"\r\n//    Scope "14-20 Daily-"\r\n//End Context\r\n\r\n\r\n\r\nTable "ESP PCA"\r\n\tColumn "Motor Voltage" in "V"\r\n\t\t "motor voltage" in "V"\r\n\tEnd Column\r\n\t\r\n\tColumn "Motor Current" in "A"\r\n\t\t"motor current" in "A"\r\n\tEnd Column\r\n\t\r\n//\tColumn "Pump Efficiency" in " "\r\n//\t\t"pump efficiency" in " "//e.g. 0.60\r\n//\tEnd Column\r\n\t\r\n//\tColumn "Motor Efficiency" in " "\r\n//\t\t"motor efficiency" in " "\t//e.g. 0.5\r\n//\tEnd Column\r\n\t\r\n//\tColumn "Pump Factor" in " "\r\n//\t\t"pump factor" in " "\t// e.g. 0.55\r\n//\tEnd Column\r\n//\t\r\n\tColumn "Pressure intake" in "psi"\r\n\t\t"pump intake pressure" in "psi"\r\n\tEnd Column\r\n\t\r\nEnd Table',
#   'ContextFormula': '/// ESP PCA Data Preparation\r\n/// \r\n/// Description:\r\n///  \r\n/// \r\n/// Input:\r\n///  motor voltage [V]\r\n///  motor current [A]\r\n///  pump efficiency [ ]\r\n///  motor efficiency [ ]\r\n///  pump factor [ ]\r\n///  pump intake pressure [psi]\r\n/// \r\n/// Author: Ramez Abdalla, 22/11/2021\r\n// Updated\r\nContext "All Wells Start To End Daily"\r\n\tEntity Set "Well 58 B5"\r\n\tScope "ESP Scope"\r\nEnd Context\r\n\r\n\r\n\r\n//Context "Well 58 B Daily"\r\n//    Entity Set "Well 58 B5"\r\n//    Scope "14-20 Daily-"\r\n//End Context\r\n\r\n\r\n\r\nTable "ESP PCA"\r\n\tColumn "Motor Voltage" in "V"\r\n\t\t "motor voltage" in "V"\r\n\tEnd Column\r\n\t\r\n\tColumn "Motor Current" in "A"\r\n\t\t"motor current" in "A"\r\n\tEnd Column\r\n\t\r\n//\tColumn "Pump Efficiency" in " "\r\n//\t\t"pump efficiency" in " "//e.g. 0.60\r\n//\tEnd Column\r\n\t\r\n//\tColumn "Motor Efficiency" in " "\r\n//\t\t"motor efficiency" in " "\t//e.g. 0.5\r\n//\tEnd Column\r\n\t\r\n//\tColumn "Pump Factor" in " "\r\n//\t\t"pump factor" in " "\t// e.g. 0.55\r\n//\tEnd Column\r\n//\t\r\n\tColumn "Pressure intake" in "psi"\r\n\t\t"pump intake pressure" in "psi"\r\n\tEnd Column\r\n\t\r\nEnd Table',
#   'TestDataMode': 'Union',
#   'ValidationDataMode': 'Union',
#   'OutlierFilters': [],
#   'Modified': '2022-03-31T15:12:51.154',
#   'Created': '2023-01-24T08:16:54.787',
#   'Labels': [],
#   'Name': 'PCA Model Ramez'},
#  {'IsTrained': True,
#   'Type': 'Regression',
#   'IsModelPerEntity': False,
#   'TableFormula': 'Table "MVR Test Data Table"\r\n\tColumn "B90_OilEq_boed" in " "\r\n\t\t"MVR_B90_OilEq_boed" in " "\r\n\tEnd Column\r\n\tColumn "TVD_e3ft" in " "\r\n\t\t"MVR_TVD_e3ft" in " "\r\n\tEnd Column\r\n\tColumn "Lateral_Length_e3ft" in " "\r\n\t\t"MVR_Lateral_Length_e3ft" in " "\r\n\tEnd Column\r\n\tColumn "Fluid_Pumped_e6gal" in " "\r\n\t\t"MVR_Fluid_Pumped_e6gal" in " "\r\n\tEnd Column\r\n\tColumn "Implied_HZ_Spacing_e3ft" in " "\r\n\t\t"MVR_Implied_HZ_Spacing_e3ft" in " "\r\n\tEnd Column\r\n\tColumn "BH_Long" in " "\r\n\t\t"MVR_BH_Long" in " "\r\n\tEnd Column\r\nEnd Table\r\n',
#   'ContextFormula': 'Context "AutoMLContext"\r\n\tEntity Set "MVR Test Entity Set"\r\n\tScope "MVR Test Scope"\r\nEnd Context\r\n\r\nEntity Set "MVR Test Entity Set"\r\n\t"ML Example"\r\nEnd Set\n\r\nScope "MVR Test Scope" \r\n\tBetween #01/01/1985 00:00# \r\n\tAnd #05/13/1986 00:00# \r\n\tStep Daily\r\nEnd Scope\n\r\n',
#   'LabelColumnName': 'B90_OilEq_boed',
#   'TrainingOptions': {'TestLatinHypercube': False,
#    'ValidationFraction': 0.1,
#    'OptimizationMetric': 'RSquared',
#    'TimeToTrain': 1,
#    'NumberOfClusters': 1,
#    'NumberOfCrossValidationFolds': 1,
#    'TrainersToExclude': ['FastForest',
#     'FastTree',
#     'FastTreeTweedie',
#     'LightGbm',
#     'OnlineGradientDescent',
#     'LbfgsPoissonRegression',
#     'StochasticDualCoordinateAscent']},
#   'Trained': '2022-06-29T13:08:52.5996194Z',
#   'TestDataMode': 'Union',
#   'ValidationDataMode': 'Union',
#   'IsReviewed': True,
#   'OutlierFilters': [],
#   'User': 'RomanManasipov',
#   'Modified': '2022-06-29T13:08:55.357',
#   'Created': '2023-01-24T08:16:54.787',
#   'Labels': [],
#   'Name': 'RM MVR Model'},
#  {'IsTrained': True,
#   'Type': 'BinaryClassification',
#   'IsModelPerEntity': False,
#   'TableFormula': 'Table "FilterTable"\r\n\tColumn "flower" in " "\r\n\t\t"flower_binary" in " "\r\n\tEnd Column\r\n\tColumn "petal length" in "cm"\r\n\t\t"petal length" in "cm"\r\n\tEnd Column\r\n\tColumn "petal width" in "cm"\r\n\t\t"petal width" in "cm"\r\n\tEnd Column\r\n\tColumn "sepal length" in "cm"\r\n\t\t"sepal length" in "cm"\r\n\tEnd Column\r\n\tColumn "sepal width" in "cm"\r\n\t\t"sepal width" in "cm"\r\n\tEnd Column\r\nEnd Table\r\n',
#   'ContextFormula': 'Context "AutoMLContext"\r\n\tEntity Set "MLModelEntitySet"\r\n\tScope "MLModelScope"\r\nEnd Context\r\n\r\nEntity Set "MLModelEntitySet"\r\n\t"ML Example"\r\nEnd Set\n\r\nScope "MLModelScope"\r\n\tBetween #01/01/1992 00:00# \r\n\tAnd #01/01/1992 08:15# \r\n\tStep EveryFiveMinutes \r\nEnd Scope\n\r\n',
#   'LabelColumnName': 'flower',
#   'TrainingOptions': {'TestLatinHypercube': False,
#    'ValidationFraction': 0.1,
#    'OptimizationMetric': 'Accuracy',
#    'TimeToTrain': 1,
#    'NumberOfClusters': 1,
#    'NumberOfCrossValidationFolds': 1,
#    'TrainersToExclude': ['AveragedPerceptron',
#     'FastForest',
#     'FastTree',
#     'LinearSvm',
#     'LbfgsLogisticRegression',
#     'SdcaLogisticRegression',
#     'SgdCalibrated',
#     'SymbolicSgdLogisticRegression']},
#   'Trained': '2022-09-20T17:53:12.4022201Z',
#   'TestDataMode': 'Union',
#   'ValidationDataMode': 'Union',
#   'IsReviewed': True,
#   'OutlierFilters': [],
#   'Modified': '2022-09-20T17:53:13.945',
#   'Created': '2023-01-24T08:16:54.787',
#   'Labels': [],
#   'Name': 'RMIrisBinaryClassification'},
#  {'IsTrained': True,
#   'Type': 'Regression',
#   'IsModelPerEntity': False,
#   'TableFormula': 'Table "IristTransformerTable"\r\n\tColumn "flower" in " "\r\n\t\t"flower" in " "\r\n\tEnd Column\r\n\tColumn "petal length" in "cm"\r\n\t\t"petal length" in "cm"\r\n\tEnd Column\r\n\tColumn "petal width" in "cm"\r\n\t\t"petal width" in "cm"\r\n\tEnd Column\r\n\tColumn "sepal length" in "cm"\r\n\t\t"sepal length" in "cm"\r\n\tEnd Column\r\n\t// Column "sepal width" in "cm"\r\n\t//\t"sepal width" in "cm"\r\n\t// End Column\r\nEnd Table',
#   'ContextFormula': 'Context "AutoMLContext"\r\n\tEntity Set "MLModelEntitySet"\r\n\tScope "MLModelScope"\r\nEnd Context\r\n\r\nEntity Set "MLModelEntitySet"\r\n\t"ML Example"\r\nEnd Set\n\r\nScope "MLModelScope"\r\n\tBetween #01/01/1985 00:00#\r\n\tAnd #07/01/1985 05:00#\r\n\tStep Hourly\r\nEnd Scope\n\r\n',
#   'LabelColumnName': 'flower',
#   'TrainingOptions': {'TestLatinHypercube': False,
#    'ValidationFraction': 0.1,
#    'OptimizationMetric': 'RSquared',
#    'TimeToTrain': 5,
#    'NumberOfClusters': 5,
#    'NumberOfCrossValidationFolds': 1,
#    'TrainersToExclude': ['FastForest',
#     'FastTree',
#     'FastTreeTweedie',
#     'LightGbm',
#     'OnlineGradientDescent',
#     'LbfgsPoissonRegression',
#     'StochasticDualCoordinateAscent']},
#   'Trained': '2022-09-20T17:54:48.3770357Z',
#   'TestDataMode': 'Union',
#   'ValidationDataMode': 'Union',
#   'IsReviewed': True,
#   'OutlierFilters': [],
#   'Modified': '2022-09-20T17:54:49.805',
#   'Created': '2023-01-24T08:16:54.787',
#   'Labels': [],
#   'Name': 'RMIrisTestBoxCoxBoxTidwell'},
#  {'IsTrained': True,
#   'Type': 'Clustering',
#   'IsModelPerEntity': False,
#   'TableFormula': 'Table "FilterTable"\r\n\tColumn "petal length" in "cm"\r\n\t\t"petal length" in "cm"\r\n\tEnd Column\r\n\tColumn "petal width" in "cm"\r\n\t\t"petal width" in "cm"\r\n\tEnd Column\r\n\tColumn "sepal length" in "cm"\r\n\t\t"sepal length" in "cm"\r\n\tEnd Column\r\n\tColumn "sepal width" in "cm"\r\n\t\t"sepal width" in "cm"\r\n\tEnd Column\r\nEnd Table\r\n',
#   'ContextFormula': 'Context "AutoMLContext"\r\n\tEntity Set "FilterEntitySet"\r\n\tScope "FilterScope"\r\nEnd Context\r\n\r\nEntity Set "FilterEntitySet"\r\n\t"ML Example"\r\nEnd Set\n\r\nScope "FilterScope" \n\tBetween #01/01/1992 00:00# \n\tAnd #01/01/1992 12:25# \n\tStep EveryFiveMinutes \nEnd Scope\n\r\n',
#   'LabelColumnName': 'petal length',
#   'TrainingOptions': {'TestLatinHypercube': False,
#    'TimeToTrain': 3,
#    'NumberOfClusters': 3,
#    'TrainersToExclude': []},
#   'Trained': '2022-12-04T10:45:58.239Z',
#   'TestDataMode': 'Union',
#   'ValidationDataMode': 'Union',
#   'IsReviewed': True,
#   'OutlierFilters': [],
#   'Modified': '2022-12-04T10:45:58.492',
#   'Created': '2023-01-24T08:16:54.787',
#   'Labels': [],
#   'Name': 'RMIrisTestClustering'},
#  {'IsTrained': True,
#   'Type': 'MultipleClassification',
#   'IsModelPerEntity': False,
#   'TableFormula': 'Table "FilterTable"\r\n\tColumn "flower" in " "\r\n\t\t"flower" in " "\r\n\tEnd Column\r\n\tColumn "petal length" in "cm"\r\n\t\t"petal length" in "cm"\r\n\tEnd Column\r\n\tColumn "petal width" in "cm"\r\n\t\t"petal width" in "cm"\r\n\tEnd Column\r\n\tColumn "sepal length" in "cm"\r\n\t\t"sepal length" in "cm"\r\n\tEnd Column\r\n\tColumn "sepal width" in "cm"\r\n\t\t"sepal width" in "cm"\r\n\tEnd Column\r\nEnd Table\r\n',
#   'ContextFormula': 'Context "AutoMLContext"\n  Entity Set "FilterEntitySet"\n  Scope "FilterScope"\n  \nEnd Context\nEntity Set "FilterEntitySet"\r\n\t"ML Example"\r\nEnd Set\nScope "FilterScope" \n\tBetween #01/01/1992 00:00# \n\tAnd #01/01/1992 12:25# \n\tStep EveryFiveMinutes \nEnd Scope',
#   'LabelColumnName': 'flower',
#   'ValidationScopeFormula': 'Scope "MLModelValidationScope"\r\n\tBetween #01/01/1992 12:00# \r\n\tAnd #01/01/1992 12:25# \r\n\tStep EveryFiveMinutes \r\nEnd Scope\n',
#   'TrainingOptions': {'TestLatinHypercube': False,
#    'OptimizationMetric': 'MacroAccuracy',
#    'TimeToTrain': 5,
#    'NumberOfClusters': 5,
#    'NumberOfCrossValidationFolds': 1,
#    'TrainersToExclude': [],
#    'PreProcessors': [{'NormalizationType': 'BoxTidwell'},
#     {'NormalizationType': 'ApproximatedKernelMap', 'Order': 1},
#     {'NormalizationType': 'Binning', 'Order': 2},
#     {'NormalizationType': 'BoxCox', 'Order': 3},
#     {'NormalizationType': 'GlobalContrast', 'Order': 4},
#     {'NormalizationType': 'LogMeanVariance', 'Order': 5},
#     {'NormalizationType': 'LpNorm', 'Order': 6},
#     {'NormalizationType': 'MeanVariance', 'Order': 7},
#     {'NormalizationType': 'MinMax', 'Order': 8},
#     {'NormalizationType': 'ProjectToPrincipalComponents', 'Order': 9},
#     {'NormalizationType': 'RobustScaling', 'Order': 10},
#     {'NormalizationType': 'SupervisedBinning', 'Order': 11}]},
#   'Trained': '2023-02-15T09:27:45.001Z',
#   'TestDataMode': 'Union',
#   'ValidationDataMode': 'Union',
#   'IsReviewed': True,
#   'OutlierFilters': [],
#   'Modified': '2023-02-15T09:27:45.217',
#   'Created': '2023-01-24T08:16:54.787',
#   'ModifiedBy': 'RomanManasipov',
#   'Labels': [],
#   'Name': 'RMIrisTestMulticlassClassification'},
#  {'IsTrained': True,
#   'Type': 'Regression',
#   'IsModelPerEntity': False,
#   'TableFormula': 'Table "FilterTable"\r\n\tColumn "flower" in " "\r\n\t\t"flower" in " "\r\n\tEnd Column\r\n\tColumn "petal length" in "cm"\r\n\t\t"petal length" in "cm"\r\n\tEnd Column\r\n\tColumn "petal width" in "cm"\r\n\t\t"petal width" in "cm"\r\n\tEnd Column\r\n\tColumn "sepal length" in "cm"\r\n\t\t"sepal length" in "cm"\r\n\tEnd Column\r\n\tColumn "sepal width" in "cm"\r\n\t\t"sepal width" in "cm"\r\n\tEnd Column\r\nEnd Table\r\n',
#   'ContextFormula': 'Context "AutoMLContext"\r\n\tEntity Set "FilterEntitySet"\r\n\tScope "FilterScope"\r\nEnd Context\r\n\r\nEntity Set "FilterEntitySet"\r\n\t"ML Example"\r\nEnd Set\n\r\nScope "FilterScope" \n\tBetween #01/01/1992 00:00# \n\tAnd #01/01/1992 12:25# \n\tStep EveryFiveMinutes \nEnd Scope\n\r\n',
#   'LabelColumnName': 'flower',
#   'TrainingOptions': {'TestFraction': 0.1,
#    'TestLatinHypercube': False,
#    'ValidationFraction': 0.2,
#    'OptimizationMetric': 'RSquared',
#    'TimeToTrain': 1,
#    'NumberOfClusters': 1,
#    'NumberOfCrossValidationFolds': 1,
#    'TrainersToExclude': ['FastForest',
#     'FastTreeTweedie',
#     'LightGbm',
#     'OnlineGradientDescent',
#     'Ols',
#     'LbfgsPoissonRegression',
#     'StochasticDualCoordinateAscent'],
#    'CustomTrainingType': 'Ols',
#    'CustomTrainingOptions': {'L2Regularization': 1e-06,
#     'EnablePruning': True,
#     'LearningRate': 0.002,
#     'MaximumBinCountPerFeature': 255,
#     'MinimumExampleCountPerLeaf': 10,
#     'NumberOfIterations': 9500,
#     'PruningMetrics': 'LeastSquares',
#     'Oversampling': 20,
#     'EnsureZeroMean': True}},
#   'Trained': '2022-11-25T20:01:33.939Z',
#   'TestDataMode': 'Intersection',
#   'ValidationDataMode': 'Intersection',
#   'IsReviewed': True,
#   'OutlierFilters': [],
#   'Modified': '2022-11-25T20:01:34.23',
#   'Created': '2023-01-24T08:16:54.787',
#   'Labels': [],
#   'Name': 'RMIrisTestRegression'},
#  {'IsTrained': True,
#   'Type': 'Regression',
#   'IsModelPerEntity': False,
#   'TableFormula': 'Table "FilterTable"\r\n\tColumn "flower" in " "\r\n\t\t"flower" in " "\r\n\tEnd Column\r\n\tColumn "petal length" in "cm"\r\n\t\t"petal length" in "cm"\r\n\tEnd Column\r\n\tColumn "petal width" in "cm"\r\n\t\t"petal width" in "cm"\r\n\tEnd Column\r\n\tColumn "sepal length" in "cm"\r\n\t\t"sepal length" in "cm"\r\n\tEnd Column\r\n\tColumn "sepal width" in "cm"\r\n\t\t"sepal width" in "cm"\r\n\tEnd Column\r\nEnd Table\r\n',
#   'ContextFormula': 'Context "AutoMLContext"\r\n\tEntity Set "MLModelEntitySet"\r\n\tScope "MLModelScope"\r\nEnd Context\r\n\r\nEntity Set "MLModelEntitySet"\r\n\t"ML Example"\r\nEnd Set\n\r\nScope "MLModelScope"\r\n\tBetween #01/01/1992 00:00#\r\n\tAnd #01/01/1992 12:25#\r\n\tStep EveryMinute\r\nEnd Scope\n\r\n',
#   'LabelColumnName': 'flower',
#   'ValidationScopeFormula': 'Scope "MLModelScope"\r\n\tBetween #01/01/1992 10:00#\r\n\tAnd #01/01/1992 11:05#\r\n\tStep EveryMinute\r\nEnd Scope\n',
#   'ValidationEntitySetFormula': 'Entity Set "MLModelValidationEntitySet"\r\n\t"ML Example"\r\nEnd Set\n',
#   'TestScopeFormula': 'Scope "MLModelTestScope"\r\n\tBetween #01/01/1992 12:00#\r\n\tAnd #01/01/1992 12:25#\r\n\tStep EveryMinute\r\nEnd Scope\n',
#   'TestEntitySetFormula': 'Entity Set "MLModelTestEntitySet"\r\n\t"ML Example"\r\nEnd Set\n',
#   'TrainingOptions': {'OptimizationMetric': 'RSquared',
#    'TimeToTrain': 5,
#    'NumberOfClusters': 5,
#    'NumberOfCrossValidationFolds': 1,
#    'TrainersToExclude': ['FastForest',
#     'FastTree',
#     'FastTreeTweedie',
#     'OnlineGradientDescent',
#     'Ols',
#     'LbfgsPoissonRegression',
#     'StochasticDualCoordinateAscent']},
#   'Trained': '2022-09-28T13:20:25.675Z',
#   'TestDataMode': 'Intersection',
#   'ValidationDataMode': 'Intersection',
#   'IsReviewed': True,
#   'OutlierFilters': [],
#   'Modified': '2022-09-28T13:20:26.103',
#   'Created': '2023-01-24T08:16:54.787',
#   'Labels': [],
#   'Name': 'RMIrisTestRegressionCustom'},
#  {'IsTrained': True,
#   'Type': 'Regression',
#   'IsModelPerEntity': False,
#   'TableFormula': 'Table "FilterTable"\r\n\tColumn "flower label" in " "\r\n\t\t"flower" in " "\r\n\tEnd Column\r\n\tColumn "petal length feature" in "cm"\r\n\t\t"petal length" in "cm"\r\n\tEnd Column\r\n\tColumn "petal width feature" in "cm"\r\n\t\t"petal width" in "cm"\r\n\tEnd Column\r\n\tColumn "sepal length feature" in "cm"\r\n\t\t"sepal length" in "cm"\r\n\tEnd Column\r\n\tColumn "sepal width feature" in "cm"\r\n\t\t"sepal width" in "cm"\r\n\tEnd Column\r\nEnd Table\r\n',
#   'ContextFormula': 'Context "AutoMLContext"\r\n\tEntity Set "MLModelEntitySet"\r\n\tScope "MLModelScope"\r\nEnd Context\r\n\r\nEntity Set "MLModelEntitySet"\r\n\t"ML Example"\r\nEnd Set\n\r\nScope "MLModelScope"\r\n\tBetween #01/01/1992 00:00# \r\n\tAnd #01/01/1992 12:25# \r\n\tStep EveryFiveMinutes \r\nEnd Scope\n\r\n',
#   'LabelColumnName': 'flower label',
#   'TrainingOptions': {'TestLatinHypercube': False,
#    'ValidationFraction': 0.1,
#    'OptimizationMetric': 'RSquared',
#    'TimeToTrain': 5,
#    'NumberOfClusters': 5,
#    'NumberOfCrossValidationFolds': 1,
#    'TrainersToExclude': ['FastTree',
#     'FastTreeTweedie',
#     'LightGbm',
#     'OnlineGradientDescent',
#     'LbfgsPoissonRegression',
#     'StochasticDualCoordinateAscent']},
#   'Trained': '2022-06-01T13:45:14.1690658Z',
#   'TestDataMode': 'Union',
#   'ValidationDataMode': 'Union',
#   'IsReviewed': True,
#   'OutlierFilters': [],
#   'Modified': '2022-06-01T13:45:15.727',
#   'Created': '2023-01-24T08:16:54.787',
#   'Labels': [],
#   'Name': 'RMIrisTestRegressionRenamedFeatures'},
#  {'Type': 'BinaryClassification',
#   'IsModelPerEntity': False,
#   'TableFormula': 'Table "FilterTable"\n\tColumn "flower" in " "\n\t\t"flower_binary" in " "\n\tEnd Column\n\tColumn "petal length" in "cm"\n\t\t"petal length" in "cm"\n\tEnd Column\n\tColumn "petal width" in "cm"\n\t\t"petal width" in "cm"\n\tEnd Column\n\tColumn "sepal length" in "cm"\n\t\t"sepal length" in "cm"\n\tEnd Column\n\tColumn "sepal width" in "cm"\n\t\t"sepal width" in "cm"\n\tEnd Column\nEnd Table\n',
#   'ContextFormula': 'Context "AutoMLContext"\n  Entity Set "MLModelEntitySet"\n  Scope "MLModelScope"\n  \nEnd Context\nEntity Set "MLModelEntitySet"\r\n\t"ML Example"\r\nEnd Set\nScope "MLModelScope"\r\n\tBetween #01/01/1992 00:00# \r\n\tAnd #01/01/1992 08:15# \r\n\tStep EveryFiveMinutes \r\nEnd Scope',
#   'LabelColumnName': 'flower',
#   'TrainingOptions': {'TimeToTrain': 5,
#    'NumberOfClusters': 1,
#    'NumberOfCrossValidationFolds': 1,
#    'TrainersToExclude': []},
#   'TestDataMode': 'Union',
#   'ValidationDataMode': 'Union',
#   'OutlierFilters': [],
#   'User': 'LisaKrenn',
#   'Modified': '2022-03-31T15:12:51.154',
#   'Created': '2023-01-24T08:16:54.787',
#   'Labels': [],
#   'Name': 'Test Binary Classification'},
#  {'Type': 'Regression',
#   'IsModelPerEntity': False,
#   'TableFormula': 'Table "classification example dataset"\n\tColumn "sepal length" in "cm"\n\t\t"sepal length" in "cm"\n\tEnd Column\n\tColumn "sp width" in "cm"\n\t\t"sepal width" in "cm"\n\tEnd Column\n\tColumn "petal length" in "cm"\n\t\t"petal length" in "cm"\n\tEnd Column\n\tColumn "petal width" in "cm"\n\t\t"petal width" in "cm"\n\tEnd Column\n\tColumn "fl class" in " "\n\t\t"fl class" in " "\n\tEnd Column\nEnd Table\n',
#   'ContextFormula': 'Context "AutoMLContext"\n  Entity Set "MLModelEntitySet"\n  Scope "MLModelScope"\n  \nEnd Context\nEntity Set "MLModelEntitySet"\n  "_this is an entity with a super long name to check if bug 11469 is fixed or not"\nEnd Set\nScope "MLModelScope"\n    Between Now()\n    And Now()\n    Step EveryFiveMinutes\nEnd Scope',
#   'LabelColumnName': 'fl class',
#   'TrainingOptions': {'TimeToTrain': 5,
#    'NumberOfClusters': 1,
#    'NumberOfCrossValidationFolds': 1,
#    'TrainersToExclude': []},
#   'TestDataMode': 'Union',
#   'ValidationDataMode': 'Union',
#   'OutlierFilters': [],
#   'Modified': '2022-03-31T15:12:51.154',
#   'Created': '2023-01-24T08:16:54.787',
#   'Labels': [],
#   'Name': 'test_methods'},
#  {'IsTrained': True,
#   'Type': 'Regression',
#   'IsModelPerEntity': False,
#   'TableFormula': 'Table "FilterTable"\r\n\tColumn "gas oil ratio upper threshold" in " "\r\n\t\t"gas oil ratio upper threshold" in " "\r\n\tEnd Column\r\n\tColumn "max allowable water cut" in " "\r\n\t\t"max allowable water cut" in " "\r\n\tEnd Column\r\n\tColumn "oil formation volume factor" in "rm3/sm3"\r\n\t\t"oil formation volume factor" in "rm3/sm3"\r\n\tEnd Column\r\n\tColumn "oil saturation" in " "\r\n\t\t"oil saturation" in " "\r\n\tEnd Column\r\n\tColumn "original oil in place" in "m3"\r\n\t\t"original oil in place" in "m3"\r\n\tEnd Column\r\n\tColumn "surface tension water" in "dyne/cm"\r\n\t\t"surface tension water" in "dyne/cm"\r\n\tEnd Column\r\n\tColumn "water cut upper threshold" in " "\r\n\t\t"water cut upper threshold" in " "\r\n\tEnd Column\r\n\tColumn "water saturation" in " "\r\n\t\t"water saturation" in " "\r\n\tEnd Column\r\nEnd Table\r\n',
#   'TestDataMode': 'Union',
#   'ValidationDataMode': 'Union',
#   'OutlierFilters': [],
#   'Modified': '2022-03-31T15:12:51.154',
#   'Created': '2023-01-24T08:16:54.787',
#   'Labels': [],
#   'Name': 'test_regression_FVC'},
#  {'IsTrained': True,
#   'Type': 'Clustering',
#   'IsModelPerEntity': False,
#   'TableFormula': 'Table "MLModelTable"\n\tColumn "Oil Production" in "STB"\n\t\tAverage(\n\t\t\tFillGaps("produced oil per time increment" in "STB")\n\t\t)\n\tEnd Column\n\n\tColumn "Water Production" in "STB"\n\t\tAverage(\n\t\t\tFillGaps("produced water per time increment" in "STB")\n\t\t)\n\tEnd Column\n\nEnd Table',
#   'ContextFormula': 'Context "AutoMLContext"\n  Entity Set "UK Wells"\n  Scope "Start To End Monthly"\n  \nEnd Context\nEntity Set "UK Wells"\r\n"Well J0001"\r\n"Well J0002"\r\n"Well J0003"\r\n"Well J0004"\r\n"Well J0005"\r\n"Well J0006"\r\n"Well J0007"\r\n"Well J0008"\r\nEnd Set\nScope "Start To End Monthly"\r\n\tBetween StartOf()\r\n\tAnd EndOf()\r\n\tStep Monthly\r\nEnd Scope',
#   'LabelColumnName': 'Oil Production',
#   'TrainingOptions': {'TimeToTrain': 2,
#    'NumberOfClusters': 2,
#    'TrainersToExclude': []},
#   'Trained': '2021-12-15T09:06:12.06Z',
#   'TestDataMode': 'Union',
#   'ValidationDataMode': 'Union',
#   'OutlierFilters': [],
#   'Modified': '2022-03-31T15:12:51.154',
#   'Created': '2023-01-24T08:16:54.787',
#   'Labels': [],
#   'Name': 'Well Classes'},
#  {'IsTrained': True,
#   'Type': 'Clustering',
#   'IsModelPerEntity': False,
#   'TableFormula': 'Table "MLModelTable"\n\tColumn "Oil Production" in "STB"\n\t\t// Average(\n\t\t\tFillGaps("produced oil per time increment" in "STB")\n\t\t// )\n\tEnd Column\n\n\tColumn "Water Production" in "STB"\n\t\t// Average(\n\t\t\tFillGaps("produced water per time increment" in "STB")\n\t\t// )\n\tEnd Column\n\nEnd Table',
#   'ContextFormula': 'Context "AutoMLContext"\n  Entity Set "UK Wells"\n  Scope "Start To End Monthly"\n  \nEnd Context\nEntity Set "UK Wells"\r\n"Well J0001"\r\n"Well J0002"\r\n"Well J0003"\r\n"Well J0004"\r\n"Well J0005"\r\n"Well J0006"\r\n"Well J0007"\r\n"Well J0008"\r\nEnd Set\nScope "Start To End Monthly"\r\n\tBetween StartOf()\r\n\tAnd EndOf()\r\n\tStep Monthly\r\nEnd Scope',
#   'LabelColumnName': 'Oil Production',
#   'TrainingOptions': {'TimeToTrain': 2,
#    'NumberOfClusters': 2,
#    'TrainersToExclude': []},
#   'Trained': '2021-12-15T09:06:36.104Z',
#   'TestDataMode': 'Union',
#   'ValidationDataMode': 'Union',
#   'OutlierFilters': [],
#   'Modified': '2022-03-31T15:12:51.154',
#   'Created': '2023-01-24T08:16:54.787',
#   'Labels': [],
#   'Name': 'Well Classes Dynamic'}]

# %%
# get item labels
pv_api.get_item_labels('MachineLearningModel')
# Out:
# ['_New',
#  'ABC Plot',
#  'Aggregation bug',
#  'Allocation (kh)',
#  'Auto DCA',
#  'Back Allocation',
#  'Backallocation',
#  'Basic',
#  'BC',
#  'Boot Camp',
#  'Bootcamp Test Lable',
#  'Bug Testing',
#  'Chan Plot',
#  'Choke Optimization',
#  'Completion Optimization',
#  'Downtime Monitoring',
#  'Economics',
#  'Electrical Submersible Pump Monitoring',
#  'Entity Scores',
#  'Estimated Ultimate Recovery',
#  'Flowing Stability',
#  'Gas Breakthrough',
#  'Gas Lift',
#  'Gas Lift Monitoring',
#  'Gradients (p, T, H)',
#  'Hall Plot',
#  'Hearn Plot',
#  'IPR (Fetkovich)',
#  'IPR (Vogel)',
#  'Jessica',
#  'Jessica Next',
#  'Jet Pump Monitoring',
#  'Liquid Loading',
#  'Monitoring',
#  'Multi-Variable Regression',
#  'PDMS',
#  'Plunger Lift Monitoring',
#  'Plunger Lift Monitoring Dashboard',
#  'Problem Detection',
#  'Production and Completion Dashboards',
#  'Production Forecast (DCA)',
#  'Production KPIs',
#  'PVT Correlations',
#  'Reactivation And Shut-In Dashboard',
#  'Reactivation And Underperformance Dashboard',
#  'Reservoir KPIs',
#  'Review Needed',
#  'Risk Index',
#  'Sand Problem',
#  'Subsurface Allocation (kh)',
#  'Sucker Rod Pump Monitoring',
#  'Technical Problem',
#  'Testing',
#  'Type Curve Builder',
#  'Underperformance Detection',
#  'Underperformance HI',
#  'Underperformance Monthly Targets',
#  'Underperformance Production Threshold',
#  'Underperforming Well Identification (HI)',
#  'Underperforming Well Identification (Monthly Targets)',
#  'Underperforming Well Identification (Production Threshold)',
#  'VFM (Choke Models)',
#  'VFM (ESP ML-based)',
#  'VFM (ESP)',
#  'VFM (NF ML-based)',
#  'VFM (SRP)',
#  'Virtual Flow Metering',
#  'Visualization',
#  'VLP',
#  'Voidage Replacement Ratio',
#  'Voronoi',
#  'VRR',
#  'Water Breakthrough',
#  'Well Test',
#  'Wells Management Dashboard']
